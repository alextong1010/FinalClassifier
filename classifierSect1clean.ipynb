# %%
#imports
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.model_selection import cross_val_score
import pandas as pd
import numpy as np
import sys
#sys.path.append("../BerkeleySETI/Messy-Notebooks")
sys.path.append("../FinalClassifier/data")
import os

import data
from data import loaders
from data import phasefold as pf
import lightkurve as lk
import warnings
import glob
import pickle

# %load_ext autoreload
# %autoreload 2

# %%
#set up
warnings.filterwarnings("ignore", category=RuntimeWarning) #fset = pd.read_csv('sect6data.csv')
data_dir = "/mnt/disks/lcs/"
data.mount_drive(data_dir)
data_dir = "/mnt/disks/lcs/tess-goddard-lcs/"
# Out:
# Disk mounted
# mount: /mnt/disks/lcs: special device /dev/sdc does not exist.

# %% [markdown]
# ___
# We want to get the features that we will use for our classifier
# <br><b> *Note: Be sure we have the correct 62 features, with mstat and astat

# %%
#import sector 6 features
# !gcsfuse --implicit-dirs tess-goddard-lcs /home/jupyter/mountpoint
datafile = "/home/jupyter/mountpoint/dataproducts/db.v2.h5"
scores6 = pd.read_hdf(datafile, f'S6/scores')
features6 = pd.read_hdf(datafile, f'S6/features')
# Out:
# 2023/02/14 02:57:31.327942 Start gcsfuse/0.39.2 (Go version go1.17.5) for app "" using mount point: /home/jupyter/mountpoint
# 2023/02/14 02:57:31.337940 Opening GCS connection...
# 2023/02/14 02:57:31.464476 Mounting file system "tess-goddard-lcs"...
# daemonize.Run: readFromProcess: sub-process: mountWithArgs: mountWithConn: Mount: mount: running /usr/bin/fusermount: exit status 1

# %%
warnings.filterwarnings("ignore", category=RuntimeWarning) #fset = pd.read_csv('sect6data.csv')
data_dir =  "/home/jupyter/mountpoint"
data.mount_drive(data_dir)
data_dir = "/mnt/disks/lcs/tess-goddard-lcs/"

# %%
# !gcsfuse --implicit-dirs tess-goddard-lcs /home/jupyter/mountpoint
# Out:
# 2023/02/14 22:43:24.617546 Start gcsfuse/0.39.2 (Go version go1.17.5) for app "" using mount point: /home/jupyter/mountpoint
# 2023/02/14 22:43:24.632209 Opening GCS connection...
# 2023/02/14 22:43:24.805606 Mounting file system "tess-goddard-lcs"...
# 2023/02/14 22:43:24.893884 File system has been successfully mounted.

# %%
ls /home/jupyter/mountpoint
# Out:
# S14_feats/          sector23lookup.csv      tesslcs_sector_17_104/
# S24_feats/          sector24lookup.csv      tesslcs_sector_18_104/
# S6_feats/           sector25lookup.csv      tesslcs_sector_19_104/
# S6_stats.csv        sector26lookup.csv      tesslcs_sector_1_104/
# S9_feats/           sector2lookup.csv       tesslcs_sector_20_104/
# dataproducts/       sector3lookup.csv       tesslcs_sector_21_104/
# sector10lookup.csv  sector4lookup.csv       tesslcs_sector_22_104/
# sector11lookup.csv  sector5lookup.csv       tesslcs_sector_23_104/
# sector12lookup.csv  sector6lookup.csv       tesslcs_sector_24_104/
# sector13lookup.csv  sector7lookup.csv       tesslcs_sector_25_104/
# sector14lookup.csv  sector8lookup.csv       tesslcs_sector_26_104/
# sector15lookup.csv  sector9lookup.csv       tesslcs_sector_2_104/
# sector16lookup.csv  tess_lc_readme.txt      tesslcs_sector_3_104/
# sector17lookup.csv  tesslcs_sector_10_104/  tesslcs_sector_4_104/
# sector18lookup.csv  tesslcs_sector_11_104/  tesslcs_sector_5_104/
# sector19lookup.csv  tesslcs_sector_12_104/  tesslcs_sector_6_104/
# sector1lookup.csv   tesslcs_sector_13_104/  tesslcs_sector_7_104/
# sector20lookup.csv  tesslcs_sector_14_104/  tesslcs_sector_8_104/
# sector21lookup.csv  tesslcs_sector_15_104/  tesslcs_sector_9_104/
# sector22lookup.csv  tesslcs_sector_16_104/  tesslcs_tmag_14_15/

# %%
features6

# %% [markdown]
# ____
# You don't need to run the below section, as feats.csv has already been provided as training data. This is just for your own reference if you're wondering where it came from

# %%
#list of ebs that we will use for our training data
txt_file = open("data/ebs_s6.txt", "r")
file_content = txt_file.read()
content_list = file_content.split("\n")
txt_file.close()
eb = [eval(i) for i in content_list]

#list of eb tics
eb
# Out:
# [235231072,
#  301185875,
#  301185877,
#  234169663,
#  89016404,
#  80836949,
#  140336965,
#  156501953,
#  282503011,
#  715766691,
#  301185891,
#  436619704,
#  39354700,
#  220140809,
#  156241056,
#  285000038,
#  285000042,
#  234065348,
#  265899106,
#  39838127,
#  234878308,
#  43144900,
#  206794153,
#  265715239,
#  207004915,
#  235548197,
#  247681431,
#  36288537,
#  119461266,
#  234169642,
#  237590010,
#  39667795,
#  235552142,
#  79635172,
#  369673753,
#  280212098,
#  266193357,
#  143215473,
#  234926584,
#  445955531,
#  712487688,
#  279900791,
#  387690877,
#  42991740,
#  438545375,
#  92009366,
#  159086692,
#  247556517,
#  284199394,
#  231161386,
#  445955532,
#  445955536,
#  206840164,
#  206840192,
#  234158088,
#  308387164,
#  60242904,
#  714514062,
#  139476794,
#  139476806,
#  308169172,
#  159057212,
#  309908733,
#  349480507,
#  42885762,
#  206840156,
#  206850953,
#  234146623,
#  308169197,
#  60242900,
#  220149256,
#  231959604,
#  42991745,
#  140209204,
#  237647557,
#  264594192,
#  264594193,
#  264594194,
#  281157204,
#  138904948,
#  280304732,
#  437918915,
#  97568437,
#  247681430,
#  369681523,
#  369681536,
#  140336990,
#  167256623,
#  201370666,
#  229237152,
#  306905057,
#  141709240,
#  283006429,
#  95418661,
#  294119465,
#  438288160,
#  232034359,
#  43144874,
#  234624242,
#  306817398,
#  438223490,
#  250443627,
#  279796545,
#  36990719,
#  42991726,
#  283006433,
#  438293906,
#  50659057,
#  300324638,
#  11808370,
#  11808371,
#  176470704,
#  206840195,
#  219409444,
#  237507887,
#  37316458,
#  119461300,
#  282495325,
#  302340148,
#  39668310,
#  151063207,
#  176614267,
#  235414808,
#  282351869,
#  282998718,
#  438288172,
#  756454456,
#  282209236,
#  301704147,
#  301704152,
#  301704153,
#  37316455,
#  437918918,
#  461703816,
#  167389970,
#  234624235,
#  234894242,
#  235303328,
#  265555610,
#  282798793,
#  403692550,
#  42338957,
#  437904791,
#  437904795,
#  53588177,
#  156393017,
#  199785944,
#  242250275,
#  42170496,
#  437904792,
#  247918435,
#  426186639,
#  438069056,
#  130471040,
#  234936456,
#  386424337,
#  762545039,
#  232032228,
#  389246178,
#  389246185,
#  42828781,
#  438227098,
#  716204722,
#  199968319,
#  229385067,
#  229385082,
#  151063222,
#  234715463,
#  24452609,
#  264624860,
#  317689427,
#  43144871,
#  53162135,
#  59612379,
#  119372769,
#  365847442,
#  372609406,
#  443259043,
#  49831062,
#  755847240,
#  97806682,
#  167394288,
#  206764020,
#  229385059,
#  39415794,
#  438418676,
#  66648950,
#  140508513,
#  232224516,
#  119461304,
#  124502767,
#  141866705,
#  284282609,
#  120745399,
#  120745404,
#  50659059,
#  12038405,
#  124689860,
#  282269780,
#  35952821,
#  229385041,
#  259701720,
#  438509428,
#  53588186,
#  120747811,
#  281413332,
#  120388722,
#  120747830,
#  167118350,
#  199822637,
#  237660049,
#  279320871,
#  234169645,
#  235306309,
#  235409201,
#  251289297,
#  281418869,
#  59280009,
#  148340729,
#  202184479,
#  220140821,
#  232198432,
#  232198435,
#  265546852,
#  300654002,
#  127301362,
#  167327421,
#  234226344,
#  234715460,
#  436423802,
#  139642009,
#  229358578,
#  229385092,
#  235396114,
#  235409203,
#  235457825,
#  282387418,
#  300036507,
#  39469660,
#  403692549,
#  59280006,
#  119167549,
#  207046873,
#  229385087,
#  229385088,
#  235258085,
#  89014648,
#  89014653,
#  124502774,
#  206674664,
#  229385112,
#  247676219,
#  281986911,
#  33715938,
#  50744490,
#  124432691,
#  229287858,
#  229385104,
#  336880307,
#  34581797,
#  438295250,
#  438424683,
#  234260432,
#  265546923,
#  280638951,
#  306691906,
#  307126450,
#  372490191,
#  415563281,
#  436012788,
#  443454759,
#  717496493,
#  124432702,
#  229358584,
#  250470344,
#  263333524,
#  272186474,
#  307728577,
#  717440280,
#  143354383,
#  144668693,
#  206674657,
#  237742527,
#  235409189,
#  266193350,
#  332970838,
#  437938517,
#  231346981,
#  25424123,
#  265899102,
#  265899110,
#  443319587,
#  157209065,
#  176614276,
#  231973885,
#  237507898,
#  32873118,
#  387229922,
#  46683673,
#  59213085,
#  156189781,
#  229352082,
#  232412758,
#  235409199,
#  251206055,
#  251237526,
#  307812314,
#  349480514,
#  36288515,
#  386327889,
#  72917766,
#  123725518,
#  247681414,
#  263272042,
#  382627629,
#  438416595,
#  53074547,
#  130644269,
#  172929558,
#  234665454,
#  251206064,
#  306690431,
#  66775597,
#  202011313,
#  206840126,
#  235258091,
#  237691704,
#  265899135,
#  39354694,
#  172833685,
#  235258076,
#  265362860,
#  415559924,
#  437986153,
#  59861132,
#  200056081,
#  235548205,
#  237441167,
#  237441169,
#  251134159,
#  255614589,
#  53170097,
#  60242909,
#  91522419,
#  11966639,
#  235437772,
#  251258191,
#  282263788,
#  123887853,
#  234700591,
#  410901165,
#  438509437,
#  54061142,
#  54061143,
#  59884578,
#  707289725,
#  140458718,
#  156734695,
#  172463638,
#  206854002,
#  24433067,
#  282577675,
#  284161463,
#  37240869,
#  437918917,
#  438416591,
#  743942566,
#  156947021,
#  234169697,
#  234699869,
#  234699871,
#  234885789,
#  235408254,
#  235548169,
#  237559308,
#  237559313,
#  280121242,
#  280121246,
#  71517879,
#  234699878,
#  36208528,
#  372609390,
#  20176492,
#  220205834,
#  232480841,
#  302869568,
#  308169213,
#  36208551,
#  365690980,
#  372425303,
#  11293508,
#  200120648,
#  206840170,
#  206840188,
#  229164895,
#  279616049,
#  307949673,
#  33715940,
#  339857928,
#  386327883,
#  434376205,
#  438365723,
#  52737084,
#  717496491,
#  200050180,
#  280304726,
#  302496282,
#  434376215,
#  207021412,
#  234616593,
#  234699858,
#  247714544,
#  291343804,
#  49246304,
#  71725881,
#  172307763,
#  20299673,
#  355357667,
#  37240864,
#  437905006,
#  153166843,
#  206702927,
#  247667456,
#  291260630,
#  291260642,
#  300325437,
#  97806687,
#  156947026,
#  158824537,
#  206764040,
#  234209263,
#  234209270,
#  247512434,
#  306691924,
#  309908721,
#  385899979,
#  420979727,
#  434376228,
#  438207939,
#  241921636,
#  346646026,
#  36367554,
#  231093356,
#  232481009,
#  234665445,
#  234665451,
#  238185181,
#  306691907,
#  319725684,
#  319853552,
#  32606913,
#  52541313,
#  91522420,
#  140570639,
#  220284125,
#  237691696,
#  24888830,
#  307950297,
#  308066391,
#  436624926,
#  443444892,
#  717295348,
#  117765901,
#  220149277,
#  234008379,
#  294671852,
#  438124870,
#  92009372,
#  92009379,
#  100682885,
#  153685840,
#  200088284,
#  206853977,
#  220047476,
#  238126522,
#  266003558,
#  282387411,
#  387694967,
#  393121395,
#  79687152,
#  117817195,
#  200056066,
#  220130146,
#  220130148,
#  53588206,
#  59347432,
#  220297784,
#  220297793,
#  235540791,
#  251258200,
#  280702982,
#  37075538,
#  436618703,
#  78819700,
#  79781905,
#  199969937,
#  231161382,
#  235155583,
#  241986556,
#  408236936,
#  42466688,
#  12232597,
#  123574363,
#  124688144,
#  220149229,
#  235155599,
#  235155604,
#  237742523,
#  344087341,
#  443460954,
#  443460957,
#  445938786,
#  759314850,
#  759314856,
#  237402053,
#  51827383,
#  92990143,
#  123887862,
#  142403599,
#  153694155,
#  20069386,
#  238011217,
#  155306460,
#  282579197,
#  372425162,
#  443083875,
#  50897839,
#  91928719,
#  139411248,
#  143381462,
#  151236160,
#  234066327,
#  234066335,
#  234879732,
#  43144899,
#  43246128,
#  241921635,
#  265999748,
#  280638974,
#  63192395,
#  140337579,
#  156574193,
#  202143810,
#  206724120,
#  206786798,
#  220297790,
#  229178814,
#  229396922,
#  232280023,
#  238034675,
#  247923859,
#  271901807,
#  35481250,
#  36208513,
#  369675041,
#  369675055,
#  443330065,
#  717181226,
#  150067840,
#  281714329,
#  302340144,
#  386272893,
#  42888689,
#  438287069,
#  53594991,
#  80566011,
#  91928688,
#  206946569,
#  207004590,
#  220332979,
#  229195593,
#  229195598,
#  307126714,
#  369467873,
#  437986119,
#  438460242,
#  140443194,
#  235445122,
#  302862144,
#  307372724,
#  32926886,
#  387226003,
#  11299475,
#  130615297,
#  140458706,
#  149629043,
#  231178604,
#  237695822,
#  247866378,
#  91928692,
#  11300045,
#  140458729,
#  157531814,
#  206890742,
#  207004944,
#  234830112,
#  235499713,
#  247878677,
#  294057678,
#  294057679,
#  34508912,
#  35481234,
#  369711010,
#  434376251,
#  436243628,
#  79141239,
#  150067837,
#  232280001,
#  232280010,
#  247712900,
#  300034498,
#  34508448,
#  35481236,
#  36993007,
#  415559907,
#  52967746,
#  207020288,
#  220336796,
#  235397625,
#  251188823,
#  39676299,
#  438410463,
#  48754534,
#  119301028,
#  20069384,
#  260130290,
#  260161144,
#  302869577,
#  434389267,
#  71576133,
#  737425238,
#  737425239,
#  207021422,
#  235397623,
#  251238463,
#  336880311,
#  385823460,
#  220275892,
#  229178824,
#  231822771,
#  235185235,
#  237425160,
#  241921634,
#  247956122,
#  282808760,
#  42821191,
#  436338003,
#  438365608,
#  438545686,
#  438545690,
#  443255589,
#  59354634,
#  11300044,
#  11357838,
#  220275907,
#  235489262,
#  281714339,
#  281804470,
#  299939799,
#  31259271,
#  36997737,
#  372495910,
#  438114855,
#  96925988,
#  118929099,
#  21729804,
#  282577679,
#  287848525,
#  307129872,
#  4351786,
#  49246291,
#  53455094,
#  59860471,
#  11901022,
#  220275894,
#  247878714,
#  307249028,
#  445960570,
#  52515811,
#  369681539,
#  369681546,
#  102571243,
#  172929552,
#  172929553,
#  172929554,
#  202114282,
#  219155476,
#  233975504,
#  234876578,
#  235397631,
#  247681411,
#  247833780,
#  302535426,
#  317878794,
#  372490054,
#  372490056,
#  438195198,
#  438195201,
#  49246311,
#  52507996,
#  59543269,
#  97856341,
#  156571689,
#  202184223,
#  247712901,
#  442923972,
#  48755874,
#  206763638,
#  220313662,
#  24451446,
#  283006461,
#  284284106,
#  306609971,
#  369673758,
#  37606903,
#  385901760,
#  42991764,
#  711721199,
#  711721201,
#  96443288,
#  207021417,
#  280113554,
#  308486315,
#  308487320,
#  35574283,
#  387690538,
#  434380323,
#  445938775,
#  461710769,
#  72781536,
#  206850943,
#  235303345,
#  279989655,
#  282381271,
#  34851176,
#  42766697,
#  43239415,
#  438460748,
#  52588893,
#  53418296,
#  61170886,
#  11693134,
#  237694486,
#  237722387,
#  237722392,
#  241986937,
#  265546846,
#  281807810,
#  48755859,
#  747218124,
#  97576369,
#  158954932,
#  220053768,
#  220212793,
#  234209267,
#  291334195,
#  306818567,
#  319856659,
#  337266314,
#  434376188,
#  434376190,
#  147765319,
#  206952262,
#  235126767,
#  235184613,
#  251237538,
#  265156769,
#  282349911,
#  306507227,
#  308064528,
#  32761657,
#  32761659,
#  438460756,
#  438465172,
#  199784245,
#  20062065,
#  220200239,
#  234226357,
#  235155619,
#  237425139,
#  237652382,
#  238081665,
#  382269132,
#  219373406,
#  271639765,
#  282510373,
#  393092190,
#  434376194,
#  438226468,
#  52871524,
#  156241215,
#  220419359,
#  235542975,
#  355357661,
#  438288209,
#  48755855,
#  97576379,
#  12036808,
#  144544666,
#  220404905,
#  263290044,
#  301593898,
#  319853550,
#  349835367,
#  438056472,
#  438120388,
#  438231187,
#  438231192,
#  93171302,
#  93171303,
#  140608211,
#  170102292,
#  207002240,
#  247878693,
#  32558398,
#  37999466,
#  385905982,
#  438418693,
#  220215755,
#  235517223,
#  141413795,
#  155310669,
#  167037441,
#  172409280,
#  25511232,
#  372428016,
#  438193116,
#  715692071,
#  11807985,
#  127234520,
#  229345338,
#  229369640,
#  234631920,
#  234955149,
#  287351976,
#  319437069,
#  39468270,
#  4378082,
#  438288149,
#  140507408,
#  202274144,
#  207012035,
#  232153159,
#  251287085,
#  282118477,
#  349522140,
#  37403711,
#  434376185,
#  92010421,
#  117883206,
#  172409276,
#  172409281,
#  206763616,
#  206763641,
#  232032230,
#  238043771,
#  282512945,
#  42885775,
#  442923974,
#  445936004,
#  461712045,
#  48328235,
#  124193566,
#  206674658,
#  234212254,
#  235328548,
#  437960834,
#  457250054,
#  79781922,
#  123739819,
#  139673135,
#  237360565,
#  263466025,
#  278992257,
#  307574667,
#  319616481,
#  36369488,
#  59547870,
#  80575183,
#  156571696,
#  156846286,
#  206706853,
#  220156264,
#  234066111,
#  234066121,
#  247713496,
#  263805916,
#  263805918,
#  282194928,
#  287436782,
#  288257992,
#  438051479,
#  708180727,
#  130651822,
#  157403189,
#  158824564,
#  250594379,
#  281056561,
#  309794213,
#  141413799,
#  150443184,
#  150443185,
#  176612492,
#  235047281,
#  265613698,
#  300162041,
#  343862758,
#  138858938,
#  173042689,
#  202059438,
#  234723446,
#  234816231,
#  235282359,
#  355354860,
#  712481447,
#  759357598,
#  11412481,
#  12155361,
#  229296087,
#  234955151,
#  372495652,
#  7393001,
#  140343938,
#  141268467,
#  199756433,
#  206730379,
#  263584181,
#  282711546,
#  284999958,
#  385756901,
#  43239409,
#  437960821,
#  53595005,
#  80768279,
#  124193559,
#  172409268,
#  234173767,
#  234173782,
#  251180522,
#  265613712,
#  285001452,
#  43148902,
#  52641320,
#  97576370,
#  150443182,
#  220278229,
#  251257259,
#  350145806,
#  42759114,
#  438102208,
#  156241220,
#  161636565,
#  200519163,
#  202274151,
#  202274156,
#  220062284,
#  235511459,
#  25188030,
#  434395786,
#  438051474,
#  438318289,
#  438318293,
#  52492969,
#  711020884,
#  206853997,
#  207049483,
#  220042007,
#  234226326,
#  251232498,
#  25188041,
#  280703313,
#  385990845,
#  393087658,
#  436422772,
#  437911978,
#  714036588,
#  220053762,
#  220053779,
#  234631923,
#  234699566,
#  234699575,
#  235517237,
#  280216513,
#  307806180,
#  336878177,
#  387686027,
#  42766728,
#  53328216,
#  59467987,
#  79536184,
#  119634758,
#  150067832,
#  202012021,
#  220278774,
#  237647564,
#  251290224,
#  279909812,
#  438365742,
#  202013055,
#  220054381,
#  ...]

# %%
f6eb = features6.loc[eb]

# %%
#f6eb - corresponding 62 features for each eb
f6eb
# Out:
#            longtermtrend  meanmedrat     skews     varss  coeffvar  stds  \
# 235231072       0.026648    0.991050  0.000710  0.026889      94.0   0.0
# 301185875       0.081945    0.971039  0.006715  0.084389      97.0   0.0
# 301185877       0.081945    0.971039  0.006715  0.084389      97.0   0.0
# 234169663       0.044620    0.984330  0.001991  0.045330      95.0   0.0
# 89016404        0.086715    0.966162  0.007520  0.089752     112.0   0.0
# ...                  ...         ...       ...       ...       ...   ...
# 271643533       0.159520    0.949524  0.025447  0.168000     387.0   0.0
# 436423408       0.214966    0.928026  0.046210  0.231638     361.0   0.0
# 33865219        0.178479    0.943878  0.031855  0.189092     339.0   0.0
# 290039579       0.184797    0.941332  0.034150  0.196315     374.0   0.0
# 267253184       0.172871    0.949194  0.029884  0.182124     360.0   0.0
#
#            numoutliers  numnegoutliers  numposoutliers  numout1s  ...  \
# 235231072          0.0             0.0        0.000851  0.024911  ...
# 301185875          6.0             6.0        0.001877  0.500361  ...
# 301185877          6.0             6.0        0.001877  0.500361  ...
# 234169663          1.0             1.0        0.001174  0.165540  ...
# 89016404           0.0             0.0        0.002893  0.599635  ...
# ...                ...             ...             ...       ...  ...
# 271643533          1.0             1.0        0.110968  5.774229  ...
# 436423408          0.0             0.0        0.147812  5.761445  ...
# 33865219           1.0             1.0        0.118789  6.655849  ...
# 290039579          1.0             1.0        0.128155  5.482608  ...
# 267253184          1.0             1.0        0.121285  6.592301  ...
#
#            sautocorrcoef  autocorrcoef  flatmean  tflatmean  roundmean  \
# 235231072       0.881838      0.009123  0.013710   0.018850   0.026099
# 301185875       0.864516      0.004411  0.009037   0.013953   0.030553
# 301185877       0.864516      0.004411  0.009037   0.013953   0.030553
# 234169663       0.864516      0.006410  0.011026   0.016200   0.026155
# 89016404        0.835498      0.007718  0.014056   0.023216   0.110242
# ...                  ...           ...       ...        ...        ...
# 271643533       0.176963      0.249553  0.441912   0.638240   0.819257
# 436423408       0.211039      0.227504  0.422346   0.601965   0.813311
# 33865219        0.214831      0.226883  0.412879   0.600523   0.794949
# 290039579       0.186848      0.235463  0.431017   0.645656   0.826721
# 267253184       0.188375      0.244444  0.435666   0.616047   0.800648
#
#            troundmean  roundrat   flatrat  mstat     astat
# 235231072    0.428787  0.108102  0.042574  1.569  0.000000
# 301185875    0.436112  0.363679  0.042226  1.561  0.838213
# 301185877    0.436112  0.363679  0.042226  1.561  0.838212
# 234169663    0.478317  0.206123  0.024256  1.559  0.673318
# 89016404     0.612072  0.357053  0.079822  1.558  0.848091
# ...               ...       ...       ...    ...       ...
# 271643533    0.941121  0.968383  0.385284  0.623  0.934289
# 436423408    0.927010  0.507398  0.340901  0.622  0.901662
# 33865219     0.928034  1.000000  0.410119  0.621  0.899500
# 290039579    0.941337  0.910452  0.456640  0.596  0.926016
# 267253184    0.929995  1.000000  0.386406  0.591  0.904894
#
# [2475 rows x 62 columns]

# %%
#list of ebs from villanova (should be exhaustive in tmcl), which we will use to find our noneb dataset
tmclebs = pd.read_csv('data/allsectorstmclebs.csv')

ref = pd.read_csv(data_dir+f"sector6lookup.csv")
tmcl = ["2_min_cadence" in fn for fn in ref.Filename]
reftmcl = ref[tmcl]
z = ~reftmcl.TIC_ID.isin(tmclebs.TIC_ID.values)
f6nonebs = reftmcl[z].sample(frac=1)

# %%
#features for our noneb
f6noneb = features6.loc[f6nonebs.TIC_ID.values]
f6noneb
# Out:
#            longtermtrend  meanmedrat         skews     varss  coeffvar  stds  \
# 25154399        0.033006    0.998913  1.089383e-03  0.033042       1.0   0.0
# 141123349       0.033007    0.998940  1.089463e-03  0.033042       1.0   0.0
# 167011964       0.032162    0.998997  1.034377e-03  0.032194       1.0   0.0
# 96590480        0.032847    0.998906  1.078938e-03  0.032883       1.0   0.0
# 46689433        0.032310    0.998876  1.043908e-03  0.032346       1.0   0.0
# ...                  ...         ...           ...       ...       ...   ...
# 199780506       0.032314    0.999077  1.044224e-03  0.032344       1.0   0.0
# 373778750       0.033028    0.998923  1.090843e-03  0.033064       1.0   0.0
# 52407841        0.000246    0.999965  6.056922e-08  0.000246      83.0   0.0
# 124773772       0.032930    0.998614  1.084376e-03  0.032976       1.0   0.0
# 219397363       0.033078    0.998893  1.094139e-03  0.033114       1.0   0.0
#
#            numoutliers  numnegoutliers  numposoutliers  numout1s  ...  \
# 25154399           1.0             1.0        0.000150  0.012306  ...
# 141123349          1.0             1.0        0.000152  0.012235  ...
# 167011964          1.0             1.0        0.000335  0.023988  ...
# 96590480           1.0             1.0        0.001286  0.098406  ...
# 46689433           1.0             1.0        0.000192  0.016726  ...
# ...                ...             ...             ...       ...  ...
# 199780506          1.0             1.0        0.000764  0.017484  ...
# 373778750          1.0             1.0        0.000778  0.020972  ...
# 52407841          15.0            15.0        0.000069  0.002541  ...
# 124773772          1.0             1.0        0.001192  0.037553  ...
# 219397363          1.0             1.0        0.000176  0.013305  ...
#
#            sautocorrcoef  autocorrcoef  flatmean  tflatmean  roundmean  \
# 25154399        0.396947      0.147083  0.265044   0.408275   0.542439
# 141123349       0.489640      0.149793  0.264070   0.401689   0.543333
# 167011964       0.808377      0.116398  0.217366   0.312743   0.446608
# 96590480        0.362756      0.150576  0.279939   0.421968   0.566077
# 46689433        0.400835      0.145079  0.267925   0.412444   0.569479
# ...                  ...           ...       ...        ...        ...
# 199780506       0.351775      0.189740  0.319898   0.480136   0.612529
# 373778750       0.450382      0.150213  0.283939   0.431919   0.605251
# 52407841        0.838710      0.104297  0.192468   0.293428   0.417384
# 124773772       0.797632      0.162092  0.277038   0.413367   0.547033
# 219397363       0.377875      0.159972  0.275404   0.421782   0.577700
#
#            troundmean  roundrat   flatrat  mstat     astat
# 25154399     0.752525  1.000000  0.909173  0.168  0.154504
# 141123349    0.736477  1.000000  1.311692  0.160  0.254272
# 167011964    0.624298  0.993891  1.221206  0.157  0.157307
# 96590480     0.799384  1.000000  1.070000  0.157  0.076025
# 46689433     0.777185  1.000000  0.579144  0.183 -0.007720
# ...               ...       ...       ...    ...       ...
# 199780506    0.780981  1.000000  1.538470  0.156  0.456356
# 373778750    0.793218  1.000000  0.991907  0.158  0.235640
# 52407841     0.592949  0.002180  0.226581  0.791 -0.056192
# 124773772    0.763540  1.000000  0.276182  0.234  0.065945
# 219397363    0.755544  1.000000  0.632074  0.168  0.091051
#
# [18189 rows x 62 columns]

# %%
#new dataset (3) = f6eb + f6noneb
frames = [f6noneb, f6eb]
feats = pd.concat(frames)
feats.to_csv('data/feats.csv')

# %% [markdown]
# ___
# ML portion here

# %%
#run this line to read in feats.csv
feats = pd.read_csv('data/feats.csv', index_col = 0)

# %%
train, test = train_test_split(np.arange(len(feats)), train_size=0.8)
labels = []

for i in range(len(f6noneb)):
    labels.append('NonEB')
for i in range(len(f6noneb),len(f6eb)+len(f6noneb)):
    labels.append('EB')
    
X_trainfull = feats.iloc[train]
X_testfull = feats.iloc[test]

y_train = []
y_test = []
for i in train:
    y_train.append(labels[i])
for i in test:
    y_test.append(labels[i])
    
y_train = pd.Series(data = y_train, index = train)
y_test = pd.Series(data = y_test, index = test)

# %%
newy_train = []
for i in (y_train.index.values):
    if (y_train[i]=='NonEB'):
        newy_train.append(0)
    else:
        newy_train.append(1)
y_train = pd.Series(data = newy_train, index = train)

newy_test = []
for i in (y_test.index.values):
    if (y_test[i]=='NonEB'):
        newy_test.append(0)
    else:
        newy_test.append(1)
y_test = pd.Series(data = newy_test, index = test)

# %%
X_train = X_trainfull
X_test = X_testfull

# %%
X_train
# Out:
#            longtermtrend  meanmedrat     skews     varss  coeffvar  stds  \
# 32034265        0.033009    0.998936  0.001090  0.033044       1.0   0.0
# 238949526       0.032758    0.998940  0.001073  0.032793       1.0   0.0
# 67197292        0.032294    0.998965  0.001043  0.032328       1.0   0.0
# 255683786       0.032777    0.998858  0.001074  0.032814       1.0   0.0
# 24948729        0.032404    0.998913  0.001050  0.032439       1.0   0.0
# ...                  ...         ...       ...       ...       ...   ...
# 278899461       0.032479    0.998945  0.001055  0.032514       1.0   0.0
# 167125688       0.032348    0.998960  0.001046  0.032382       1.0   0.0
# 219183103       0.032757    0.998931  0.001073  0.032792       1.0   0.0
# 251236566       0.089483    0.959907  0.008007  0.093220     165.0   0.0
# 272429506       0.032353    0.998777  0.001047  0.032392       1.0   0.0
#
#            numoutliers  numnegoutliers  numposoutliers  numout1s  ...  \
# 32034265           1.0             1.0        0.000280  0.015626  ...
# 238949526          1.0             1.0        0.000201  0.012172  ...
# 67197292           1.0             1.0        0.000257  0.021495  ...
# 255683786          1.0             1.0        0.000834  0.012149  ...
# 24948729           1.0             1.0        0.001013  0.086636  ...
# ...                ...             ...             ...       ...  ...
# 278899461          1.0             1.0        0.000153  0.007374  ...
# 167125688          1.0             1.0        0.000335  0.025409  ...
# 219183103          1.0             1.0        0.000181  0.012155  ...
# 251236566          0.0             0.0        0.015844  0.653571  ...
# 272429506          1.0             1.0        0.000682  0.019655  ...
#
#            sautocorrcoef  autocorrcoef  flatmean  tflatmean  roundmean  \
# 32034265        0.432933      0.143311  0.264984   0.393812   0.532299
# 238949526       0.371643      0.150027  0.270864   0.412247   0.558991
# 67197292        0.376827      0.147975  0.266305   0.398647   0.565261
# 255683786       0.335124      0.154607  0.302515   0.408824   0.549936
# 24948729        0.402516      0.132812  0.246446   0.360943   0.520940
# ...                  ...           ...       ...        ...        ...
# 278899461       0.366420      0.155859  0.269150   0.423038   0.582543
# 167125688       0.518325      0.141360  0.249840   0.374989   0.520015
# 219183103       0.392052      0.141220  0.259406   0.385886   0.538042
# 251236566       0.693548      0.040739  0.083116   0.206994   0.511864
# 272429506       0.283770      0.182621  0.342348   0.465525   0.638942
#
#            troundmean  roundrat   flatrat  mstat     astat
# 32034265     0.766463  1.000000  1.273311  0.164  0.235399
# 238949526    0.769680  1.000000  0.641473  0.162  0.232014
# 67197292     0.770930  1.000000  0.814851  0.160  0.076123
# 255683786    0.751167  1.000000  0.571830  0.165  0.631518
# 24948729     0.751524  1.000000  0.663836  0.167  0.031053
# ...               ...       ...       ...    ...       ...
# 278899461    0.804810  1.000000  0.724643  0.161  0.406353
# 167125688    0.765963  1.000000  0.806458  0.164  0.173805
# 219183103    0.743628  1.000000  0.591531  0.163  0.099505
# 251236566    0.830851  0.296436  0.169804  1.249  0.867780
# 272429506    0.842035  1.000000  0.615087  0.181  0.295077
#
# [16531 rows x 62 columns]

# %%
RF = make_pipeline(StandardScaler(), RandomForestClassifier(n_estimators = 500, max_depth = 15,random_state=31415))
RF.fit(X_train,y_train)
y_predRF = RF.predict(X_test)
print(accuracy_score(y_test,y_predRF)) # Fraction of classifications that were correct
print(precision_score(y_test,y_predRF,pos_label=1))
# Out:
# 0.9997580450036293
# 0.9979879275653923

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_predRF)
# Out:
# array([[3636,    1],
#        [   0,  496]])

# %%
featswithlabels = feats
featswithlabels['Label'] = labels
featswithlabels = featswithlabels.sample(frac=1,random_state = 31415)
ylabel = featswithlabels['Label']
y = pd.Series(ylabel.values)
featswithlabels = featswithlabels.drop(columns=['Label'])
X = featswithlabels

# %%
models = [RF]
for i in models:
    scores = cross_val_score(i, X, y, cv=10)
    print(f'{i.named_steps}: {sum(scores)/10}')
# Out:
# {'standardscaler': StandardScaler(), 'randomforestclassifier': RandomForestClassifier(max_depth=15, n_estimators=500, random_state=31415)}: 0.9995160431451506

# %% [markdown]
# __________
# This assumes that astats is already in the datafile, and can be imported along with the other features

# %%
#sector you want to classify
sector = 1

# %%
#create the directory for each sector
os.mkdir(f'Sector{sector}')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# /tmp/ipykernel_19572/2473630476.py in <module>
#       1 #create the directory for each sector
# ----> 2 os.mkdir(f'Sector{sector}')
#
# FileExistsError: [Errno 17] File exists: 'Sector1'

# %%
#change the variable toClassify to data that you want to classify
toClassify = pd.read_hdf(datafile, f'S{sector}/features')
refsect = pd.read_csv(data_dir+f"sector{sector}lookup.csv")

# %%
refsect = pd.read_hdf(datafile, f'S{sector}/sector1lookup.csv')

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_26566/2596417889.py in <module>
# ----> 1 refsect = pd.read_hdf(datafile, f'S{sector}/sector1lookup.csv')
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/pytables.py in read_hdf(path_or_buf, key, mode, errors, where, start, stop, columns, iterator, chunksize, **kwargs)
#     461             iterator=iterator,
#     462             chunksize=chunksize,
# --> 463             auto_close=auto_close,
#     464         )
#     465     except (ValueError, TypeError, KeyError):
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/pytables.py in select(self, key, where, start, stop, columns, iterator, chunksize, auto_close)
#     848         group = self.get_node(key)
#     849         if group is None:
# --> 850             raise KeyError(f"No object named {key} in the file")
#     851
#     852         # create the storer and axes
#
# KeyError: 'No object named S1/sector1lookup.csv in the file'

# %%
y_pred = RF.predict(toClassify)
y_predprob = RF.predict_proba(toClassify)

# %%
y_probzero = []
y_probone = []
for i in range(len(y_predprob)):
    y_probzero.append(y_predprob[i][0])
    y_probone.append(y_predprob[i][1])

# %%
predictions = pd.DataFrame(index = toClassify.index.values)
predictions['probzero'] = y_probzero
predictions['probone'] = y_probone
predictions['pred'] = y_pred
predictions = predictions.sort_values(by=['probone'], ascending = False)

# %%
predictions
# Out:
#            probzero  probone  pred
# 140608211       0.0      1.0     1
# 231791552       0.0      1.0     1
# 300740040       0.0      1.0     1
# 181052118       0.0      1.0     1
# 38811805        0.0      1.0     1
# ...             ...      ...   ...
# 389505262       1.0      0.0     0
# 280048495       1.0      0.0     0
# 404808101       1.0      0.0     0
# 284196526       1.0      0.0     0
# 255567371       1.0      0.0     0
#
# [1192407 rows x 3 columns]

# %%
rslt_df = predictions[predictions['pred'] == 1]
rslt_df.to_csv(f'Sector{sector}/predSector{sector}.csv')
predictions.to_csv(f'Sector{sector}/sect{sector}predandprob.csv')

# %%
p = predictions[predictions['probone'] == 1]
# Out:
#            probzero  probone  pred
# 140608211       0.0      1.0     1
# 231791552       0.0      1.0     1
# 300740040       0.0      1.0     1
# 181052118       0.0      1.0     1
# 38811805        0.0      1.0     1
# ...             ...      ...   ...
# 260950407       0.0      1.0     1
# 349641813       0.0      1.0     1
# 33734375        0.0      1.0     1
# 141122198       0.0      1.0     1
# 25154836        0.0      1.0     1
#
# [337 rows x 3 columns]

# %%
p = predictions[predictions['probone'] > 0.9]
p
# Out:
#            probzero  probone  pred
# 140608211     0.000    1.000     1
# 231791552     0.000    1.000     1
# 300740040     0.000    1.000     1
# 181052118     0.000    1.000     1
# 38811805      0.000    1.000     1
# ...             ...      ...   ...
# 206498836     0.098    0.902     1
# 349683770     0.098    0.902     1
# 419588384     0.098    0.902     1
# 281630204     0.098    0.902     1
# 212261672     0.098    0.902     1
#
# [1489 rows x 3 columns]

# %%
p = predictions[predictions['probone'] > 0.5]
p = p[p['probone'] < 0.9]
p
# Out:
#             probzero   probone  pred
# 270221859   0.102000  0.898000     1
# 126803454   0.102000  0.898000     1
# 206488769   0.102000  0.898000     1
# 231702259   0.102000  0.898000     1
# 1989908229  0.102000  0.898000     1
# ...              ...       ...   ...
# 425064789   0.498000  0.502000     1
# 212255303   0.498000  0.502000     1
# 269883697   0.499000  0.501000     1
# 55274131    0.499000  0.501000     1
# 309860772   0.499667  0.500333     1
#
# [3331 rows x 3 columns]

# %%
#rslt_df = pd.read_csv(f'predSector{sector}.csv', index_col = 0)
values = rslt_df.index.values
values = values.tolist()
with open(f"Sector{sector}/ticpredictionsSector{sector}.txt", "w") as output:
    for i in range(len(values)):
        output.write(str(values[i]))
        output.write("\n")

# %%
values
# Out:
# [140608211,
#  231791552,
#  300740040,
#  181052118,
#  38811805,
#  303909865,
#  126605150,
#  270203709,
#  204497617,
#  307364443,
#  117544914,
#  89018905,
#  349835374,
#  316852879,
#  33715938,
#  316937318,
#  126945917,
#  306573146,
#  370239669,
#  126944778,
#  273550448,
#  39017668,
#  220388567,
#  290495367,
#  327939046,
#  177236393,
#  2026930048,
#  306665786,
#  31798977,
#  238891804,
#  232087348,
#  231093356,
#  278666918,
#  219170666,
#  261265716,
#  33734376,
#  267091837,
#  141866705,
#  89043105,
#  92259410,
#  425935688,
#  294671852,
#  220491219,
#  389021724,
#  117544922,
#  306900745,
#  410354938,
#  302751961,
#  300014528,
#  270174474,
#  201256776,
#  181886413,
#  355545390,
#  234524824,
#  231714659,
#  234285429,
#  219335483,
#  177164595,
#  389020350,
#  389020349,
#  30266257,
#  260503860,
#  309781192,
#  734588359,
#  300013254,
#  167750920,
#  314887863,
#  141268467,
#  300657354,
#  219159872,
#  277773589,
#  167651110,
#  355446601,
#  382627633,
#  126945904,
#  126945919,
#  150389733,
#  33862174,
#  150390197,
#  394700186,
#  150361911,
#  260541900,
#  382627629,
#  140761918,
#  184134559,
#  452357557,
#  349059354,
#  176933974,
#  300654002,
#  340459872,
#  350443417,
#  30266262,
#  350520980,
#  410354930,
#  25226885,
#  389476160,
#  277103007,
#  261746657,
#  234509214,
#  31636377,
#  270582604,
#  253912623,
#  260608573,
#  91450443,
#  290547046,
#  426031808,
#  181886412,
#  350336454,
#  441085223,
#  326442531,
#  279324151,
#  350145806,
#  140997887,
#  126785811,
#  409136916,
#  349966338,
#  307087198,
#  309472288,
#  126945918,
#  139265588,
#  147201138,
#  270204401,
#  232085494,
#  79181218,
#  307364441,
#  350622185,
#  349575587,
#  181879098,
#  737425239,
#  139453166,
#  33715940,
#  197979841,
#  219338651,
#  181879094,
#  302753894,
#  369180187,
#  121469576,
#  176982334,
#  441021825,
#  126803650,
#  389020348,
#  406279367,
#  301193954,
#  309472204,
#  139841210,
#  238891802,
#  302300783,
#  441080077,
#  278992257,
#  262704328,
#  260046636,
#  306630842,
#  394731512,
#  389528590,
#  126945913,
#  382101519,
#  358512352,
#  231712591,
#  115188534,
#  370243555,
#  307364426,
#  201293349,
#  306823710,
#  29753242,
#  25358644,
#  319290692,
#  266996790,
#  38762229,
#  231712592,
#  60647930,
#  389021723,
#  261677822,
#  167724932,
#  167724935,
#  55498363,
#  30266241,
#  201256771,
#  318606776,
#  271811068,
#  231791524,
#  441032606,
#  234346466,
#  33834253,
#  139699256,
#  260161144,
#  388198039,
#  2027167502,
#  393948907,
#  319290696,
#  161313139,
#  271901807,
#  289951325,
#  147201134,
#  453079616,
#  294206969,
#  300324638,
#  350145355,
#  91369561,
#  214367709,
#  260795041,
#  278703629,
#  44623916,
#  425865607,
#  261525123,
#  273550444,
#  300652458,
#  231665173,
#  2026841336,
#  270366148,
#  382629507,
#  167304040,
#  197980089,
#  79424812,
#  197979845,
#  31672006,
#  29286513,
#  294750649,
#  370239670,
#  373843394,
#  115177383,
#  309549613,
#  349480514,
#  358510297,
#  289952556,
#  99411125,
#  149040151,
#  348762908,
#  327937353,
#  348762899,
#  281814851,
#  300740195,
#  206363145,
#  409856414,
#  259720528,
#  141413795,
#  300162041,
#  144462697,
#  269939837,
#  181043969,
#  229060127,
#  141709240,
#  280053053,
#  349406253,
#  734588360,
#  259962026,
#  271638035,
#  306630840,
#  349677586,
#  149629043,
#  167250523,
#  231830630,
#  350155186,
#  140596438,
#  141413799,
#  234294638,
#  394242723,
#  388181972,
#  237905903,
#  260161142,
#  139355704,
#  349678280,
#  144219348,
#  141709132,
#  410252684,
#  300034498,
#  141213462,
#  219155476,
#  392814185,
#  278776988,
#  139347829,
#  299779869,
#  31869094,
#  737425238,
#  161167795,
#  141122196,
#  139754969,
#  309144265,
#  139699260,
#  287436782,
#  2027167504,
#  2027112725,
#  277941240,
#  220491218,
#  52154495,
#  300140005,
#  309256410,
#  382199764,
#  734511288,
#  206462118,
#  302753893,
#  261543495,
#  141709133,
#  302751916,
#  167815131,
#  358336077,
#  375036635,
#  441400622,
#  149541326,
#  392792586,
#  259719568,
#  231814930,
#  309403898,
#  404806381,
#  260654689,
#  79424807,
#  410446243,
#  177387851,
#  279475555,
#  184134558,
#  234524826,
#  388198040,
#  309256411,
#  300091984,
#  316976100,
#  139720025,
#  139091411,
#  270275805,
#  260271338,
#  139700944,
#  349575582,
#  60646278,
#  279616049,
#  279475551,
#  234346463,
#  29475978,
#  349522140,
#  261204832,
#  114948643,
#  231269538,
#  290547040,
#  270535918,
#  55652785,
#  260950407,
#  349641813,
#  33734375,
#  141122198,
#  25154836,
#  234516716,
#  29824720,
#  89398045,
#  117544915,
#  271639765,
#  54001270,
#  299779868,
#  306507227,
#  147201136,
#  267000838,
#  55652788,
#  126873187,
#  147338110,
#  270275812,
#  150067837,
#  201249836,
#  152223725,
#  234509218,
#  179314875,
#  306896976,
#  197695643,
#  350096019,
#  290547036,
#  219342231,
#  394242722,
#  279639068,
#  290133836,
#  220508951,
#  142016939,
#  290133832,
#  300445233,
#  219338650,
#  30104570,
#  150034856,
#  32177507,
#  261524220,
#  274014583,
#  287436799,
#  89398038,
#  261332760,
#  31268555,
#  306505222,
#  270244648,
#  270582602,
#  150067832,
#  150067845,
#  10000089372,
#  141472325,
#  234491752,
#  425935689,
#  161136872,
#  234509221,
#  299939799,
#  234337768,
#  306778837,
#  349407536,
#  147333766,
#  261592957,
#  141268468,
#  167339240,
#  160036449,
#  325204384,
#  372911986,
#  281631494,
#  238185181,
#  349764458,
#  139301655,
#  441191301,
#  349478455,
#  405412258,
#  349480491,
#  439366897,
#  2055311157,
#  152825523,
#  421950457,
#  201176965,
#  166975685,
#  270034984,
#  238202490,
#  152799055,
#  309251288,
#  150067840,
#  389527961,
#  79492099,
#  300330083,
#  382268992,
#  270250516,
#  92591722,
#  261543492,
#  177021252,
#  211403640,
#  300325437,
#  317097350,
#  765289454,
#  389920099,
#  197695641,
#  514923774,
#  402066970,
#  139322633,
#  79173869,
#  349832824,
#  79225651,
#  206462116,
#  1989169801,
#  2028782096,
#  2028782097,
#  269833439,
#  269833443,
#  317057820,
#  280801975,
#  33716637,
#  219308281,
#  317087106,
#  220404905,
#  271596289,
#  349835367,
#  415615620,
#  261646556,
#  407581481,
#  260951353,
#  309853389,
#  29189037,
#  97409172,
#  181043970,
#  257772609,
#  308751405,
#  167250519,
#  204544746,
#  309780436,
#  271596290,
#  140827017,
#  180212890,
#  350654946,
#  370239668,
#  349965312,
#  220388571,
#  299943609,
#  309853341,
#  393890994,
#  52384357,
#  139899011,
#  290463054,
#  237911081,
#  261748412,
#  631196353,
#  410422824,
#  410187774,
#  97409171,
#  52245789,
#  30313682,
#  441426728,
#  306573151,
#  631196355,
#  389023000,
#  349056499,
#  300447348,
#  260239481,
#  271812251,
#  140071573,
#  281631516,
#  350954272,
#  306736486,
#  231714759,
#  349480507,
#  197600964,
#  266996791,
#  300036507,
#  270565975,
#  139827700,
#  300514010,
#  234491750,
#  219213075,
#  350095551,
#  289794579,
#  79172475,
#  159808296,
#  235004657,
#  143951692,
#  349911024,
#  405412503,
#  161112484,
#  79153669,
#  281631635,
#  270424361,
#  300867470,
#  139720234,
#  211379274,
#  270204578,
#  389729356,
#  139720235,
#  152825521,
#  206363134,
#  214913613,
#  235004659,
#  281632837,
#  1989153984,
#  139839550,
#  388198038,
#  167549388,
#  314864554,
#  350093792,
#  441012391,
#  309780747,
#  300514590,
#  309474271,
#  300514057,
#  300447502,
#  280052690,
#  277099871,
#  382268993,
#  231714760,
#  270247508,
#  31796118,
#  79354602,
#  2026991166,
#  161155149,
#  79354601,
#  220516211,
#  301937147,
#  350213888,
#  126944775,
#  92498019,
#  1992094833,
#  139148071,
#  300445297,
#  281631485,
#  309853343,
#  293439290,
#  419744996,
#  232085493,
#  349911018,
#  349965325,
#  300742546,
#  293484138,
#  349910950,
#  349965171,
#  262577770,
#  30313695,
#  281631624,
#  350025635,
#  737153831,
#  375035513,
#  219212548,
#  309853217,
#  143855289,
#  382520171,
#  300514075,
#  350095993,
#  267047408,
#  141827133,
#  410354921,
#  270298631,
#  349833875,
#  267549665,
#  350027848,
#  358457398,
#  152251163,
#  350095330,
#  232085492,
#  350143905,
#  403282732,
#  410212440,
#  206538007,
#  206538005,
#  206535873,
#  206439944,
#  300704696,
#  300514556,
#  300512530,
#  266582162,
#  309859894,
#  206470724,
#  206499063,
#  349059129,
#  1992188726,
#  350025669,
#  281631546,
#  269741823,
#  290079005,
#  300561305,
#  161155151,
#  393891001,
#  201248950,
#  281631415,
#  278825952,
#  25226886,
#  349155251,
#  141526909,
#  261091441,
#  349910930,
#  53950776,
#  299835005,
#  349369521,
#  270558340,
#  265591866,
#  232081766,
#  350212591,
#  91450620,
#  206561223,
#  33834250,
#  262577726,
#  262576832,
#  350027811,
#  79225655,
#  364392985,
#  141268471,
#  91430459,
#  281631434,
#  271643372,
#  281727619,
#  300447602,
#  300561545,
#  231625810,
#  281631636,
#  349158366,
#  300514605,
#  389327838,
#  300705203,
#  349158387,
#  262578045,
#  309853269,
#  220388573,
#  453102164,
#  300742562,
#  281632634,
#  349833816,
#  220388574,
#  281631347,
#  300704806,
#  281631841,
#  441382263,
#  349910900,
#  147131974,
#  301941119,
#  206538011,
#  309714109,
#  31796120,
#  650263134,
#  325373788,
#  38845898,
#  238201559,
#  309860008,
#  350144384,
#  350093805,
#  281631682,
#  364392354,
#  238188417,
#  281633723,
#  350096037,
#  300705144,
#  211403907,
#  206487342,
#  350095460,
#  281631681,
#  262705073,
#  38906722,
#  300514581,
#  349965499,
#  421952284,
#  309853295,
#  29282091,
#  419745002,
#  309853503,
#  300742501,
#  349910947,
#  350145426,
#  391947238,
#  300561565,
#  349911001,
#  349788565,
#  300513047,
#  234518098,
#  143821436,
#  29345395,
#  206505572,
#  382435933,
#  300512849,
#  262705163,
#  350095856,
#  262608667,
#  53953961,
#  39069184,
#  349910940,
#  53951977,
#  91448148,
#  350095895,
#  394341018,
#  300445175,
#  349833924,
#  350144232,
#  262705171,
#  183306014,
#  349910827,
#  382435996,
#  262577485,
#  281631627,
#  272088299,
#  350145221,
#  300651329,
#  300562620,
#  350144116,
#  300514441,
#  29345396,
#  25229579,
#  309860025,
#  206408323,
#  281633646,
#  393890981,
#  309146895,
#  141436274,
#  349911023,
#  364392202,
#  349833299,
#  300562439,
#  262576891,
#  206439940,
#  349305022,
#  272126076,
#  393491149,
#  126583415,
#  140068218,
#  281631393,
#  234505869,
#  281631529,
#  350095500,
#  348761381,
#  349910972,
#  141473335,
#  650065056,
#  348960729,
#  270270809,
#  270220093,
#  270099653,
#  53951994,
#  309714129,
#  350095780,
#  262577516,
#  53950793,
#  92566356,
#  300514483,
#  220516213,
#  350144336,
#  309853266,
#  270250531,
#  441382252,
#  349787133,
#  281633721,
#  300445152,
#  309853072,
#  350145095,
#  349833511,
#  31602633,
#  309853376,
#  300514047,
#  206487579,
#  301941138,
#  300562449,
#  364392187,
#  309859835,
#  349833820,
#  382435997,
#  206535822,
#  389049236,
#  421952815,
#  300562608,
#  53954028,
#  53975108,
#  206439680,
#  206537971,
#  206542964,
#  197766143,
#  2026828876,
#  262705128,
#  10001514175,
#  350093760,
#  431481356,
#  167125054,
#  262577762,
#  350095855,
#  309853154,
#  300561340,
#  267091832,
#  270220087,
#  350146222,
#  421952823,
#  300514592,
#  300561487,
#  350144236,
#  300514325,
#  309257557,
#  765468565,
#  261136311,
#  300747190,
#  267091830,
#  300447536,
#  349965367,
#  350143140,
#  364392181,
#  350144152,
#  392814184,
#  309853147,
#  281631307,
#  300651962,
#  314864553,
#  281632880,
#  149351413,
#  79357088,
#  234333403,
#  300325562,
#  206470206,
#  234333402,
#  287436796,
#  206498845,
#  309859743,
#  349965220,
#  261724521,
#  206537976,
#  393890985,
#  139148070,
#  349833300,
#  79491024,
#  219342229,
#  349057602,
#  349965523,
#  300513989,
#  349833868,
#  270166247,
#  25299732,
#  270251139,
#  281632798,
#  349158360,
#  350026480,
#  306511396,
#  349787264,
#  364393522,
#  349787295,
#  206535816,
#  281631725,
#  141606986,
#  350933533,
#  235015153,
#  349833505,
#  325280301,
#  300746847,
#  309713753,
#  389327832,
#  25166623,
#  25230276,
#  206498847,
#  126873196,
#  349910828,
#  350146132,
#  289918855,
#  300561284,
#  206400412,
#  309559631,
#  349478464,
#  309714046,
#  300514098,
#  281633596,
#  281631397,
#  394517166,
#  349375609,
#  394517163,
#  281631654,
#  79304240,
#  79173870,
#  89018908,
#  349910812,
#  389441485,
#  300562417,
#  262616055,
#  30274968,
#  300514664,
#  394517162,
#  350142937,
#  270250610,
#  270099627,
#  301937199,
#  206439674,
#  309853418,
#  2028853723,
#  281594406,
#  25357667,
#  206439669,
#  25285382,
#  421952853,
#  270299571,
#  38944151,
#  349834078,
#  309853516,
#  143854596,
#  10000042429,
#  281631496,
#  349195462,
#  206505569,
#  364393462,
#  349833405,
#  211379272,
#  206505568,
#  206498875,
#  393891128,
#  206462011,
#  234494315,
#  290076699,
#  300512811,
#  309853587,
#  302029070,
#  300707137,
#  350027797,
#  300382066,
#  53939876,
#  25357646,
#  391902612,
#  300704584,
#  25300837,
#  364392270,
#  206506890,
#  300707139,
#  394355804,
#  79357091,
#  206481790,
#  350026541,
#  270101737,
#  206505567,
#  270251052,
#  300509150,
#  300562461,
#  25357654,
#  300509151,
#  281631540,
#  300443903,
#  300561510,
#  350026269,
#  77368857,
#  38843984,
#  152830351,
#  441041386,
#  10000584649,
#  309852761,
#  301941136,
#  309298260,
#  394006752,
#  300651987,
#  300651510,
#  349375597,
#  300513021,
#  425826291,
#  349910788,
#  421950654,
#  300562201,
#  281632496,
#  350095990,
#  53975731,
#  53895732,
#  206436399,
#  300651966,
#  300561406,
#  350095723,
#  25302394,
#  309779275,
#  261137705,
#  300745705,
#  ...]

# %% [markdown]
# ---

# %%
sec1 = pd.read_csv('Sector1/sect1predandprob.csv', index_col=0)

# %%
eblist = sec1[sec1['probone'] > 0.5]
eblist
# Out:
#            probzero   probone  pred
# 140608211  0.000000  1.000000     1
# 231791552  0.000000  1.000000     1
# 300740040  0.000000  1.000000     1
# 181052118  0.000000  1.000000     1
# 38811805   0.000000  1.000000     1
# ...             ...       ...   ...
# 425064789  0.498000  0.502000     1
# 212255303  0.498000  0.502000     1
# 269883697  0.499000  0.501000     1
# 55274131   0.499000  0.501000     1
# 309860772  0.499667  0.500333     1
#
# [4824 rows x 3 columns]

# %%
values = sec1.index.values
ref = pd.read_csv(data_dir+f"sector1lookup.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_22968/3493509113.py in <module>
#       1 values = sec1.index.values
# ----> 2 ref = pd.read_csv(data_dir+f"sector1lookup.csv")
#
# /opt/conda/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/disks/lcs/tess-goddard-lcs/sector1lookup.csv'

# %%
values
# Out:
# array([140608211, 231791552, 300740040, ..., 404808101, 284196526,
#        255567371])

# %%
tics = eblist.index.values
len(tics)
# Out:
# 4824

# %%
tics
# Out:
# array([140608211, 231791552, 300740040, ..., 269883697,  55274131,
#        309860772])

# %%
ebvals = eblist[eblist['probone'] == 1].index.values
ebvals
# Out:
# array([ 140608211,  231791552,  300740040,  181052118,   38811805,
#         303909865,  126605150,  270203709,  204497617,  307364443,
#         117544914,   89018905,  349835374,  316852879,   33715938,
#         316937318,  126945917,  306573146,  370239669,  126944778,
#         273550448,   39017668,  220388567,  290495367,  327939046,
#         177236393, 2026930048,  306665786,   31798977,  238891804,
#         232087348,  231093356,  278666918,  219170666,  261265716,
#          33734376,  267091837,  141866705,   89043105,   92259410,
#         425935688,  294671852,  220491219,  389021724,  117544922,
#         306900745,  410354938,  302751961,  300014528,  270174474,
#         201256776,  181886413,  355545390,  234524824,  231714659,
#         234285429,  219335483,  177164595,  389020350,  389020349,
#          30266257,  260503860,  309781192,  734588359,  300013254,
#         167750920,  314887863,  141268467,  300657354,  219159872,
#         277773589,  167651110,  355446601,  382627633,  126945904,
#         126945919,  150389733,   33862174,  150390197,  394700186,
#         150361911,  260541900,  382627629,  140761918,  184134559,
#         452357557,  349059354,  176933974,  300654002,  340459872,
#         350443417,   30266262,  350520980,  410354930,   25226885,
#         389476160,  277103007,  261746657,  234509214,   31636377,
#         270582604,  253912623,  260608573,   91450443,  290547046,
#         426031808,  181886412,  350336454,  441085223,  326442531,
#         279324151,  350145806,  140997887,  126785811,  409136916,
#         349966338,  307087198,  309472288,  126945918,  139265588,
#         147201138,  270204401,  232085494,   79181218,  307364441,
#         350622185,  349575587,  181879098,  737425239,  139453166,
#          33715940,  197979841,  219338651,  181879094,  302753894,
#         369180187,  121469576,  176982334,  441021825,  126803650,
#         389020348,  406279367,  301193954,  309472204,  139841210,
#         238891802,  302300783,  441080077,  278992257,  262704328,
#         260046636,  306630842,  394731512,  389528590,  126945913,
#         382101519,  358512352,  231712591,  115188534,  370243555,
#         307364426,  201293349,  306823710,   29753242,   25358644,
#         319290692,  266996790,   38762229,  231712592,   60647930,
#         389021723,  261677822,  167724932,  167724935,   55498363,
#          30266241,  201256771,  318606776,  271811068,  231791524,
#         441032606,  234346466,   33834253,  139699256,  260161144,
#         388198039, 2027167502,  393948907,  319290696,  161313139,
#         271901807,  289951325,  147201134,  453079616,  294206969,
#         300324638,  350145355,   91369561,  214367709,  260795041,
#         278703629,   44623916,  425865607,  261525123,  273550444,
#         300652458,  231665173, 2026841336,  270366148,  382629507,
#         167304040,  197980089,   79424812,  197979845,   31672006,
#          29286513,  294750649,  370239670,  373843394,  115177383,
#         309549613,  349480514,  358510297,  289952556,   99411125,
#         149040151,  348762908,  327937353,  348762899,  281814851,
#         300740195,  206363145,  409856414,  259720528,  141413795,
#         300162041,  144462697,  269939837,  181043969,  229060127,
#         141709240,  280053053,  349406253,  734588360,  259962026,
#         271638035,  306630840,  349677586,  149629043,  167250523,
#         231830630,  350155186,  140596438,  141413799,  234294638,
#         394242723,  388181972,  237905903,  260161142,  139355704,
#         349678280,  144219348,  141709132,  410252684,  300034498,
#         141213462,  219155476,  392814185,  278776988,  139347829,
#         299779869,   31869094,  737425238,  161167795,  141122196,
#         139754969,  309144265,  139699260,  287436782, 2027167504,
#        2027112725,  277941240,  220491218,   52154495,  300140005,
#         309256410,  382199764,  734511288,  206462118,  302753893,
#         261543495,  141709133,  302751916,  167815131,  358336077,
#         375036635,  441400622,  149541326,  392792586,  259719568,
#         231814930,  309403898,  404806381,  260654689,   79424807,
#         410446243,  177387851,  279475555,  184134558,  234524826,
#         388198040,  309256411,  300091984,  316976100,  139720025,
#         139091411,  270275805,  260271338,  139700944,  349575582,
#          60646278,  279616049,  279475551,  234346463,   29475978,
#         349522140,  261204832,  114948643,  231269538,  290547040,
#         270535918,   55652785,  260950407,  349641813,   33734375,
#         141122198,   25154836])

# %%
refebs = ref.loc[ref['TIC_ID'].isin(ebvals)]
files = data_dir + refebs.Filename.values
filepath = files[0]

# %%
#100%ebs
lcc = loaders.LightCurveCollection(refebs.Sector.values,
                                   refebs.Camera.values,
                                   files,
                                   False
                            )
lcc.useCpus = 8
lcc.load_all_lcs()

lcs = lcc.lcs

# %%
import matplotlib.pyplot as plt

from matplotlib.backends.backend_pdf import PdfPages

# %%
with PdfPages(f"Sector1/100%ebs.pdf") as pdf:
    plt.cla()
    for i in range(len(ebvals)):
        lcs[i].scatter()
        pdf.savefig()
        plt.close();
plt.close()

# %%
#90%-100%ebs
ebvals = eblist[eblist['probone'] > 0.9]
ebvals = ebvals[ebvals['probone'] < 1].index.values
refebs = ref.loc[ref['TIC_ID'].isin(ebvals)]
files = data_dir + refebs.Filename.values
filepath = files[0]
len(ebvals)
# Out:
# 1152

# %%
lcc = loaders.LightCurveCollection(refebs.Sector.values,
                                   refebs.Camera.values,
                                   files,
                                   False
                            )
lcc.useCpus = 8
lcc.load_all_lcs()

lcs = lcc.lcs

# %%
import matplotlib.pyplot as plt

from matplotlib.backends.backend_pdf import PdfPages

with PdfPages(f"Sector1/90-100%ebs.pdf") as pdf:
    plt.cla()
    for i in range(len(ebvals)):
        lcs[i].scatter()
        pdf.savefig()
        plt.close();
plt.close()

# %% [markdown]
# ____
# classified as ebs (50%>)
# <br>
# Finding and removing closest stars, then printing the remaining light curves into a pdf file to visually examine

# %%
stars = ref.TIC_ID.isin(tics)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_22968/3943226802.py in <module>
# ----> 1 stars = ref.TIC_ID.isin(tics)
#
# NameError: name 'ref' is not defined

# %%
#ref7335.csv - csv file for all ebs found
ref[stars].to_csv(f"Sector{sector}/refSect{sector}.csv")

# %%
closestarslist = []
for i in range(len(tics)):
    rastar = ref[stars].RA.values[i]
    decstar = ref[stars].Dec.values[i]
    dist = np.sqrt(((rastar-ref[stars].RA.values)*(np.cos(decstar)))**2+(decstar-ref[stars].Dec.values)**2)
    closestars = np.where((dist < 0.1) & (dist != 0))
    closestarslist.append(closestars)

# %%
closestarslist
# Out:
# [(array([], dtype=int64),),
#  (array([ 350, 1513, 2081]),),
#  (array([], dtype=int64),),
#  (array([691]),),
#  (array([1600]),),
#  (array([ 359,  696, 1605]),),
#  (array([355]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([ 731, 1664]),),
#  (array([], dtype=int64),),
#  (array([1679]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([1720, 1721, 1722]),),
#  (array([], dtype=int64),),
#  (array([1753]),),
#  (array([ 375, 1755, 1788]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([ 793,  794, 4792]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([2023]),),
#  (array([2043]),),
#  (array([], dtype=int64),),
#  (array([ 425, 2050]),),
#  (array([], dtype=int64),),
#  (array([877]),),
#  (array([], dtype=int64),),
#  (array([2069]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([455]),),
#  (array([38]),),
#  (array([37]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([ 127, 1519, 4809]),),
#  (array([956, 957]),),
#  (array([785]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([961]),),
#  (array([2322]),),
#  (array([2232, 2233, 2313, 2326]),),
#  (array([989, 996]),),
#  (array([409, 998]),),
#  (array([2487]),),
#  (array([1034, 1035, 1041, 2486, 2508, 2512, 2513, 2514, 2619, 2620, 2624,
#          2625, 2626, 2627, 2628, 2713, 2719, 4808]),),
#  (array([], dtype=int64),),
#  (array([504]),),
#  (array([512]),),
#  (array([], dtype=int64),),
#  (array([1128, 2790]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([1174, 3428]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([ 542, 3465, 3472]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([553]),),
#  (array([3524]),),
#  (array([], dtype=int64),),
#  (array([ 135,  449, 2187, 2188, 3537, 4796, 4815]),),
#  (array([ 136, 2237, 4806]),),
#  (array([ 138, 4816]),),
#  (array([], dtype=int64),),
#  (array([3568]),),
#  (array([3572]),),
#  (array([], dtype=int64),),
#  (array([1303, 1304, 3831]),),
#  (array([], dtype=int64),),
#  (array([3519, 3520]),),
#  (array([3841]),),
#  (array([3844]),),
#  (array([1317]),),
#  (array([4817]),),
#  (array([], dtype=int64),),
#  (array([ 303, 2435]),),
#  (array([ 307, 1205, 3513]),),
#  (array([], dtype=int64),),
#  (array([1527, 4233]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([1758, 3589]),),
#  (array([673]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([740, 741]),),
#  (array([], dtype=int64),),
#  (array([188]),),
#  (array([ 242,  331,  445,  446,  665, 1505, 1696, 1698, 2176]),),
#  (array([], dtype=int64),),
#  (array([ 395,  800, 1796, 2182, 2217, 3550, 3552, 3560]),),
#  (array([822]),),
#  (array([132, 208]),),
#  (array([], dtype=int64),),
#  (array([837]),),
#  (array([], dtype=int64),),
#  (array([216, 848]),),
#  (array([1944]),),
#  (array([2038, 2049]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([ 283,  284, 3573]),),
#  (array([472]),),
#  (array([], dtype=int64),),
#  (array([2546]),),
#  (array([  42, 1519, 4809]),),
#  (array([], dtype=int64),),
#  (array([2895, 2908, 2909, 2910, 2990]),),
#  (array([1139, 3057]),),
#  (array([1204]),),
#  (array([104, 208]),),
#  (array([3518, 4814]),),
#  (array([1209, 3527, 3528]),),
#  (array([  72,  449, 2187, 2188, 3537, 4796, 4815]),),
#  (array([  73, 2237, 4806]),),
#  (array([564, 565]),),
#  (array([  74, 4816]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([687]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([ 299, 3835]),),
#  (array([300, 569]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([ 306, 3871]),),
#  (array([], dtype=int64),),
#  (array([1517, 1690, 1694, 1697]),),
#  (array([], dtype=int64),),
#  (array([1370, 1376]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([4414, 4822]),),
#  (array([], dtype=int64),),
#  (array([ 632, 4441]),),
#  (array([ 642, 1437, 1453, 4452]),),
#  (array([ 325, 1454]),),
#  (array([ 546, 4614]),),
#  (array([], dtype=int64),),
#  (array([1503, 4617]),),
#  (array([333]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([1574]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([2075]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([1627]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([187]),),
#  (array([733, 734, 735]),),
#  (array([185]),),
#  (array([99]),),
#  (array([ 742, 1686]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([ 759,  760, 1752]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([775]),),
#  (array([], dtype=int64),),
#  (array([779]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([392]),),
#  (array([3558]),),
#  (array([], dtype=int64),),
#  (array([398]),),
#  (array([1834]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([104, 132]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([842, 845]),),
#  (array([410, 411]),),
#  (array([], dtype=int64),),
#  (array([108, 848]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([878]),),
#  (array([2063]),),
#  (array([880]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([230]),),
#  (array([229]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([236]),),
#  (array([235]),),
#  (array([2086]),),
#  (array([ 439, 2089]),),
#  (array([ 559,  561, 2183, 2189]),),
#  (array([ 241,  242,  331,  445,  446,  665, 1215, 1505, 2176]),),
#  (array([ 240,  242,  331,  444,  445,  446, 1215, 1505, 2176]),),
#  (array([ 100,  240,  241,  331,  445,  446,  665, 1215, 1505, 2176]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([2331]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([ 253, 3853]),),
#  (array([ 252, 3853]),),
#  (array([1329]),),
#  (array([ 414,  485,  487,  488,  489,  490,  491,  644, 1005, 1006, 1007,
#          1008, 1017, 1028, 1032, 1033, 1047, 1766, 2478, 2481, 2536, 2538,
#          2582, 2589, 2593, 2594, 2595, 2601, 2602, 4516]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([ 511, 1104]),),
#  (array([], dtype=int64),),
#  (array([3018]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([2955]),),
#  (array([537]),),
#  (array([], dtype=int64),),
#  (array([539]),),
#  (array([], dtype=int64),),
#  (array([1378, 1551, 1553, 1555, 1556, 3974, 3975, 3979, 4063, 4071, 4820]),),
#  (array([3487]),),
#  (array([ 544, 1188]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([2334, 2335]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([1811]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([ 123,  284, 3573]),),
#  (array([ 123,  283, 3573]),),
#  (array([], dtype=int64),),
#  (array([ 570, 3606]),),
#  (array([], dtype=int64),),
#  (array([328]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([1250, 3621]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([ 582, 1266, 1271, 1272, 1293, 1294, 3679, 3685, 3696, 3704, 3708]),),
#  (array([ 144, 3835]),),
#  (array([145, 569]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([  87, 2435]),),
#  (array([ 600, 3860]),),
#  (array([3867, 3868]),),
#  (array([ 148, 3871]),),
#  (array([  88, 1205, 3513]),),
#  (array([1338]),),
#  (array([], dtype=int64),),
#  (array([3906]),),
#  (array([1345]),),
#  (array([], dtype=int64),),
#  (array([2400]),),
#  (array([ 339,  619,  676,  677,  678, 1552, 1554, 4092]),),
#  (array([3586]),),
#  (array([4229]),),
#  (array([1404, 4230, 4790]),),
#  (array([4315, 4319, 4321]),),
#  (array([], dtype=int64),),
#  (array([4417]),),
#  (array([ 323,  633,  636, 1431, 1432, 1433, 1436, 1439, 4448, 4449, 4451,
#          4486]),),
#  (array([ 641, 1132, 1274, 1291, 1295, 1435, 1438, 1447, 1448, 1449, 1452,
#          3705, 3775, 3776, 3777, 4453, 4455, 4456, 4458, 4459, 4485, 4493,
#          4494, 4495]),),
#  (array([ 321,  633,  636, 1431, 1432, 1433, 1436, 1439, 4448, 4451, 4486]),),
#  (array([], dtype=int64),),
#  (array([ 160, 1454]),),
#  (array([], dtype=int64),),
#  (array([4473, 4501, 4505]),),
#  (array([288]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([ 100,  240,  241,  242,  445,  446,  665, 1505, 1696, 1698, 2176]),),
#  (array([], dtype=int64),),
#  (array([164]),),
#  (array([], dtype=int64),),
#  (array([ 659, 1405, 1504, 4753]),),
#  (array([], dtype=int64),),
#  (array([ 617,  674, 1537, 1538, 1545, 1549, 4056, 4060, 4062]),),
#  (array([ 675, 1378, 1379, 1540, 1543, 1550, 1555, 3975, 3979, 4055, 4063,
#          4071, 4073]),),
#  (array([ 314,  619,  676,  677,  678, 1552, 1554, 1557, 4092]),),
#  (array([ 676,  677,  678, 1551, 1552, 1553, 1556, 1557]),),
#  (array([], dtype=int64),),
#  (array([682]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([   1, 1513, 2081]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([420]),),
#  (array([6]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([   5,  696, 1605]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([1676]),),
#  (array([], dtype=int64),),
#  (array([787]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([1520, 2745, 2747, 2749]),),
#  (array([1516, 1738, 2172, 2173]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([  19, 1788]),),
#  (array([1754]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([1778, 1780]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([2342]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([1578]),),
#  (array([1762]),),
#  (array([], dtype=int64),),
#  (array([200]),),
#  (array([1748]),),
#  (array([1794]),),
#  (array([ 102,  800, 1796, 2217, 3548, 3552, 3560]),),
#  (array([ 803,  809, 1808, 2213, 2214, 3541]),),
#  (array([], dtype=int64),),
#  (array([203]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([ 52, 998]),),
#  (array([214, 411]),),
#  (array([214, 410]),),
#  (array([843]),),
#  (array([], dtype=int64),),
#  (array([ 255,  485,  487,  488,  489,  490,  491,  644,  847, 1005, 1006,
#          1007, 1017, 1032, 1033, 2481, 2538, 2582, 2593, 2594, 2595, 2601,
#          2602, 4516, 4517]),),
#  (array([], dtype=int64),),
#  (array([1883]),),
#  (array([], dtype=int64),),
#  (array([ 857, 1173]),),
#  (array([2011]),),
#  (array([354]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([  29, 2050]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([2076]),),
#  (array([], dtype=int64),),
#  (array([891]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([896]),),
#  (array([ 238, 2089]),),
#  (array([ 898, 2090, 2091]),),
#  (array([ 903, 2095, 2096, 2097, 2114, 2115, 2144, 4628, 4757, 4758, 4764,
#          4771]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([ 917, 1215, 2184]),),
#  (array([ 100,  240,  241,  242,  331,  446,  665, 1215, 1505, 2176]),),
#  (array([ 100,  240,  241,  242,  331,  445,  665, 1215, 1505, 2176]),),
#  (array([ 918, 2171, 2183, 2185, 3543]),),
#  (array([924]),),
#  (array([  72,  135, 2187, 2188, 4796, 4815]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([36]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([2286, 4434]),),
#  (array([707, 708]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([2318]),),
#  (array([2323]),),
#  (array([], dtype=int64),),
#  (array([124]),),
#  (array([ 990, 2336]),),
#  (array([], dtype=int64),),
#  (array([2357]),),
#  (array([ 981, 2371, 2386, 2387, 2388]),),
#  (array([2420]),),
#  (array([987]),),
#  (array([ 995, 2424]),),
#  (array([], dtype=int64),),
#  (array([1004, 2464, 2468, 2469]),),
#  (array([], dtype=int64),),
#  (array([ 493,  494, 1010, 1038, 1042, 1053, 1054, 1765, 2484, 2489, 2492,
#          2511, 2531, 2541, 2542, 2562, 2619, 2628, 2672, 2680, 2685, 2705,
#          2706, 2709, 2720, 4528, 4539, 4545]),),
#  (array([ 495,  496,  497,  714, 1026, 1027, 1058, 1059, 2529, 2537, 2574,
#          2616, 2736, 2737]),),
#  (array([ 255,  414,  487,  488,  489,  490,  491,  644,  847, 1005, 1006,
#          1007, 1008, 1017, 1028, 1032, 1033, 1047, 1766, 2478, 2481, 2536,
#          2538, 2582, 2589, 2593, 2594, 2595, 2601, 2602, 4516, 4517]),),
#  (array([2591, 2596]),),
#  (array([ 255,  414,  485,  488,  489,  490,  491,  644,  847, 1005, 1006,
#          1007, 1008, 1017, 1028, 1032, 1033, 2478, 2481, 2536, 2538, 2582,
#          2593, 2594, 2595, 2601, 2602, 4516, 4517]),),
#  (array([ 255,  414,  485,  487,  489,  490,  491,  644,  847, 1005, 1006,
#          1007, 1008, 1017, 1028, 1032, 1033, 1047, 1766, 2478, 2481, 2536,
#          2538, 2582, 2593, 2594, 2595, 2601, 2602, 4516, 4517]),),
#  (array([ 255,  414,  485,  487,  488,  490,  491,  644,  847, 1005, 1006,
#          1007, 1008, 1017, 1028, 1032, 1033, 1047, 1766, 2478, 2481, 2536,
#          2538, 2582, 2589, 2593, 2594, 2595, 2601, 2602, 4516, 4517]),),
#  (array([ 255,  414,  485,  487,  488,  489,  491,  644, 1005, 1006, 1007,
#          1008, 1017, 1028, 1032, 1033, 1047, 1766, 2478, 2481, 2536, 2538,
#          2582, 2589, 2593, 2594, 2595, 2601, 2602, 4516]),),
#  (array([ 255,  485,  487,  488,  489,  490,  644, 1005, 1006, 1008, 1017,
#          1028, 1032, 1033, 1047, 1766, 2478, 2481, 2536, 2538, 2582, 2589,
#          2593, 2594, 2595, 2602, 4516]),),
#  (array([1036, 2605, 2606, 2607, 2608, 2609, 2633, 2677, 2683, 2695, 2697,
#          2726]),),
#  (array([ 483,  494, 1038, 1041, 1042, 1053, 1054, 1622, 1765, 2484, 2511,
#          2512, 2514, 2531, 2541, 2542, 2562, 2619, 2620, 2626, 2627, 2628,
#          2672, 2680, 2685, 2719, 2720, 4539, 4545]),),
#  (array([  54,  483,  486,  493, 1034, 1038, 1041, 1042, 1054, 1622, 2508,
#          2511, 2512, 2513, 2514, 2531, 2542, 2544, 2562, 2591, 2596, 2619,
#          2620, 2624, 2625, 2626, 2627, 2628, 2674, 2680, 2713, 2719, 2720,
#          2733, 4545, 4808]),),
#  (array([ 484,  496,  497,  714, 1026, 1027, 1058, 1059, 2529, 2537, 2574,
#          2616, 2736, 2737, 4518]),),
#  (array([ 484,  495,  497,  714, 1026, 1027, 1058, 1059, 2529, 2537, 2574,
#          2616, 2736, 2737, 4518]),),
#  (array([ 484,  495,  496,  714, 1026, 1027, 1058, 1059, 2529, 2537, 2574,
#          2616, 2736, 2737, 4518]),),
#  (array([2495, 2502]),),
#  (array([], dtype=int64),),
#  (array([1523, 2482, 2559]),),
#  (array([], dtype=int64),),
#  (array([2768, 2778, 2826, 2844]),),
#  (array([2985]),),
#  (array([56]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([1073, 1093, 1099, 2905, 4103]),),
#  (array([], dtype=int64),),
#  (array([ 514, 1130]),),
#  (array([ 258, 1104]),),
#  (array([57]),),
#  (array([], dtype=int64),),
#  (array([ 510, 1130]),),
#  (array([], dtype=int64),),
#  (array([ 517, 1108, 1109, 1110, 2973, 2977, 2980, 2981]),),
#  (array([ 516, 1108, 1109, 1110, 2973, 2977, 2980, 2981]),),
#  (array([4167]),),
#  (array([], dtype=int64),),
#  (array([3005]),),
#  (array([], dtype=int64),),
#  (array([1120, 3016, 3020]),),
#  (array([1075, 1120, 1121, 1124]),),
#  (array([], dtype=int64),),
#  (array([3014]),),
#  (array([], dtype=int64),),
#  (array([1134, 1879, 3042, 3043, 3044, 3045, 3053]),),
#  (array([1135]),),
#  (array([ 536, 1085, 1161, 1164, 1166, 1167, 2798, 2803, 2869, 2871, 2872,
#          2875, 2876, 3339, 3344, 3356, 3359, 3368]),),
#  (array([3404, 4811]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([1157]),),
#  (array([], dtype=int64),),
#  (array([ 528, 1134, 1135, 1138, 1144, 1145, 1852, 3045, 3052, 3058, 3062,
#          3092, 3099, 3114, 3117, 3138, 3160, 3180, 3189, 3190, 3191, 3197,
#          3243, 3270, 3310, 3323, 3407, 4239, 4240, 4269, 4294, 4296, 4333,
#          4335, 4338, 4339, 4340]),),
#  (array([ 529, 1085, 1161, 1164, 1166, 1167, 1847, 2869, 2871, 2875, 2876,
#          3161, 3162, 3339, 3344, 3356, 3359, 3368, 4007]),),
#  (array([265]),),
#  (array([], dtype=int64),),
#  (array([267]),),
#  (array([], dtype=int64),),
#  (array([3469]),),
#  (array([  66, 3465, 3472]),),
#  (array([], dtype=int64),),
#  (array([ 271, 1188]),),
#  (array([], dtype=int64),),
#  (array([ 161, 4614]),),
#  (array([3501, 3514, 3515, 3516]),),
#  (array([1201, 2971, 3511]),),
#  (array([], dtype=int64),),
#  (array([3521]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([69]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([ 799, 1799, 1804, 2171, 2184]),),
#  (array([ 802, 1803, 3555, 3556]),),
#  (array([ 239,  561, 2183, 2189]),),
#  (array([], dtype=int64),),
#  (array([ 239,  559, 2183, 2189]),),
#  (array([563]),),
#  (array([562]),),
#  (array([137, 565]),),
#  (array([137, 564]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([145, 300]),),
#  (array([ 286, 3606]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([1249, 3616]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([3643]),),
#  (array([ 581, 3647]),),
#  (array([ 580, 1256, 1285, 1286, 1287, 3647]),),
#  (array([ 298, 1132, 1260, 1266, 1267, 1268, 1271, 1272, 1274, 1291, 1294,
#          1295, 3679, 3685, 3696, 3704, 3705, 3708, 3775, 3776, 3777]),),
#  (array([3700, 3701, 3712]),),
#  (array([], dtype=int64),),
#  (array([609]),),
#  (array([3699]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([ 846, 1278, 3721, 3738, 3740]),),
#  (array([], dtype=int64),),
#  (array([3764]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([3832]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([3849]),),
#  (array([ 304, 3860]),),
#  (array([1326]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([1236, 1398]),),
#  (array([], dtype=int64),),
#  (array([ 975,  990, 1330, 1332, 2336, 2370]),),
#  (array([ 993, 2404]),),
#  (array([585]),),
#  (array([1348, 1486, 3888, 3891]),),
#  (array([1351, 1352, 3927, 3928]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([1374, 4821]),),
#  (array([], dtype=int64),),
#  (array([ 337,  674, 1537, 1538, 1549, 4060, 4062]),),
#  (array([4092, 4093]),),
#  (array([ 314,  339,  676,  677,  678, 1552, 1554, 4092]),),
#  (array([1391, 4049, 4156, 4157]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([4343]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([3068, 3266]),),
#  (array([], dtype=int64),),
#  (array([1428]),),
#  (array([], dtype=int64),),
#  (array([ 158, 4441]),),
#  (array([ 321,  323,  636,  642, 1436, 1439, 4448, 4451, 4452]),),
#  (array([651]),),
#  (array([1429, 1435, 1446, 4449, 4450]),),
#  (array([ 321,  323,  633,  642, 1436, 1439, 4448, 4449, 4451]),),
#  (array([ 641, 1440, 1449, 1452, 4453, 4454, 4455, 4456, 4457, 4458, 4459,
#          4489, 4490]),),
#  (array([1450, 1451, 4492]),),
#  (array([1430, 4823]),),
#  (array([], dtype=int64),),
#  (array([ 322,  637, 1440, 1448, 1449, 1452, 4453, 4454, 4455, 4456, 4457,
#          4458, 4459, 4493, 4495]),),
#  (array([ 159,  633,  636, 1436, 4448]),),
#  (array([2600]),),
#  (array([ 255,  414,  485,  487,  488,  489,  490,  491,  847, 1005, 1006,
#          1007, 1017, 1028, 1032, 1033, 2481, 2536, 2538, 2582, 2593, 2594,
#          2595, 2601, 2602, 4516, 4517]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([1623, 3922, 4619]),),
#  (array([634]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([4625]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([2112, 2121, 2127, 2156]),),
#  (array([], dtype=int64),),
#  (array([ 335, 4753]),),
#  (array([ 815,  910, 1496, 1500, 1815, 4776, 4777, 4781, 4783]),),
#  (array([ 663, 1506, 1508, 1719, 1741]),),
#  (array([668, 693]),),
#  (array([ 661,  745, 1506, 1508, 1511, 1703, 1741]),),
#  (array([1515, 1719]),),
#  (array([ 100,  240,  241,  242,  331,  445,  446, 1505, 1696, 1698, 2176]),),
#  (array([2585]),),
#  (array([], dtype=int64),),
#  (array([662, 693]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([1525]),),
#  (array([], dtype=int64),),
#  (array([94]),),
#  (array([ 337,  617, 1537, 1538, 1545, 1549, 4060, 4062]),),
#  (array([ 338, 1364, 1379, 1539, 1540, 1541, 1542, 1543, 1546, 1550, 4055,
#          4057, 4059, 4073]),),
#  (array([ 314,  339,  340,  619,  677,  678, 1552, 1554, 1557]),),
#  (array([ 314,  339,  340,  619,  676,  678, 1551, 1552, 1554, 1557]),),
#  (array([ 314,  339,  340,  619,  676,  677, 1551, 1552, 1554, 1557]),),
#  (array([ 680, 1558, 1559, 1565, 1566, 1567, 1569]),),
#  (array([ 679, 1558, 1559, 1562, 1565, 1566, 1567, 1569]),),
#  (array([], dtype=int64),),
#  (array([342]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([141]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([3]),),
#  (array([], dtype=int64),),
#  (array([662, 668]),),
#  (array([], dtype=int64),),
#  (array([178]),),
#  (array([   5,  359, 1605]),),
#  (array([], dtype=int64),),
#  (array([1606]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([1611]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([1615]),),
#  (array([463, 708]),),
#  (array([463, 707]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([1616]),),
#  (array([1619, 2634]),),
#  (array([ 484,  495,  496,  497, 1026, 1027, 1058, 1059, 2529, 2537, 2574,
#          2616, 2736, 2737, 4518]),),
#  (array([], dtype=int64),),
#  (array([1628, 1630]),),
#  (array([], dtype=int64),),
#  (array([1632, 1633]),),
#  (array([], dtype=int64),),
#  (array([1634, 1635]),),
#  (array([], dtype=int64),),
#  (array([1637, 1638, 1821]),),
#  (array([ 730, 1172, 1674, 3455, 3457]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([1660]),),
#  (array([1646, 1654, 1655]),),
#  (array([], dtype=int64),),
#  (array([1639, 1640, 1658, 1661, 3447, 3449]),),
#  (array([ 723, 1172, 1674, 3455, 3457]),),
#  (array([  10, 1664]),),
#  (array([], dtype=int64),),
#  (array([186, 734, 735]),),
#  (array([186, 733, 735]),),
#  (array([186, 733, 734]),),
#  (array([1680]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([ 97, 741]),),
#  (array([ 97, 740]),),
#  (array([], dtype=int64),),
#  (array([1690, 1697, 1725]),),
#  (array([1512]),),
#  (array([ 663, 1506, 1507, 1515, 1703, 1741, 2744]),),
#  (array([1724, 1735]),),
#  (array([1699, 1700, 1705, 1713]),),
#  (array([1701, 1704, 1709, 1718, 1734, 2751]),),
#  (array([], dtype=int64),),
#  (array([797, 798]),),
#  (array([ 747, 1699, 1700, 1705, 1729, 1732]),),
#  (array([2220]),),
#  (array([1727]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([ 192,  760, 1752]),),
#  (array([ 192,  759, 1752]),),
#  (array([1749]),),
#  (array([], dtype=int64),),
#  (array([764, 765]),),
#  (array([763, 765]),),
#  (array([763, 764]),),
#  (array([1750]),),
#  (array([], dtype=int64),),
#  (array([1757]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([776]),),
#  (array([], dtype=int64),),
#  (array([774]),),
#  (array([1777]),),
#  (array([], dtype=int64),),
#  (array([197]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([44]),),
#  (array([], dtype=int64),),
#  (array([367]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([  23,  794, 4792]),),
#  (array([  23,  793, 4792]),),
#  (array([796]),),
#  (array([795]),),
#  (array([750, 798]),),
#  (array([750, 797]),),
#  (array([ 917,  918, 1797, 2171, 2184, 2185]),),
#  (array([ 102,  395, 1796, 2214, 2217, 3550, 3552, 3560]),),
#  (array([], dtype=int64),),
#  (array([ 558, 1803, 3555]),),
#  (array([ 396,  809, 1808, 2213, 2214, 3541]),),
#  (array([ 805,  947, 1217, 1807, 1810, 2222]),),
#  (array([ 804, 1807, 1810]),),
#  (array([1800]),),
#  (array([1801, 3551]),),
#  (array([ 925, 2178, 2203]),),
#  (array([ 396,  803, 1808, 2213, 3541]),),
#  (array([], dtype=int64),),
#  (array([1816]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([ 660,  910, 2148, 4776, 4777, 4781]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([103]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([ 881, 1851]),),
#  (array([1856]),),
#  (array([], dtype=int64),),
#  (array([834]),),
#  (array([833]),),
#  (array([868]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([213, 845]),),
#  (array([412]),),
#  (array([1872]),),
#  (array([213, 842]),),
#  (array([ 589, 1278, 3721, 3738, 3740]),),
#  (array([ 255,  414,  485,  487,  488,  489,  490,  644, 1006, 1007, 1032,
#          2481, 2489, 2538, 2582, 2593, 2595, 2601, 2602, 4516, 4517]),),
#  (array([108, 216]),),
#  (array([1886, 1889]),),
#  (array([], dtype=int64),),
#  (array([1892, 1899, 1916, 1995, 2013]),),
#  (array([1884, 1930, 1933, 2051, 2054, 2055, 2449]),),
#  (array([], dtype=int64),),
#  (array([1951, 1961, 1969, 1977]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([ 418, 1173]),),
#  (array([1888, 1896, 1999, 2009, 2015, 2016, 2017, 2021]),),
#  (array([1992, 1996, 1997, 1998, 2000, 2001, 2002]),),
#  (array([], dtype=int64),),
#  (array([862]),),
#  (array([861]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([2037]),),
#  (array([], dtype=int64),),
#  (array([835]),),
#  (array([4804]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([2044, 2045]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([31]),),
#  (array([223]),),
#  (array([], dtype=int64),),
#  (array([225]),),
#  (array([ 830, 1851]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([3574]),),
#  (array([2066]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([432]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([438]),),
#  (array([], dtype=int64),),
#  (array([ 440, 2090, 2091]),),
#  (array([2092]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([2111]),),
#  (array([ 441, 2095, 2096, 2097, 2114, 2115, 2144, 4628, 4757, 4758, 4764]),),
#  (array([3591, 3594]),),
#  (array([], dtype=int64),),
#  (array([2136]),),
#  (array([ 908, 1500, 2125, 2129, 2132, 2134, 2139, 2140, 2142, 4783]),),
#  (array([ 907, 1500, 2125, 2129, 2132, 2134, 2139, 2140, 2141, 2142, 3577,
#          4783]),),
#  (array([], dtype=int64),),
#  (array([ 660,  815,  911,  912,  913, 1500, 2148, 2149, 2150, 2151, 2152,
#          2154, 4776, 4777, 4781, 4783]),),
#  (array([ 910,  912,  913, 2147, 2148, 2149, 2150, 2151, 2152, 2154, 4777,
#          4781]),),
#  (array([ 910,  911,  913, 2148, 2149, 2150, 2151, 2152, 2154, 4777, 4781]),),
#  (array([ 911,  912, 2148, 2150, 2151, 2152, 2154]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([ 444,  799, 1797, 2171, 2184]),),
#  (array([ 447,  799, 1797, 2171, 2183, 2185, 3543]),),
#  (array([ 920, 2192, 2193, 2202]),),
#  (array([ 919, 2192, 2193, 2198, 2200, 2202, 3559]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([448]),),
#  (array([ 808, 1802, 2203]),),
#  (array([ 927,  928, 2218, 2219, 2220, 2221]),),
#  (array([ 926,  928, 2219, 2221]),),
#  (array([ 926,  927, 2218, 2220, 2221]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([933]),),
#  (array([932]),),
#  (array([2254, 2255]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([2264]),),
#  (array([], dtype=int64),),
#  (array([2276]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([ 804, 1217, 2215, 2222]),),
#  (array([2288, 2289, 2290, 2291, 2292, 2293, 2294, 2295, 2296, 2297, 2298,
#          2299, 2300, 2301, 2302, 2303, 2304, 2305]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([2310]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([ 958, 2317]),),
#  (array([ 43, 957]),),
#  (array([ 43, 956]),),
#  (array([ 955, 2317]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([48]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([ 967, 2340, 2341]),),
#  (array([ 966, 2340]),),
#  (array([2339, 2340, 2341]),),
#  (array([], dtype=int64),),
#  (array([ 971,  984,  985, 2343, 2350, 2395]),),
#  (array([ 970,  984,  985, 2343, 2350, 2395, 4555]),),
#  (array([2381, 2383, 2385]),),
#  (array([ 974, 1191, 1193, 2359, 4574]),),
#  (array([ 973, 1191, 1193, 2359, 4574]),),
#  (array([ 990, 2336, 2370]),),
#  (array([2352, 2373]),),
#  (array([2338, 2346, 2376, 2423]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([2356, 2378, 2379, 2396]),),
#  (array([ 476, 2371, 2386, 2387, 2388]),),
#  (array([2368]),),
#  (array([2391, 2403]),),
#  (array([ 970,  971,  985, 2350, 2395, 4555, 4557]),),
#  (array([ 970,  971,  984, 1480, 2349, 2350, 2393, 2395, 4557, 4610]),),
#  (array([], dtype=int64),),
#  (array([478]),),
#  (array([], dtype=int64),),
#  (array([ 51, 996]),),
#  (array([ 473,  975, 2336, 2370]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([ 608, 2404]),),
#  (array([], dtype=int64),),
#  (array([ 479, 2424]),),
#  (array([ 51, 989]),),
#  (array([2443]),),
#  (array([ 52, 409]),),
#  (array([3941, 3942]),),
#  ...]

# %%
closestarstics = []
for i in range (len(closestarslist)):
    tics = []
    tics.append(ref[stars].TIC_ID.values[i])
    for j in range(len(closestarslist[i][0])):
        tics.append(ref[stars].TIC_ID.values[closestarslist[i][0][j]])
    closestarstics.append(tics)

# %%
closestarstics
# Out:
# [[269762258],
#  [263074592, 263074589, 612155681, 263074593],
#  [278706358],
#  [261656371, 261656369],
#  [152825521, 152825523],
#  [139699256, 2026930048, 139699260, 139699248],
#  [139721086, 139721085],
#  [139841210],
#  [214198381],
#  [144462697],
#  [389726435, 389726434, 389726433],
#  [160036449],
#  [229057817, 229056112],
#  [204497617],
#  [441406061],
#  [152223725],
#  [25226885, 25226877, 25226886, 25244926],
#  [280052690],
#  [358457398, 299835005],
#  [141268467, 141268468, 141268471, 141268474],
#  [33862174],
#  [267263253],
#  [79403459],
#  [79225651, 79225639, 79225655, 1989169801],
#  [99465976],
#  [201176965],
#  [389476160, 389476161],
#  [261746657, 261748317],
#  [262958558],
#  [290547036, 290547040, 290547046],
#  [263078276],
#  [33715938, 33715940],
#  [303909865],
#  [271596290, 271596289],
#  [220474209],
#  [278683641],
#  [201256771, 201256776],
#  [92352621, 92352620],
#  [92352620, 92352621],
#  [441422220],
#  [89398867],
#  [147083089],
#  [206462116, 2028782097, 206462118, 2028782096],
#  [117544915, 117544922, 117544914],
#  [139148071, 139148070],
#  [139207681],
#  [91369561],
#  [44623916],
#  [144194304, 144194307],
#  [126944775, 126944778],
#  [126945917, 126945904, 126945919, 126945918, 126945913],
#  [167692429, 167692420, 765416705],
#  [410354930, 410354921, 410354938],
#  [32200310, 32200311],
#  [290131778,
#   302333528,
#   302333537,
#   302299653,
#   290129401,
#   302333514,
#   302333497,
#   302333525,
#   302333494,
#   302299663,
#   302299649,
#   302299626,
#   302299636,
#   302299642,
#   302299652,
#   302299660,
#   302335952,
#   302335967,
#   1992266045],
#  [281498280],
#  [220521199, 220521196],
#  [234491752, 234491750],
#  [38586438],
#  [55652785, 55652788, 55652781],
#  [349832824],
#  [147131974],
#  [91448148],
#  [147201138, 147201134, 147201136],
#  [117515123],
#  [121420805],
#  [89018905, 89018908, 2027112725, 89018909],
#  [126602778],
#  [141606986],
#  [197766143, 2026828876],
#  [266996791, 266996790],
#  [219308281],
#  [206505568,
#   206505567,
#   206505552,
#   206505575,
#   206505572,
#   206498877,
#   206505569,
#   206498875],
#  [260161144, 737425239, 260161142, 737425238],
#  [403153647, 403153641, 2026963422],
#  [265591866],
#  [219338651, 219338650],
#  [231714759, 231714760],
#  [54001270],
#  [220388567, 220388574, 220388573, 220388571],
#  [381857817],
#  [394006752, 394006751, 394006756],
#  [270204401, 318606776],
#  [419744996, 419745002],
#  [350443417, 350443411],
#  [350622185, 734511288],
#  [201293780],
#  [31796120, 650263134, 31796118],
#  [181043970, 181052118, 10000089372, 181043969],
#  [32000625],
#  [30313682, 30274968, 30313695],
#  [31653503],
#  [141622065],
#  [425064757, 425064789, 425064770],
#  [167304040, 167304030],
#  [393948907],
#  [389729356],
#  [89398045, 89398038, 89398039],
#  [204544746],
#  [92498019, 1992094833],
#  [206537976,
#   206538007,
#   206537981,
#   206535868,
#   206538005,
#   206535891,
#   206537983,
#   206537971,
#   206537969,
#   206535873],
#  [267093915],
#  [421952824,
#   421952839,
#   421952837,
#   421952823,
#   206406794,
#   421952845,
#   206406798,
#   421952815,
#   421952853],
#  [350954272, 350954274],
#  [201248425, 201248424, 201248423],
#  [407580995],
#  [261137705, 392011499],
#  [261724521],
#  [309143751, 309143752, 309143731],
#  [441041386, 441040934],
#  [261136311, 261136317, 261136304],
#  [269852699],
#  [129681302],
#  [314887863],
#  [389527961],
#  [114948643],
#  [33767523],
#  [300012172],
#  [441157639],
#  [115192433],
#  [260659986],
#  [260239481],
#  [266540667],
#  [403150111, 2026655087, 2026655085, 403150113],
#  [262826230, 262826232],
#  [141126559],
#  [269833439, 269833443],
#  [2028782097, 206462116, 206462118, 2028782096],
#  [235015153],
#  [349835367, 349831811, 349831802, 349831805, 349831812, 349835374],
#  [309402205, 309402209, 309402207],
#  [183981740, 183979031],
#  [201248424, 201248425, 201248423],
#  [370239670, 370239668, 370239669],
#  [197979841, 2026841336, 197980089, 197979845],
#  [206505567,
#   206505568,
#   206505552,
#   206505575,
#   206505572,
#   206498877,
#   206505569,
#   206498875],
#  [737425239, 260161144, 260161142, 737425238],
#  [389020348, 389020349, 389020350],
#  [403153641, 403153647, 2026963422],
#  [270174474],
#  [179244391],
#  [300654002, 300657354],
#  [410214468],
#  [409136916],
#  [219342231, 219342229, 219342235],
#  [267091832, 267091830, 267091837],
#  [382101519],
#  [279161495],
#  [277913200, 277913197, 277913201],
#  [327937353],
#  [206542964, 206539259, 206506524, 206537919, 206537920],
#  [309405242],
#  [309472288, 309549613, 309472204],
#  [167651110],
#  [469973582],
#  [149351413],
#  [234509221, 234509214, 234509218],
#  [61178236],
#  [211379275, 211379272, 211379274],
#  [441381645, 441355928, 441381607, 441381598, 441382348],
#  [270582609, 270582604, 270582602],
#  [140802498, 140802492, 140802512],
#  [394372620],
#  [306507325, 306507321, 765047104],
#  [295070869, 295070863],
#  [261646556],
#  [309781192],
#  [270275812, 270275805],
#  [234337768],
#  [29778064],
#  [261592957],
#  [176933601],
#  [261091441],
#  [214367709],
#  [260965285],
#  [79250321],
#  [206363145, 206363134],
#  [139915712],
#  [139844571],
#  [139899011],
#  [259928347],
#  [52245789],
#  [197695641, 197695643],
#  [115106052],
#  [39046297],
#  [60912975, 60911322],
#  [97409171, 97409172, 97409177, 97409169],
#  [60911322, 60912975],
#  [1992094833, 92498019],
#  [92560718, 92259410, 92560720],
#  [38807203],
#  [140827017],
#  [141333573, 141333574, 141333570, 141333569],
#  [141544911],
#  [140761918],
#  [231269538, 161167795],
#  [206328160],
#  [79153662, 79153669],
#  [391902612],
#  [141978095],
#  [33734375, 33734376],
#  [206498165, 206498157],
#  [392793234],
#  [300707137, 300707139],
#  [300034498, 300034497],
#  [300559128],
#  [300091984],
#  [278825952],
#  [201248423, 201248425, 201248424],
#  [234285429],
#  [406279367],
#  [280723416],
#  [261332760],
#  [319290696, 319290682, 319290692],
#  [388198039, 388198038, 388198040],
#  [370243555],
#  [309143752, 309143751, 309143731],
#  [441021825],
#  [261540883],
#  [99411125],
#  [394232475],
#  [263015046],
#  [267094867],
#  [238891804, 238891802],
#  [314864553, 314864554],
#  [238188289, 238188288],
#  [267047103],
#  [183116749],
#  [129680965],
#  [271975434, 271975437],
#  [271975437, 271975434],
#  [391947238],
#  [141412831],
#  [141027451],
#  [364424328],
#  [141122196, 141122198],
#  [141122198, 141122196],
#  [139720025, 139720027],
#  [79424807, 79424815, 79424812],
#  [206508795, 206508793, 2028821202, 206508769, 206508782],
#  [206538009,
#   206538011,
#   206538007,
#   206537981,
#   206535868,
#   206538005,
#   206535891,
#   206538020,
#   206537983,
#   206535873],
#  [206538011,
#   206538009,
#   206538007,
#   206537981,
#   206535837,
#   206535868,
#   206538005,
#   206538020,
#   206537983,
#   206535873],
#  [206538007,
#   206537976,
#   206538009,
#   206538011,
#   206537981,
#   206535868,
#   206538005,
#   206535891,
#   206538020,
#   206537983,
#   206535873],
#  [114917180],
#  [382266319],
#  [294054184],
#  [270565975],
#  [92729069],
#  [89040715],
#  [79492099, 79492098],
#  [235005703],
#  [232058110],
#  [31672006, 31672004, 650252070],
#  [31672004, 31672006, 650252070],
#  [232065886, 631176129],
#  [289936185,
#   290024080,
#   289950548,
#   289950533,
#   289950542,
#   289950553,
#   289950555,
#   289950564,
#   289953269,
#   289953231,
#   289953250,
#   289953278,
#   289953221,
#   289936184,
#   289936171,
#   290024096,
#   290024146,
#   289933806,
#   289936143,
#   289953224,
#   289953249,
#   289936170,
#   289936195,
#   289936192,
#   289950591,
#   289950551,
#   289950560,
#   289950539,
#   290024071,
#   290024114,
#   289953254],
#  [55602946],
#  [372911986],
#  [234505865, 234505869, 234505868],
#  [237911081],
#  [38909245, 38909247],
#  [279639068],
#  [309253911],
#  [349059354],
#  [350213888, 350221207],
#  [91433128, 91433130],
#  [235004516],
#  [235003170, 235003169],
#  [139453166],
#  [309859835,
#   309853161,
#   309859894,
#   309859850,
#   309859743,
#   309859862,
#   309853059,
#   309853171,
#   309853154,
#   309853147,
#   309853146,
#   309853072],
#  [229810745, 229810746],
#  [33834253, 33834252, 33834250],
#  [141425837],
#  [238185181],
#  [394517162, 394517163, 394517166],
#  [181043309],
#  [197985960],
#  [316879824],
#  [316852879],
#  [197600964],
#  [206439531, 206439529],
#  [277716604],
#  [394005458],
#  [2026655087, 403150111, 2026655085, 403150113],
#  [2026655085, 403150111, 2026655087, 403150113],
#  [370247078],
#  [238832575, 238832738, 238832736],
#  [31961007],
#  [177021252, 765289454],
#  [277773589],
#  [318516482],
#  [260608573],
#  [29345396, 29345395, 29345393],
#  [290079005],
#  [441080077],
#  [301193954],
#  [410212588],
#  [300577403],
#  [212318346,
#   212318426,
#   212318468,
#   212318428,
#   212318425,
#   212318336,
#   441355657,
#   212318380,
#   212318453,
#   212318465,
#   212318381,
#   212325151],
#  [219342229, 219342231, 219342235],
#  [267091830, 267091832, 267091837],
#  [260797021],
#  [293484138],
#  [650263134, 31796120, 31796118],
#  [281594406, 281594408, 281592910],
#  [293507031, 293507025, 293507029],
#  [277913197, 277913200, 277913201],
#  [181052118, 181043970, 10000089372, 181043969],
#  [167339240, 167339237],
#  [231093356],
#  [53950852, 53940313],
#  [270250630, 270250618],
#  [32177507],
#  [349157974, 765380013],
#  [309860098,
#   309860080,
#   309860120,
#   309860037,
#   309860019,
#   309860025,
#   309860008,
#   309860062,
#   309860186],
#  [31529035, 31529029],
#  [39069184, 39069188],
#  [234346466, 234346464, 234346468, 234346463],
#  [150067837, 150067845, 150067840, 150067832],
#  [358543427],
#  [425935689, 425935688],
#  [441382263,
#   441382281,
#   441382297,
#   441382274,
#   441389793,
#   441389789,
#   441389790,
#   441382266,
#   441381760,
#   441382269,
#   441381788,
#   441382252,
#   441389337],
#  [441381937,
#   441355785,
#   212343973,
#   212343982,
#   212343979,
#   441355613,
#   441382099,
#   441382068,
#   441355700,
#   441355719,
#   441355765,
#   441355780,
#   212325192,
#   441389521,
#   441389530,
#   441355675,
#   441330086,
#   441330095,
#   441330102,
#   441330100,
#   441330098,
#   441389495,
#   441355732,
#   441355711,
#   441355728],
#  [441382281,
#   441382263,
#   441382297,
#   441382274,
#   441389793,
#   441389789,
#   441389790,
#   441382266,
#   441381760,
#   441382269,
#   441382252,
#   441389337],
#  [92787648],
#  [270582604, 270582609, 270582602],
#  [253912623],
#  [211355854, 211336394, 211355815, 211355816],
#  [765289454, 177021252],
#  [167125054],
#  [300140005],
#  [206537981,
#   206537976,
#   206538009,
#   206538011,
#   206538007,
#   206535868,
#   206538005,
#   206535891,
#   206537983,
#   206537971,
#   206537969,
#   206535873],
#  [159693374],
#  [295070863, 295070869],
#  [389920099],
#  [373914184, 373843914, 277314298, 277099871, 373843925],
#  [308665618],
#  [309853661,
#   309853755,
#   309853675,
#   309853660,
#   309853657,
#   309853587,
#   309853693,
#   309853561,
#   309853714,
#   309853652],
#  [309853210,
#   309853343,
#   309853161,
#   309853217,
#   309853236,
#   309853242,
#   309853269,
#   309859743,
#   309853171,
#   309853154,
#   309853266,
#   309853147,
#   309853146,
#   309853295],
#  [309860080,
#   309860098,
#   309860120,
#   309860037,
#   309860019,
#   309860025,
#   309860008,
#   309860062,
#   309859948,
#   309860186],
#  [309859921,
#   309860037,
#   309860019,
#   309860025,
#   309859894,
#   309860008,
#   309859850,
#   309859862,
#   309859948],
#  [309403898],
#  [421950457, 421950453],
#  [421871796],
#  [232066460],
#  [392792586],
#  [277911324],
#  [281638173],
#  [261235797],
#  [358336077],
#  [263074589, 263074592, 612155681, 263074593],
#  [350137596],
#  [290484661],
#  [152825734],
#  [115152156, 115152159],
#  [139721085, 139721086],
#  [161270650],
#  [79422107],
#  [143855289],
#  [2026930048, 139699256, 139699260, 139699248],
#  [79223976],
#  [214913613],
#  [139207922],
#  [144254048],
#  [147338110],
#  [126605150, 126605145],
#  [51993496],
#  [232083665, 631265310],
#  [63037965],
#  [211414471],
#  [92631328],
#  [206508541, 301976795, 206406360, 206407795, 421953348],
#  [206505294, 206498004, 206505296, 206505314, 206505318],
#  [271901807],
#  [141709240],
#  [141268468, 141268467, 141268474],
#  [141413795, 141413799],
#  [140967545],
#  [33862642],
#  [140608211],
#  [267000838],
#  [355507583],
#  [231810776, 231810778, 231810777],
#  [375092714],
#  [219183387],
#  [375151660],
#  [139827700, 139839550],
#  [183116530],
#  [431481356],
#  [273550444, 273550448],
#  [431481291, 394231824],
#  [261265716],
#  [33734376, 33734375],
#  [141436274, 364589033],
#  [79172475, 1989153984],
#  [421952839,
#   421952824,
#   421952837,
#   421952823,
#   421952845,
#   421952284,
#   421952815,
#   421952853],
#  [206406752, 206406737, 206407338, 206406735, 206406731, 206406763, 206406739],
#  [300740040],
#  [300707139, 300707137],
#  [299939799],
#  [325280301],
#  [260608425],
#  [260503860],
#  [261644656],
#  [350622857],
#  [92591722],
#  [325412893],
#  [410252684],
#  [273739295],
#  [410354921, 410354930, 410354938],
#  [388198038, 388198039, 388198040],
#  [388198040, 388198039, 388198038],
#  [263079669, 263077685],
#  [261722744],
#  [290024080,
#   289936185,
#   289950548,
#   289950533,
#   289950542,
#   289950553,
#   289950555,
#   289950564,
#   289953269,
#   290024054,
#   289953231,
#   289953250,
#   289953278,
#   289936184,
#   290024096,
#   290024146,
#   289953249,
#   289936195,
#   289936192,
#   289950551,
#   289950560,
#   289950539,
#   290024071,
#   290024114,
#   289953254,
#   289953289],
#  [309474271],
#  [309144265, 309144277],
#  [206586764],
#  [161155149, 161155151, 2026991166],
#  [25301258, 25301246],
#  [115152159, 115152156],
#  [441047223],
#  [270424361],
#  [260950407],
#  [290606663],
#  [290547040, 290547036, 290547046],
#  [350152834],
#  [159692791],
#  [238188417],
#  [304034291],
#  [431481496, 431479701],
#  [141866705],
#  [141423697, 141423696],
#  [238180568],
#  [238870367],
#  [369180187],
#  [8195655],
#  [79180101],
#  [139720234, 139720235],
#  [79424815, 79424807, 79424812],
#  [307364426, 307364443, 307364441, 307364417],
#  [306577169,
#   306577143,
#   306511396,
#   306511406,
#   306511433,
#   306577173,
#   306577182,
#   306511370,
#   306511440,
#   306577196,
#   306577165,
#   306577191,
#   306577231],
#  [209309334],
#  [415615620],
#  [206535837, 206535822, 206538020, 206535816],
#  [206535868,
#   206537976,
#   206538009,
#   206538011,
#   206538007,
#   206537981,
#   206538005,
#   206535891,
#   206538020,
#   206537983,
#   206535873],
#  [206538005,
#   206537976,
#   206538009,
#   206538011,
#   206538007,
#   206537981,
#   206535868,
#   206535891,
#   206538020,
#   206537983,
#   206535873],
#  [206508749, 206508746, 206508722, 206508769, 206508745, 206508759],
#  [389528590, 389528584],
#  [206505552, 206505568, 206505567, 206505575, 206505572, 206505569, 206498875],
#  [115177383],
#  [260373589],
#  [350932561],
#  [350444940],
#  [294206969],
#  [201256776, 201256771],
#  [92319207],
#  [91450443],
#  [91450620],
#  [211411347],
#  [274015151],
#  [211403640],
#  [266582162, 266582163, 1992188726],
#  [161315263, 2055438618, 2055438619],
#  [220435884],
#  [393491149],
#  [260043515],
#  [350479496],
#  [79425923],
#  [220491218, 220491219],
#  [126873187, 126873196],
#  [53897632],
#  [262826232, 262826230],
#  [306894517, 306670213, 306778837],
#  [140040845],
#  [306505222, 306573636],
#  [300557956, 300557955, 300557973, 300557982, 300557996, 300557962],
#  [404806381, 404806414],
#  [167250523, 167250519],
#  [234333403, 234333401, 234333402],
#  [394731512],
#  [53950776, 53950793, 53951977, 53951994, 53954028],
#  [326442531],
#  [302333447,
#   300903742,
#   302333486,
#   300903778,
#   302299704,
#   302299680,
#   300577670,
#   302336010,
#   10001042145,
#   300579781,
#   290129286,
#   290129283,
#   302333482,
#   326395334,
#   300271965,
#   300271966,
#   302260201,
#   302299663,
#   302299660,
#   300579748,
#   300577679,
#   300577659,
#   290165024,
#   290131862,
#   290165011,
#   302335978,
#   302376932,
#   302376918,
#   302297149],
#  [289825612,
#   289825630,
#   289825628,
#   289825636,
#   10002600022,
#   289825607,
#   289825624,
#   289795667,
#   326392892,
#   289825645,
#   289825642,
#   289825605,
#   289825635,
#   289795661,
#   289795674],
#  [289950548,
#   289936185,
#   290024080,
#   289950533,
#   289950542,
#   289950553,
#   289950555,
#   289950564,
#   289953269,
#   290024054,
#   289953231,
#   289953250,
#   289953278,
#   289953221,
#   289936184,
#   289936171,
#   290024096,
#   290024146,
#   289933806,
#   289936143,
#   289953224,
#   289953249,
#   289936170,
#   289936195,
#   289936192,
#   289950591,
#   289950551,
#   289950560,
#   289950539,
#   290024071,
#   290024114,
#   289953254,
#   289953289],
#  [29392987, 29393035, 29393047],
#  [289950533,
#   289936185,
#   290024080,
#   289950548,
#   289950542,
#   289950553,
#   289950555,
#   289950564,
#   289953269,
#   290024054,
#   289953231,
#   289953250,
#   289953278,
#   289953221,
#   289936184,
#   289936171,
#   290024096,
#   290024146,
#   289953224,
#   289953249,
#   289936170,
#   289936195,
#   289936192,
#   289950551,
#   289950560,
#   289950539,
#   290024071,
#   290024114,
#   289953254,
#   289953289],
#  [289950542,
#   289936185,
#   290024080,
#   289950548,
#   289950533,
#   289950553,
#   289950555,
#   289950564,
#   289953269,
#   290024054,
#   289953231,
#   289953250,
#   289953278,
#   289953221,
#   289936184,
#   289936171,
#   290024096,
#   290024146,
#   289933806,
#   289936143,
#   289953224,
#   289953249,
#   289936170,
#   289936195,
#   289936192,
#   289950551,
#   289950560,
#   289950539,
#   290024071,
#   290024114,
#   289953254,
#   289953289],
#  [289950553,
#   289936185,
#   290024080,
#   289950548,
#   289950533,
#   289950542,
#   289950555,
#   289950564,
#   289953269,
#   290024054,
#   289953231,
#   289953250,
#   289953278,
#   289953221,
#   289936184,
#   289936171,
#   290024096,
#   290024146,
#   289933806,
#   289936143,
#   289953224,
#   289953249,
#   289936170,
#   289936195,
#   289936192,
#   289950591,
#   289950551,
#   289950560,
#   289950539,
#   290024071,
#   290024114,
#   289953254,
#   289953289],
#  [289950555,
#   289936185,
#   290024080,
#   289950548,
#   289950533,
#   289950542,
#   289950553,
#   289950564,
#   289953269,
#   289953231,
#   289953250,
#   289953278,
#   289953221,
#   289936184,
#   289936171,
#   290024096,
#   290024146,
#   289933806,
#   289936143,
#   289953224,
#   289953249,
#   289936170,
#   289936195,
#   289936192,
#   289950591,
#   289950551,
#   289950560,
#   289950539,
#   290024071,
#   290024114,
#   289953254],
#  [289950564,
#   289936185,
#   289950548,
#   289950533,
#   289950542,
#   289950553,
#   289950555,
#   289953269,
#   289953231,
#   289953250,
#   289953221,
#   289936184,
#   289936171,
#   290024096,
#   290024146,
#   289933806,
#   289936143,
#   289953224,
#   289953249,
#   289936170,
#   289936195,
#   289936192,
#   289950591,
#   289950551,
#   289950560,
#   289950539,
#   290024114,
#   289953254],
#  [290049085,
#   290049092,
#   290049058,
#   290049078,
#   290049055,
#   290049112,
#   290049115,
#   290077344,
#   290077318,
#   290077307,
#   290080093,
#   290046432,
#   290046460],
#  [300903742,
#   302333447,
#   302333486,
#   302299704,
#   302299653,
#   302299680,
#   300577670,
#   302336010,
#   300908041,
#   10001042145,
#   300579781,
#   302333482,
#   302333497,
#   302333494,
#   326395334,
#   300271965,
#   300271966,
#   302260201,
#   302299663,
#   302299649,
#   302299642,
#   302299652,
#   302299660,
#   300579748,
#   300577679,
#   300577659,
#   302335967,
#   302335978,
#   302376918,
#   302297149],
#  [302333486,
#   290131778,
#   302333447,
#   29392987,
#   300903742,
#   302333528,
#   302299704,
#   302299653,
#   302299680,
#   302336010,
#   300908041,
#   302333514,
#   302333482,
#   302333497,
#   302333525,
#   302333494,
#   326395334,
#   300271966,
#   29498560,
#   302260201,
#   29393035,
#   29393047,
#   302299663,
#   302299649,
#   302299626,
#   302299636,
#   302299642,
#   302299652,
#   302299660,
#   269883697,
#   300577679,
#   302335952,
#   302335967,
#   302335978,
#   29543345,
#   302297149,
#   1992266045],
#  [289825630,
#   289825612,
#   289825628,
#   289825636,
#   10002600022,
#   289825607,
#   289825624,
#   289795667,
#   326392892,
#   289825645,
#   289825642,
#   289825605,
#   289825635,
#   289795661,
#   289795674,
#   289825673],
#  [289825628,
#   289825612,
#   289825630,
#   289825636,
#   10002600022,
#   289825607,
#   289825624,
#   289795667,
#   326392892,
#   289825645,
#   289825642,
#   289825605,
#   289825635,
#   289795661,
#   289795674,
#   289825673],
#  [289825636,
#   289825612,
#   289825630,
#   289825628,
#   10002600022,
#   289825607,
#   289825624,
#   289795667,
#   326392892,
#   289825645,
#   289825642,
#   289825605,
#   289825635,
#   289795661,
#   289795674,
#   289825673],
#  [290080342, 290128958, 290128934],
#  [290028022],
#  [290027518, 290027504, 290027512, 290031855],
#  [419589159],
#  [262608101, 262608069, 262608099, 364393522, 364393541],
#  [38877247, 38846294],
#  [220521196, 220521199],
#  [237926199],
#  [316976100],
#  [349056499],
#  [349831865, 349788701, 349831871, 349788749, 349831810, 349831846],
#  [349641813],
#  [231829787, 231829788, 631403488],
#  [234505869, 234505865, 234505868],
#  [234491750, 234491752],
#  [425934461],
#  [231829788, 231829787, 631403488],
#  [237905903],
#  [349683728,
#   349683758,
#   349683749,
#   349683776,
#   349683785,
#   349683750,
#   349683742,
#   349683734,
#   349683770],
#  [349683758,
#   349683728,
#   349683749,
#   349683776,
#   349683785,
#   349683750,
#   349683742,
#   349683734,
#   349683770],
#  [375035513, 737153831],
#  [167815131],
#  [167718833, 167718839],
#  [220559179],
#  [38810760, 38810764, 38810762, 38810769],
#  [38810748, 684922919, 38810764, 38810749, 38810753],
#  [220537358],
#  [220516211, 220516213],
#  [149629043],
#  [309715828,
#   309715879,
#   309626029,
#   309715825,
#   309715748,
#   309715773,
#   309715880,
#   806290376],
#  [308852332, 309256301],
#  [350024726,
#   350027748,
#   350027816,
#   350024735,
#   350027749,
#   350027765,
#   350027792,
#   350024666,
#   350024647,
#   350027804,
#   350027811,
#   350027848,
#   350027817,
#   350027815,
#   350027782,
#   350027779,
#   350027716,
#   350027788,
#   350027797],
#  [349480491, 349480514, 349480507],
#  [149664951],
#  [150361911],
#  [150390197, 150390200],
#  [150389733],
#  [410486826,
#   308852332,
#   309715879,
#   309256301,
#   309256410,
#   349575582,
#   349575584,
#   364393220,
#   309715880,
#   309256411,
#   308399401,
#   382520347,
#   410446627,
#   364393095,
#   410446677,
#   382526262,
#   350096623,
#   349834788,
#   350145806,
#   382572814,
#   262578020,
#   382572789,
#   262578045,
#   364393104,
#   350025038,
#   410486835,
#   350025028,
#   350096687,
#   350096657,
#   350096674,
#   262616340,
#   410446600,
#   410446701,
#   349575561,
#   349575587,
#   349575564,
#   349575577,
#   349575606],
#  [350027748,
#   350024726,
#   350027816,
#   350024735,
#   350027749,
#   350027765,
#   350027792,
#   350094093,
#   350027804,
#   350027811,
#   350027817,
#   350027815,
#   350094116,
#   350094091,
#   350027782,
#   350027779,
#   350027716,
#   350027788,
#   350027797,
#   350094069],
#  [91433130, 91433128],
#  [355446601],
#  [235003169, 235003170],
#  [161265146],
#  [389659039, 389659042],
#  [89018908, 89018905, 2027112725, 89018909],
#  [259717688],
#  [33834252, 33834253, 33834250],
#  [410422824],
#  [140802492, 140802498, 140802512],
#  [181886412, 181886413, 181879100, 181879094, 181879098],
#  [231910501, 231910499, 231908770, 231910496],
#  [231631989],
#  [220508951, 2055311157],
#  [231701398],
#  [316937318],
#  [2026828876, 197766143],
#  [394494335],
#  [231696917],
#  [219213075],
#  [206506382, 206508716, 206506413, 206506414, 206508722, 206535816],
#  [206499063, 206499071, 206498101, 206498113, 206498116],
#  [206508793, 206508795, 2028821202, 206508769, 206508782],
#  [206406827],
#  [2028821202, 206508795, 206508793, 206508769, 206508782],
#  [219170666, 219170670],
#  [219170670, 219170666],
#  [389020349, 389020348, 389020350],
#  [389020350, 389020348, 389020349],
#  [231714659],
#  [316967214],
#  [294671852],
#  [267091837, 267091832, 267091830],
#  [238832738, 238832575, 238832736],
#  [261525123],
#  [394632091],
#  [238830696],
#  [278825613],
#  [302753894, 302753893, 302751916],
#  [53782886],
#  [405412258],
#  [29753242],
#  [290025724, 290025711],
#  [29259283, 29259304, 29259322],
#  [29259304, 29259283, 29259340, 29253702, 29253709, 29253711, 29259322],
#  [212318426,
#   212318346,
#   212343973,
#   441382026,
#   212318468,
#   212318392,
#   212318418,
#   212318428,
#   212318425,
#   212343982,
#   212343979,
#   441355657,
#   441355613,
#   212318380,
#   212318453,
#   212318465,
#   212318381,
#   212325192,
#   212325151,
#   441389521,
#   441389530,
#   441355675],
#  [290049792, 290049747, 290049766, 290076557],
#  [410212440],
#  [2054785911, 238832400],
#  [290076672, 290049720],
#  [290076699],
#  [289951325],
#  [212287329, 10000112964, 212293871, 212293892, 212287314, 212287331],
#  [29542484],
#  [29286513, 29286514],
#  [289842910],
#  [419588384],
#  [219138810],
#  [267040542, 267040543],
#  [410134402],
#  [325204384],
#  [260161938],
#  [382268993, 382268992],
#  [281594408, 281594406, 281592910],
#  [392814184, 392814185],
#  [31415131],
#  [176932824],
#  [167338355],
#  [231791552, 231791465, 231791524],
#  [232087348],
#  [179314875, 306573151, 306670213, 404971093, 31268555, 306778837, 306573146],
#  [30266257, 30266241, 30266262],
#  [238832400, 2054785911],
#  [393890981, 270251139, 393891001, 393890994, 393890985],
#  [209399358, 209399352, 209399347, 209399350, 209399351],
#  [441119274],
#  [382629507],
#  [410453494],
#  [349572806, 349572810, 349572805],
#  [30104570],
#  [309853755,
#   309853661,
#   309853675,
#   309853660,
#   309853657,
#   309853693,
#   309853714,
#   309853652],
#  [309860259, 309860186, 309860249],
#  [309860120,
#   309860098,
#   309860080,
#   309860037,
#   309860019,
#   309860025,
#   309860008,
#   309860062,
#   309860186],
#  [349158571, 349158569, 349158531, 349158552, 349158568],
#  [259962026],
#  [52245237],
#  [31183631],
#  [167890109, 167890110],
#  [374940426],
#  [262926994],
#  [358512352],
#  [262704328, 364392985, 262577762],
#  [204441306],
#  [211432927, 211432928],
#  [92788528],
#  [211379272, 211379275, 211379274],
#  [441382297,
#   441382263,
#   441382281,
#   441382274,
#   441355928,
#   441382266,
#   441381760,
#   441382269,
#   441382252,
#   441382348],
#  [1992445863, 441405332],
#  [441382168, 441389418, 441382099, 441389431, 441381788, 441382177],
#  [441382274,
#   441382263,
#   441382281,
#   441382297,
#   441355928,
#   441382266,
#   441381760,
#   441382269,
#   441381788,
#   441382252],
#  [441330106,
#   441355785,
#   441330138,
#   441355765,
#   441355780,
#   441330086,
#   441330108,
#   441330095,
#   441330102,
#   441330124,
#   441330100,
#   441330098,
#   441329779,
#   441329850],
#  [441330238, 441355873, 441355439, 441355869],
#  [211336601, 2028427389, 211336604],
#  [92502487],
#  [441355785,
#   441381937,
#   441330106,
#   441330138,
#   441355719,
#   441355765,
#   441355780,
#   441330086,
#   441330108,
#   441330095,
#   441330102,
#   441330124,
#   441330100,
#   441330098,
#   441355732,
#   441355728],
#  [441355928, 441381645, 441382297, 441382274, 441382266, 441382269],
#  [269939837, 269883639],
#  [289953269,
#   289936185,
#   290024080,
#   289950548,
#   289950533,
#   289950542,
#   289950553,
#   289950555,
#   289950564,
#   290024054,
#   289953231,
#   289953250,
#   289953278,
#   289936184,
#   289936171,
#   290024096,
#   290024146,
#   289953249,
#   289936170,
#   289936195,
#   289936192,
#   289950551,
#   289950560,
#   289950539,
#   290024071,
#   290024114,
#   289953254,
#   289953289],
#  [29281501],
#  [272288007],
#  [141870501],
#  [391927558],
#  [391926737],
#  [441181782, 441181780, 2028327521, 441181781],
#  [441405332, 1992445863],
#  [229060127],
#  [152285357],
#  [306630840, 306630842],
#  [300324638],
#  [31602633],
#  [300652458, 453081705, 300604907, 300604975, 300599100],
#  [30313070],
#  [373843914, 373914184, 373843925],
#  [300934004,
#   300867547,
#   300867480,
#   300934001,
#   300934078,
#   300933978,
#   300934032,
#   300934057,
#   300934054,
#   300934070],
#  [421951430, 421951420, 421951415, 421951426, 421953653, 302029063],
#  [394242722, 261748412, 394242723],
#  [421951420,
#   421951430,
#   302029059,
#   421951415,
#   421951426,
#   421951404,
#   302029070,
#   302029063],
#  [421951461, 421951451, 421953653],
#  [206535891,
#   206537976,
#   206538009,
#   206538011,
#   206538007,
#   206537981,
#   206535868,
#   206538005,
#   206537983,
#   206537971,
#   206537969,
#   206535873],
#  [29435807, 29392921],
#  [143849401],
#  [261748412, 394242722, 394242723],
#  [394341018],
#  [270366148],
#  [263078636, 263078632],
#  [261748796],
#  [167304030, 167304040],
#  [309853675,
#   309853661,
#   309853755,
#   309853660,
#   309853657,
#   309853587,
#   309853693,
#   309853714,
#   309853652],
#  [309853343,
#   309853210,
#   806366723,
#   309853217,
#   309853372,
#   309853236,
#   309853341,
#   309853389,
#   309853242,
#   309853376,
#   309853269,
#   309853266,
#   309853413,
#   309853418,
#   309853295],
#  [309860037,
#   309860098,
#   309860080,
#   309859921,
#   309860120,
#   309860019,
#   309860025,
#   309860008,
#   309860062,
#   309859948],
#  [309860019,
#   309860098,
#   309860080,
#   309859921,
#   309860120,
#   309860037,
#   309860025,
#   309859894,
#   309860008,
#   309860062,
#   309859948],
#  [309860025,
#   309860098,
#   309860080,
#   309859921,
#   309860120,
#   309860037,
#   309860019,
#   309859894,
#   309860008,
#   309860062,
#   309859948],
#  [309780401,
#   309780431,
#   309780436,
#   309780394,
#   309780441,
#   309780442,
#   309780470,
#   309780347],
#  [309780431,
#   309780401,
#   309780436,
#   309780394,
#   309780502,
#   309780441,
#   309780442,
#   309780470,
#   309780347],
#  [277939151],
#  [421950453, 421950457],
#  [273473842],
#  [407581481],
#  [31636377],
#  [270558340],
#  [300657354, 300654002],
#  [394680010],
#  [152799055],
#  [278538682],
#  [261656369, 261656371],
#  [290498952],
#  [394242723, 394242722, 261748412],
#  [40792629],
#  [79491024, 139844571],
#  [139699260, 139699256, 2026930048, 139699248],
#  [320954453],
#  [79357088, 79357091],
#  [161136872],
#  [139989962],
#  [143951692],
#  [143896906],
#  [402046594, 402047581],
#  [143895187],
#  [206355320],
#  [161154736, 2027061308],
#  [2055438618, 161315263, 2055438619],
#  [2055438619, 161315263, 2055438618],
#  [139932736],
#  [52245652],
#  [79304240],
#  [79354602, 79354601],
#  [300907803, 300907810, 300579697],
#  [10002600022,
#   289825612,
#   289825630,
#   289825628,
#   289825636,
#   289825607,
#   289825624,
#   289795667,
#   326392892,
#   289825645,
#   289825642,
#   289825605,
#   289825635,
#   289795661,
#   289795674,
#   289825673],
#  [278666918],
#  [152824941, 152824945, 152807714],
#  [214773593],
#  [152830345, 152830363, 152830351],
#  [215195743],
#  [215114674, 215197035, 215197038],
#  [214710699],
#  [453100671, 453100673, 453100734, 453100657],
#  [126803454, 126803455, 1989908229, 126803429, 126803478, 126803456],
#  [382414206],
#  [139189880],
#  [121487719, 121475571],
#  [44627557, 121421853, 44627568, 44627572],
#  [139322091],
#  [44565836, 44565958, 44565963, 44565828, 44565921, 44564147, 44564150],
#  [126803455, 126803454, 1989908229, 126803429, 126803478, 126803456],
#  [389726434, 389726435, 389726433],
#  [278785015],
#  [97409172, 97409171, 97409177, 97409169],
#  [97409177, 97409171, 97409172, 97409169],
#  [97409169, 97409171, 97409172, 97409177],
#  [60646278, 60647930],
#  [204497971],
#  [92441460],
#  [97432330],
#  [89398038, 89398045, 89398039],
#  [89398039, 89398045, 89398038],
#  [92259410],
#  [206506520, 206506524, 206537920, 206506512],
#  [206462073, 206462053],
#  [302029059,
#   421951420,
#   421951415,
#   2028833878,
#   421951451,
#   302029070,
#   302029063,
#   302029057],
#  [441032606, 441032612, 441029726],
#  [25373195, 25352180, 25352193, 25357714, 25373216],
#  [25299738, 25352226, 25299716, 25299741, 25303971, 25302384, 25299732],
#  [231261607],
#  [25092883, 25135249, 25135250],
#  [25304031, 25373195, 25352180, 25352193, 25357714, 25302267, 25302259],
#  [25243334, 25243367],
#  [25200706, 25200696],
#  [206547259],
#  [271643372],
#  [270474299],
#  [142016939],
#  [141627221],
#  [141333574, 141333573, 141333570, 141333569],
#  [141333570, 141333573, 141333574, 141333569],
#  [426031808, 280053053],
#  [140997887],
#  [232085493, 232085492, 232085494],
#  [232085492, 232085493, 232085494],
#  [232085494, 232085493, 232085492],
#  [141526909, 141526900],
#  [33832255],
#  [184134558, 184134559],
#  [182909294],
#  [238872498],
#  [40348031],
#  [266907594],
#  [161112484],
#  [140068027, 140068025],
#  [161167795],
#  [140068025, 140068027],
#  [79173869, 79173870],
#  [79451127],
#  [79153669, 79153662],
#  [469850335],
#  [452357557],
#  [255546550],
#  [219159872],
#  [219159933],
#  [139148070, 139148071],
#  [303951396],
#  [631265310, 232083665],
#  [183306014],
#  [267549665],
#  [269763053],
#  [270244648],
#  [270203165],
#  [79225639, 79225651, 79225655, 1989169801],
#  [79225655, 79225651, 79225639, 1989169801],
#  [161313139, 161313137],
#  [161313137, 161313139],
#  [25135249, 25092883, 25135250],
#  [25135250, 25092883, 25135249],
#  [206508716, 206535822, 206508746, 206508720, 206508722, 206535816, 206508745],
#  [421952837,
#   421952824,
#   421952839,
#   421952823,
#   206406763,
#   421952845,
#   206406798,
#   421952815,
#   421952853],
#  [206482882],
#  [206499071, 206499063, 206498101, 206498113],
#  [206406737, 206406752, 206407338, 206406735, 206406731, 206406763, 206406739],
#  [206439680,
#   206439944,
#   206439674,
#   206439669,
#   206439941,
#   206439940,
#   2028853723],
#  [206439944, 206439680, 206439941, 206439940],
#  [206480147, 206480138],
#  [206489731, 206489743, 206498090],
#  [206488769, 206488753, 206486307, 206488761],
#  [206407338, 206406752, 206406737, 206406735, 206406731, 206406739],
#  [300240101],
#  [300600720, 300600723],
#  [300745181],
#  [300744844],
#  [391900011],
#  [300867547, 300934004, 300867480, 300867519, 300934032, 300934057, 300934054],
#  [300443903],
#  [177237758],
#  [176932559],
#  [176982334],
#  [177018590],
#  [325373788],
#  [350954274, 350954272],
#  [278992257],
#  [350585213],
#  [260192156],
#  [350930938],
#  [201248950],
#  [382101212],
#  [234993145],
#  [177309715, 764681066, 764681068],
#  [412051798, 412051801],
#  [277771645],
#  [388200400, 388200401],
#  [388200401, 388200400],
#  [348761381, 650065056],
#  [273696175],
#  [392011499],
#  [260951353],
#  [270395038],
#  [290495367],
#  [302965473],
#  [319290682, 319290696, 319290692],
#  [263077685, 263079669],
#  [392025951, 392025953],
#  [319290692, 319290696, 319290682],
#  [10000112964, 212287329, 212293871, 212293892, 212287314, 212287331],
#  [290024054,
#   289936185,
#   290024080,
#   289950548,
#   289950533,
#   289950542,
#   289950553,
#   289950555,
#   289953269,
#   289953250,
#   289953278,
#   290024096,
#   289953249,
#   290129286,
#   289936195,
#   289936192,
#   289950551,
#   289950539,
#   290024071,
#   290024114,
#   289953254,
#   289953289],
#  [309143731, 309143751, 309143752],
#  [301979347, 301979352, 301979363],
#  [206561223],
#  [301941136, 301941237, 301941119, 301941138, 53975108, 301937199],
#  [206437556,
#   10000104256,
#   206409136,
#   206409117,
#   206437548,
#   206409120,
#   206437511,
#   206437538],
#  [441021579],
#  [25229579, 25225864, 25229602, 25229584, 25230276],
#  [140044709],
#  [161172832],
#  [161155151, 161155149, 2026991166],
#  [326357162,
#   326327791,
#   441051092,
#   326357148,
#   326327807,
#   326327790,
#   326327815,
#   326327826,
#   326327814],
#  [326357247,
#   25091723,
#   326357607,
#   326357262,
#   326357267,
#   326357234,
#   326357274,
#   326357619],
#  [439366897],
#  [99672411, 99672412],
#  [99672412, 99672411],
#  [441012391],
#  [261204832],
#  [260972784],
#  [269730072, 269730074],
#  [260985277],
#  [650065056, 348761381],
#  [348762899, 348762908],
#  [278703629],
#  [290463054],
#  [270309025],
#  [207078218, 207078222, 207078207],
#  [389473806],
#  [238202490],
#  [140687469],
#  [33715940, 33715938],
#  [238891802, 238891804],
#  [370118582],
#  [238188288, 238188289],
#  [764681066, 177309715, 764681068],
#  [304092049],
#  [182517221],
#  [177387851],
#  [220492973, 220489456],
#  [272088299, 272126076],
#  [142148382],
#  [141472325],
#  [141941332],
#  [140608645],
#  [141423696, 141423697],
#  [115043061],
#  [317097350],
#  [261677822],
#  [204447346],
#  [139720235, 139720234],
#  [139720461],
#  [307364443, 307364426, 307364441, 307364417],
#  [306469923, 306469925],
#  [306736486],
#  [306928146],
#  [300746196, 300746199],
#  [306577143,
#   306577169,
#   306511396,
#   306511406,
#   306511433,
#   306577173,
#   306577182,
#   306511370,
#   306511440,
#   306577196,
#   306577165,
#   306577191],
#  [306577406, 765064334, 306580585],
#  [300605401],
#  [300808106, 300808133],
#  [300937636,
#   300937654,
#   300934078,
#   300937717,
#   300937704,
#   300937688,
#   300937639,
#   300937673,
#   300937684,
#   300937702,
#   300934070],
#  [300937654,
#   300937636,
#   300934078,
#   300937717,
#   300937704,
#   300937688,
#   300937639,
#   300937673,
#   300937684,
#   300937737,
#   300937702,
#   300937742,
#   300934070],
#  [300013254],
#  [300867480,
#   300934004,
#   300867547,
#   300867456,
#   300867484,
#   300867513,
#   300934078,
#   300867519,
#   300867415,
#   300867464,
#   300867465,
#   300867470,
#   300867458,
#   300934032,
#   300934057,
#   300934054,
#   300934070],
#  [300867456,
#   300867480,
#   300867484,
#   300867513,
#   300867381,
#   300867519,
#   300867415,
#   300867464,
#   300867465,
#   300867470,
#   300867458,
#   300934057,
#   300934054],
#  [300867484,
#   300867480,
#   300867456,
#   300867513,
#   300867519,
#   300867415,
#   300867464,
#   300867465,
#   300867470,
#   300867458,
#   300934057,
#   300934054],
#  [300867513,
#   300867456,
#   300867484,
#   300867519,
#   300867464,
#   300867465,
#   300867470,
#   300867458],
#  [53781599],
#  [206483422],
#  [206483655],
#  [206535822, 206535837, 206508716, 206508720, 206508722, 206535816],
#  [206508746,
#   206508749,
#   206508716,
#   206508720,
#   206508722,
#   206508769,
#   206508745,
#   206508759],
#  [25302524, 25299577, 25302505, 25302537, 25299569],
#  [25299577,
#   25302524,
#   25302505,
#   25302537,
#   25299553,
#   25299604,
#   25299569,
#   25285382],
#  [159778224],
#  [382298569],
#  [159844372],
#  [389528584, 389528590],
#  [206488753, 206488769, 206489700, 206488761],
#  [25244804, 25244791, 25244820, 25243391, 25243401, 25243367, 25244816],
#  [25244791, 25244804, 25244820, 25243401, 25244816],
#  [25244820, 25244804, 25244791, 25243391, 25243367, 25244816],
#  [294054946],
#  [350654946],
#  [220395278],
#  [279475551, 279475555],
#  [279475555, 279475551],
#  [278957988, 278957986, 278957959],
#  [260350645],
#  [281460038],
#  [214427109],
#  [70459735],
#  [204448277],
#  [204392200, 204392198],
#  [441400622],
#  [126783518, 126766469],
#  [147248320],
#  [260271338],
#  [204416416],
#  [270535918],
#  [206439674, 206439680, 206439669, 206436399, 2028853723],
#  [121421110,
#   121421044,
#   121421045,
#   121421046,
#   121421049,
#   121421051,
#   121421063,
#   121421066,
#   121421069,
#   121421071,
#   121421073,
#   121421074,
#   121421075,
#   121421077,
#   121421102,
#   121421109,
#   121421123,
#   121421131,
#   121421149],
#  [220404905],
#  [350583013],
#  [201293349, 201293352],
#  [234518098],
#  [201292881],
#  [201249836],
#  [89043105, 2027167504, 2027167502],
#  [117544922, 117544915, 117544914],
#  [117544914, 117544915, 117544922],
#  [2027167504, 89043105, 2027167502],
#  [79425491],
#  [126605703],
#  [144194307, 144194304],
#  [441183392],
#  [143856701],
#  [389471462],
#  [410442304],
#  [453078812, 453078814, 453078847, 453078852],
#  [453078814, 453078812, 453078847],
#  [453078844, 453078843, 453078847, 453078852],
#  [300709268],
#  [300655732, 300655725, 271998431, 271998454, 300655740, 300655726, 271998453],
#  [300655725,
#   300655732,
#   271998431,
#   271998454,
#   300655740,
#   300655726,
#   271998453,
#   271998576],
#  [300557699, 300557688, 300557896, 300557933],
#  [272086345, 272086347, 272086329, 272086267, 272086335, 272086305],
#  [272086347, 272086345, 272086329, 272086267, 272086335, 272086305],
#  [306573151, 306670213, 306778837, 306573146],
#  [453079231, 300602424, 453079229],
#  [453097988, 453097973, 271906212, 453097993, 764814093],
#  [143980227],
#  [306742085],
#  [271998495, 300709616, 271998523, 271998517, 271998489],
#  [300557955, 300557956, 300557973, 300557982, 300557996, 300557962],
#  [391890400, 391890357],
#  [300291347, 300291360, 300291394],
#  [271998431,
#   300655732,
#   300655725,
#   271998454,
#   300655726,
#   271998453,
#   271998576,
#   271998398],
#  [271998454,
#   300655732,
#   300655725,
#   271998431,
#   271998412,
#   300655683,
#   300655726,
#   271998433,
#   271998453,
#   271998398,
#   271998408],
#  [300330083],
#  [167250519, 167250523],
#  [139700944],
#  [167692420, 167692429, 765416705],
#  [306670213, 306894517, 306573151, 306778837, 306573146],
#  [167308872],
#  [167309182],
#  [30266241, 30266257, 30266262],
#  [300015200],
#  [234333401, 234333403, 234333402],
#  [765416705, 167692429, 167692420],
#  [257736471, 257736470],
#  [410354938, 410354930, 410354921],
#  [10000112870, 212257911, 212257894],
#  ...]

# %%
#get lcs for ebs in the larger list thats not in smaller(same depth dip) eb list
refebs = ref.loc[ref['TIC_ID'].isin(eblist.index.values)]
files = data_dir + refebs.Filename.values
lcc = loaders.LightCurveCollection(refebs.Sector.values,
                                   refebs.Camera.values,
                                   files,
                                   False
                            )
lcc.useCpus = 8
lcc.load_all_lcs()

lcs = lcc.lcs

# %%
len(lcs)
# Out:
# 4824

# %%
tic = []
avgflux = []
    
for i in range(len(lcs)):
    tic.append(refebs['TIC_ID'].values[i])
    avgflux.append(np.median(lcs[i].flux.value))

# %%
d = {'TIC': tic, 'avgflux': avgflux}
avg = pd.DataFrame(d)

# %%
avg
# Out:
#             TIC       avgflux
# 0     269762258    443.491322
# 1     263074592  30010.553216
# 2     278706358   8850.857966
# 3     261656371   9947.039924
# 4     152825521   8615.038484
# ...         ...           ...
# 4819  278861826  10458.540525
# 4820  309853072  14305.984937
# 4821  349572805  10619.731527
# 4822  234509218  12718.302203
# 4823  211336604  20778.617945
#
# [4824 rows x 2 columns]

# %%
highestfluxtics = []
for i in range(len(closestarstics)):
    a = []
    for j in closestarstics[i]:
        a.append(avg[avg['TIC'] == j].avgflux.values[0])
    highestfluxtics.append(closestarstics[i][a.index(max(a))])

# %%
highestfluxtics
# Out:
# [269762258,
#  263074592,
#  278706358,
#  261656371,
#  152825521,
#  139699256,
#  139721085,
#  139841210,
#  214198381,
#  144462697,
#  389726435,
#  160036449,
#  229057817,
#  204497617,
#  441406061,
#  152223725,
#  25226886,
#  280052690,
#  358457398,
#  141268467,
#  33862174,
#  267263253,
#  79403459,
#  79225651,
#  99465976,
#  201176965,
#  389476160,
#  261746657,
#  262958558,
#  290547036,
#  263078276,
#  33715938,
#  303909865,
#  271596290,
#  220474209,
#  278683641,
#  201256776,
#  92352621,
#  92352621,
#  441422220,
#  89398867,
#  147083089,
#  206462116,
#  117544915,
#  139148070,
#  139207681,
#  91369561,
#  44623916,
#  144194307,
#  126944775,
#  126945917,
#  167692429,
#  410354930,
#  32200310,
#  290131778,
#  281498280,
#  220521199,
#  234491752,
#  38586438,
#  55652788,
#  349832824,
#  147131974,
#  91448148,
#  147201138,
#  117515123,
#  121420805,
#  89018905,
#  126602778,
#  141606986,
#  197766143,
#  266996791,
#  219308281,
#  206505572,
#  260161144,
#  403153647,
#  265591866,
#  219338651,
#  231714759,
#  54001270,
#  220388567,
#  381857817,
#  394006752,
#  270204401,
#  419744996,
#  350443417,
#  350622185,
#  201293780,
#  31796120,
#  181043970,
#  32000625,
#  30313682,
#  31653503,
#  141622065,
#  425064757,
#  167304040,
#  393948907,
#  389729356,
#  89398045,
#  204544746,
#  92498019,
#  206537971,
#  267093915,
#  421952824,
#  350954272,
#  201248425,
#  407580995,
#  261137705,
#  261724521,
#  309143752,
#  441041386,
#  261136311,
#  269852699,
#  129681302,
#  314887863,
#  389527961,
#  114948643,
#  33767523,
#  300012172,
#  441157639,
#  115192433,
#  260659986,
#  260239481,
#  266540667,
#  403150113,
#  262826232,
#  141126559,
#  269833439,
#  2028782097,
#  235015153,
#  349835367,
#  309402205,
#  183981740,
#  201248424,
#  370239670,
#  197979841,
#  206505572,
#  737425239,
#  389020348,
#  403153647,
#  270174474,
#  179244391,
#  300654002,
#  410214468,
#  409136916,
#  219342231,
#  267091837,
#  382101519,
#  279161495,
#  277913200,
#  327937353,
#  206542964,
#  309405242,
#  309472288,
#  167651110,
#  469973582,
#  149351413,
#  234509221,
#  61178236,
#  211379275,
#  441381645,
#  270582609,
#  140802498,
#  394372620,
#  306507321,
#  295070869,
#  261646556,
#  309781192,
#  270275812,
#  234337768,
#  29778064,
#  261592957,
#  176933601,
#  261091441,
#  214367709,
#  260965285,
#  79250321,
#  206363145,
#  139915712,
#  139844571,
#  139899011,
#  259928347,
#  52245789,
#  197695641,
#  115106052,
#  39046297,
#  60912975,
#  97409171,
#  60912975,
#  1992094833,
#  92560720,
#  38807203,
#  140827017,
#  141333573,
#  141544911,
#  140761918,
#  231269538,
#  206328160,
#  79153662,
#  391902612,
#  141978095,
#  33734376,
#  206498165,
#  392793234,
#  300707137,
#  300034498,
#  300559128,
#  300091984,
#  278825952,
#  201248423,
#  234285429,
#  406279367,
#  280723416,
#  261332760,
#  319290696,
#  388198039,
#  370243555,
#  309143752,
#  441021825,
#  261540883,
#  99411125,
#  394232475,
#  263015046,
#  267094867,
#  238891804,
#  314864553,
#  238188289,
#  267047103,
#  183116749,
#  129680965,
#  271975434,
#  271975434,
#  391947238,
#  141412831,
#  141027451,
#  364424328,
#  141122198,
#  141122198,
#  139720025,
#  79424807,
#  206508793,
#  206538007,
#  206535837,
#  206538007,
#  114917180,
#  382266319,
#  294054184,
#  270565975,
#  92729069,
#  89040715,
#  79492099,
#  235005703,
#  232058110,
#  31672006,
#  31672006,
#  232065886,
#  289936185,
#  55602946,
#  372911986,
#  234505865,
#  237911081,
#  38909245,
#  279639068,
#  309253911,
#  349059354,
#  350213888,
#  91433128,
#  235004516,
#  235003170,
#  139453166,
#  309859835,
#  229810745,
#  33834253,
#  141425837,
#  238185181,
#  394517162,
#  181043309,
#  197985960,
#  316879824,
#  316852879,
#  197600964,
#  206439531,
#  277716604,
#  394005458,
#  403150113,
#  403150113,
#  370247078,
#  238832575,
#  31961007,
#  177021252,
#  277773589,
#  318516482,
#  260608573,
#  29345395,
#  290079005,
#  441080077,
#  301193954,
#  410212588,
#  300577403,
#  212318346,
#  219342231,
#  267091837,
#  260797021,
#  293484138,
#  650263134,
#  281594406,
#  293507031,
#  277913200,
#  181043970,
#  167339237,
#  231093356,
#  53950852,
#  270250630,
#  32177507,
#  349157974,
#  309860080,
#  31529035,
#  39069184,
#  234346466,
#  150067837,
#  358543427,
#  425935688,
#  441381760,
#  441330102,
#  441381760,
#  92787648,
#  270582609,
#  253912623,
#  211355854,
#  765289454,
#  167125054,
#  300140005,
#  206537971,
#  159693374,
#  295070863,
#  389920099,
#  277314298,
#  308665618,
#  309853561,
#  309853161,
#  309859948,
#  309859948,
#  309403898,
#  421950457,
#  421871796,
#  232066460,
#  392792586,
#  277911324,
#  281638173,
#  261235797,
#  358336077,
#  263074589,
#  350137596,
#  290484661,
#  152825734,
#  115152156,
#  139721085,
#  161270650,
#  79422107,
#  143855289,
#  2026930048,
#  79223976,
#  214913613,
#  139207922,
#  144254048,
#  147338110,
#  126605150,
#  51993496,
#  232083665,
#  63037965,
#  211414471,
#  92631328,
#  206508541,
#  206505294,
#  271901807,
#  141709240,
#  141268467,
#  141413795,
#  140967545,
#  33862642,
#  140608211,
#  267000838,
#  355507583,
#  231810776,
#  375092714,
#  219183387,
#  375151660,
#  139827700,
#  183116530,
#  431481356,
#  273550444,
#  431481291,
#  261265716,
#  33734376,
#  141436274,
#  79172475,
#  421952824,
#  206406752,
#  300740040,
#  300707137,
#  299939799,
#  325280301,
#  260608425,
#  260503860,
#  261644656,
#  350622857,
#  92591722,
#  325412893,
#  410252684,
#  273739295,
#  410354930,
#  388198039,
#  388198039,
#  263079669,
#  261722744,
#  289936185,
#  309474271,
#  309144265,
#  206586764,
#  161155149,
#  25301258,
#  115152156,
#  441047223,
#  270424361,
#  260950407,
#  290606663,
#  290547036,
#  350152834,
#  159692791,
#  238188417,
#  304034291,
#  431481496,
#  141866705,
#  141423697,
#  238180568,
#  238870367,
#  369180187,
#  8195655,
#  79180101,
#  139720234,
#  79424807,
#  307364426,
#  306577169,
#  209309334,
#  415615620,
#  206535837,
#  206538007,
#  206538005,
#  206508746,
#  389528590,
#  206505572,
#  115177383,
#  260373589,
#  350932561,
#  350444940,
#  294206969,
#  201256776,
#  92319207,
#  91450443,
#  91450620,
#  211411347,
#  274015151,
#  211403640,
#  266582162,
#  161315263,
#  220435884,
#  393491149,
#  260043515,
#  350479496,
#  79425923,
#  220491218,
#  126873187,
#  53897632,
#  262826232,
#  306894517,
#  140040845,
#  306505222,
#  300557956,
#  404806381,
#  167250523,
#  234333403,
#  394731512,
#  53950776,
#  326442531,
#  302333486,
#  289825612,
#  289936185,
#  29392987,
#  289936185,
#  289936185,
#  289936185,
#  289936185,
#  289936185,
#  290049085,
#  302333486,
#  290131778,
#  289825612,
#  289825612,
#  289825612,
#  290080342,
#  290028022,
#  290027518,
#  419589159,
#  262608101,
#  38877247,
#  220521199,
#  237926199,
#  316976100,
#  349056499,
#  349788701,
#  349641813,
#  231829787,
#  234505865,
#  234491752,
#  425934461,
#  231829787,
#  237905903,
#  349683758,
#  349683758,
#  375035513,
#  167815131,
#  167718833,
#  220559179,
#  38810760,
#  38810749,
#  220537358,
#  220516211,
#  149629043,
#  309715828,
#  308852332,
#  350027748,
#  349480507,
#  149664951,
#  150361911,
#  150390197,
#  150389733,
#  308852332,
#  350027748,
#  91433128,
#  355446601,
#  235003169,
#  161265146,
#  389659039,
#  89018905,
#  259717688,
#  33834253,
#  410422824,
#  140802492,
#  181886413,
#  231910501,
#  231631989,
#  220508951,
#  231701398,
#  316937318,
#  2026828876,
#  394494335,
#  231696917,
#  219213075,
#  206508716,
#  206499063,
#  206508793,
#  206406827,
#  206508793,
#  219170670,
#  219170670,
#  389020349,
#  389020348,
#  231714659,
#  316967214,
#  294671852,
#  267091837,
#  238832575,
#  261525123,
#  394632091,
#  238830696,
#  278825613,
#  302753894,
#  53782886,
#  405412258,
#  29753242,
#  290025724,
#  29259283,
#  29259283,
#  212318346,
#  290049792,
#  410212440,
#  2054785911,
#  290076672,
#  290076699,
#  289951325,
#  212287331,
#  29542484,
#  29286513,
#  289842910,
#  419588384,
#  219138810,
#  267040542,
#  410134402,
#  325204384,
#  260161938,
#  382268993,
#  281594406,
#  392814184,
#  31415131,
#  176932824,
#  167338355,
#  231791552,
#  232087348,
#  179314875,
#  30266257,
#  238832400,
#  393890981,
#  209399358,
#  441119274,
#  382629507,
#  410453494,
#  349572805,
#  30104570,
#  309853693,
#  309860259,
#  309860080,
#  349158568,
#  259962026,
#  52245237,
#  31183631,
#  167890109,
#  374940426,
#  262926994,
#  358512352,
#  262704328,
#  204441306,
#  211432927,
#  92788528,
#  211379275,
#  441381760,
#  1992445863,
#  441382168,
#  441381760,
#  441329850,
#  441355439,
#  211336604,
#  92502487,
#  441330102,
#  441381645,
#  269939837,
#  289936185,
#  29281501,
#  272288007,
#  141870501,
#  391927558,
#  391926737,
#  441181782,
#  441405332,
#  229060127,
#  152285357,
#  306630840,
#  300324638,
#  31602633,
#  300652458,
#  30313070,
#  373843925,
#  300934070,
#  421951420,
#  261748412,
#  302029059,
#  421951461,
#  206537971,
#  29435807,
#  143849401,
#  261748412,
#  394341018,
#  270366148,
#  263078636,
#  261748796,
#  167304040,
#  309853693,
#  309853210,
#  309859948,
#  309859948,
#  309859948,
#  309780401,
#  309780401,
#  277939151,
#  421950457,
#  273473842,
#  407581481,
#  31636377,
#  270558340,
#  300654002,
#  394680010,
#  152799055,
#  278538682,
#  261656369,
#  290498952,
#  261748412,
#  40792629,
#  139844571,
#  139699256,
#  320954453,
#  79357088,
#  161136872,
#  139989962,
#  143951692,
#  143896906,
#  402046594,
#  143895187,
#  206355320,
#  161154736,
#  2055438618,
#  2055438619,
#  139932736,
#  52245652,
#  79304240,
#  79354602,
#  300907810,
#  289825612,
#  278666918,
#  152807714,
#  214773593,
#  152830351,
#  215195743,
#  215197038,
#  214710699,
#  453100657,
#  126803455,
#  382414206,
#  139189880,
#  121487719,
#  44627568,
#  139322091,
#  44564147,
#  126803455,
#  389726435,
#  278785015,
#  97409172,
#  97409171,
#  97409171,
#  60646278,
#  204497971,
#  92441460,
#  97432330,
#  89398045,
#  89398045,
#  92259410,
#  206506520,
#  206462073,
#  302029059,
#  441032606,
#  25373195,
#  25299738,
#  231261607,
#  25092883,
#  25304031,
#  25243334,
#  25200706,
#  206547259,
#  271643372,
#  270474299,
#  142016939,
#  141627221,
#  141333573,
#  141333573,
#  280053053,
#  140997887,
#  232085493,
#  232085493,
#  232085493,
#  141526909,
#  33832255,
#  184134558,
#  182909294,
#  238872498,
#  40348031,
#  266907594,
#  161112484,
#  140068025,
#  161167795,
#  140068025,
#  79173870,
#  79451127,
#  79153662,
#  469850335,
#  452357557,
#  255546550,
#  219159872,
#  219159933,
#  139148070,
#  303951396,
#  631265310,
#  183306014,
#  267549665,
#  269763053,
#  270244648,
#  270203165,
#  79225651,
#  79225651,
#  161313139,
#  161313139,
#  25092883,
#  25092883,
#  206508716,
#  421952824,
#  206482882,
#  206499063,
#  206406752,
#  206439669,
#  206439944,
#  206480147,
#  206489731,
#  206488769,
#  206406752,
#  300240101,
#  300600720,
#  300745181,
#  300744844,
#  391900011,
#  300934004,
#  300443903,
#  177237758,
#  176932559,
#  176982334,
#  177018590,
#  325373788,
#  350954272,
#  278992257,
#  350585213,
#  260192156,
#  350930938,
#  201248950,
#  382101212,
#  234993145,
#  177309715,
#  412051798,
#  277771645,
#  388200400,
#  388200401,
#  348761381,
#  273696175,
#  392011499,
#  260951353,
#  270395038,
#  290495367,
#  302965473,
#  319290696,
#  263079669,
#  392025953,
#  319290696,
#  212287331,
#  289936185,
#  309143752,
#  301979347,
#  206561223,
#  301941119,
#  10000104256,
#  441021579,
#  25229579,
#  140044709,
#  161172832,
#  161155149,
#  326357162,
#  326357267,
#  439366897,
#  99672411,
#  99672411,
#  441012391,
#  261204832,
#  260972784,
#  269730072,
#  260985277,
#  650065056,
#  348762908,
#  278703629,
#  290463054,
#  270309025,
#  207078218,
#  389473806,
#  238202490,
#  140687469,
#  33715938,
#  238891804,
#  370118582,
#  238188289,
#  764681066,
#  304092049,
#  182517221,
#  177387851,
#  220492973,
#  272088299,
#  142148382,
#  141472325,
#  141941332,
#  140608645,
#  141423696,
#  115043061,
#  317097350,
#  261677822,
#  204447346,
#  139720235,
#  139720461,
#  307364426,
#  306469923,
#  306736486,
#  306928146,
#  300746196,
#  306577169,
#  765064334,
#  300605401,
#  300808106,
#  300934070,
#  300934070,
#  300013254,
#  300934070,
#  300867381,
#  300867484,
#  300867484,
#  53781599,
#  206483422,
#  206483655,
#  206535837,
#  206508716,
#  25302524,
#  25302524,
#  159778224,
#  382298569,
#  159844372,
#  389528590,
#  206488769,
#  25244820,
#  25244820,
#  25244820,
#  294054946,
#  350654946,
#  220395278,
#  279475551,
#  279475555,
#  278957959,
#  260350645,
#  281460038,
#  214427109,
#  70459735,
#  204448277,
#  204392200,
#  441400622,
#  126783518,
#  147248320,
#  260271338,
#  204416416,
#  270535918,
#  206439669,
#  121421044,
#  220404905,
#  350583013,
#  201293349,
#  234518098,
#  201292881,
#  201249836,
#  89043105,
#  117544915,
#  117544915,
#  2027167504,
#  79425491,
#  126605703,
#  144194307,
#  441183392,
#  143856701,
#  389471462,
#  410442304,
#  453078812,
#  453078812,
#  453078843,
#  300709268,
#  271998431,
#  271998431,
#  300557699,
#  272086345,
#  272086345,
#  306670213,
#  453079229,
#  453097988,
#  143980227,
#  306742085,
#  271998495,
#  300557956,
#  391890400,
#  300291347,
#  271998431,
#  271998431,
#  300330083,
#  167250523,
#  139700944,
#  167692429,
#  306894517,
#  167308872,
#  167309182,
#  30266257,
#  300015200,
#  234333403,
#  167692429,
#  257736471,
#  410354930,
#  10000112870,
#  ...]

# %%
def checkIfDuplicates_2(listOfElems):
    ''' Check if given list contains any duplicates '''    
    setOfElems = set()
    for elem in listOfElems:
        if elem in setOfElems:
            return True
        else:
            setOfElems.add(elem)         
    return False

# %%
result = checkIfDuplicates_2(highestfluxtics)
if result:
    print('Yes, list contains duplicates')
else:
    print('No duplicates found in list')
# Out:
# Yes, list contains duplicates

# %%
newlist = [] #eb list with no duplicates, cut down to ones with highest flux values in a radius of 0.1
duplist = []
for i in highestfluxtics:
    if i not in newlist:
        newlist.append(i)
    else:
        duplist.append(i)

# %%
len(newlist)
# Out:
# 2651

# %%
with open(f"Sector{sector}/newlistSect{sector}.txt", "w") as output:
    for i in range(len(newlist)):
        output.write(str(newlist[i]))
        output.write("\n")

# %%
refebs = ref.loc[ref['TIC_ID'].isin(newlist)]
files = data_dir + refebs.Filename.values
filepath = files[0]
refebs
# Out:
#                                                   Filename          RA  \
# 571      tesslcs_sector_1_104/2_min_cadence_targets/tes...   66.470863
# 715      tesslcs_sector_1_104/2_min_cadence_targets/tes...   16.409233
# 758      tesslcs_sector_1_104/2_min_cadence_targets/tes...  334.810708
# 797      tesslcs_sector_1_104/2_min_cadence_targets/tes...   20.218095
# 849      tesslcs_sector_1_104/2_min_cadence_targets/tes...  344.569628
# ...                                                    ...         ...
# 1190317  tesslcs_sector_1_104/tesslcs_tmag_9_10/tesslc_...  100.658603
# 1190890  tesslcs_sector_1_104/tesslcs_tmag_9_10/tesslc_...  126.553872
# 1190959  tesslcs_sector_1_104/tesslcs_tmag_9_10/tesslc_...  111.752572
# 1191688  tesslcs_sector_1_104/tesslcs_tmag_9_10/tesslc_...   12.913047
# 1191848  tesslcs_sector_1_104/tesslcs_tmag_9_10/tesslc_...  320.428150
#
#                Dec     TIC_ID  Sector  Camera  CCD  Magnitude
# 571     -81.319731  269762258       1       3    3  13.024600
# 715     -80.061304  263074592       1       3    3   9.358700
# 758     -40.533673  278706358       1       1    2  10.389200
# 797     -80.316844  261656371       1       3    3  10.566000
# 849     -41.826179  152825521       1       2    3   9.915200
# ...            ...        ...     ...     ...  ...        ...
# 1190317 -56.541875  278861826       1       4    4   9.869500
# 1190890 -63.101620  309853072       1       4    3   9.678800
# 1190959 -63.734975  349572805       1       4    3   9.833201
# 1191688 -65.340492  234509218       1       3    1   9.795600
# 1191848 -30.936537  211336604       1       1    4   9.741900
#
# [2651 rows x 8 columns]

# %%
lcc = loaders.LightCurveCollection(refebs.Sector.values,
                                   refebs.Camera.values,
                                   files,
                                   False
                            )
lcc.useCpus = 8
lcc.load_all_lcs()

lcs = lcc.lcs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_17042/1290362520.py in <module>
# ----> 1 lcc = loaders.LightCurveCollection(refebs.Sector.values,
#       2                                    refebs.Camera.values,
#       3                                    files,
#       4                                    False
#       5                             )
#
# NameError: name 'refebs' is not defined

# %%
with PdfPages(f"Sector1/newlist.pdf") as pdf:
    plt.cla()
    for i in range(len(newlist)):
        lcs[i].scatter()
        pdf.savefig()
        plt.close();
plt.close()

# %% [markdown]
# ___
# classified as ebs (90%> but not 100%)
# <br>
# Finding and removing closest stars, then printing the remaining light curves into a pdf file to visually examine

# %%
eb90 = sec1[sec1['probone'] >= 0.9]

# %%
eb90 = eb90[eb90['probone'] < 1]

# %%
tics90 = eb90.index.values
len(tics90)
# Out:
# 1156

# %%
stars90 = ref.TIC_ID.isin(tics90)
ref[stars90]
# Out:
#                                                   Filename          RA  \
# 849      tesslcs_sector_1_104/2_min_cadence_targets/tes...  344.569628
# 1656     tesslcs_sector_1_104/2_min_cadence_targets/tes...  336.752288
# 1759     tesslcs_sector_1_104/2_min_cadence_targets/tes...  331.990313
# 1932     tesslcs_sector_1_104/2_min_cadence_targets/tes...  312.279500
# 2134     tesslcs_sector_1_104/2_min_cadence_targets/tes...   45.447123
# ...                                                    ...         ...
# 1187616  tesslcs_sector_1_104/tesslcs_tmag_9_10/tesslc_...  110.936772
# 1187938  tesslcs_sector_1_104/tesslcs_tmag_9_10/tesslc_...  348.388141
# 1188651  tesslcs_sector_1_104/tesslcs_tmag_9_10/tesslc_...  332.331275
# 1190890  tesslcs_sector_1_104/tesslcs_tmag_9_10/tesslc_...  126.553872
# 1191688  tesslcs_sector_1_104/tesslcs_tmag_9_10/tesslc_...   12.913047
#
#                Dec     TIC_ID  Sector  Camera  CCD  Magnitude
# 849     -41.826179  152825521       1       2    3    9.91520
# 1656    -37.188368  160036449       1       1    2   10.80220
# 1759    -32.833234  229057817       1       1    2   10.40450
# 1932    -33.731793  152223725       1       1    4    9.31480
# 2134    -76.203210  280052690       1       3    3    9.24610
# ...            ...        ...     ...     ...  ...        ...
# 1187616 -65.010940  349480507       1       4    3    9.39600
# 1187938 -47.640055  139301655       1       2    3    9.94530
# 1188651 -18.988099  206498875       1       1    3    9.18637
# 1190890 -63.101620  309853072       1       4    3    9.67880
# 1191688 -65.340492  234509218       1       3    1    9.79560
#
# [1156 rows x 8 columns]

# %%
closestarslist90 = []
for i in range(len(tics90)):
    rastar = ref[stars90].RA.values[i]
    decstar = ref[stars90].Dec.values[i]
    dist = np.sqrt(((rastar-ref[stars90].RA.values)*(np.cos(decstar)))**2+(decstar-ref[stars90].Dec.values)**2)
    closestars = np.where((dist < 0.1) & (dist != 0))
    closestarslist90.append(closestars)

# %%
closestarslist90
# Out:
# [(array([389]),),
#  (array([], dtype=int64),),
#  (array([399]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([422]),),
#  (array([ 235, 1142]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([537]),),
#  (array([], dtype=int64),),
#  (array([  53, 1150]),),
#  (array([], dtype=int64),),
#  (array([231]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([169]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([177]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([  57,  571,  572, 1145, 1153]),),
#  (array([], dtype=int64),),
#  (array([856]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([871]),),
#  (array([], dtype=int64),),
#  (array([110, 609]),),
#  (array([308]),),
#  (array([361, 980]),),
#  (array([], dtype=int64),),
#  (array([219]),),
#  (array([], dtype=int64),),
#  (array([74]),),
#  (array([ 89, 153, 154, 403, 404, 565]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([625]),),
#  (array([  13, 1150]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([307]),),
#  (array([  28,  571,  572, 1145, 1153]),),
#  (array([107, 868]),),
#  (array([108]),),
#  (array([112, 875]),),
#  (array([359, 402]),),
#  (array([], dtype=int64),),
#  (array([1155]),),
#  (array([ 196, 1042]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([394]),),
#  (array([218]),),
#  (array([42]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([138]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([534]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([182]),),
#  (array([ 88,  89, 153, 154, 311, 565]),),
#  (array([ 87,  89, 152, 153, 154, 311, 565]),),
#  (array([ 43,  87,  88, 153, 154, 311, 565]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([873]),),
#  (array([], dtype=int64),),
#  (array([168, 288]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([ 338,  374,  376,  377,  912,  942, 1154]),),
#  (array([], dtype=int64),),
#  (array([596, 597]),),
#  (array([], dtype=int64),),
#  (array([119]),),
#  (array([319]),),
#  (array([], dtype=int64),),
#  (array([ 58, 868]),),
#  (array([59]),),
#  (array([], dtype=int64),),
#  (array([ 36, 609]),),
#  (array([189]),),
#  (array([ 60, 875]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([978]),),
#  (array([1008, 1011, 1012]),),
#  (array([], dtype=int64),),
#  (array([1043]),),
#  (array([104]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([204, 363, 364, 370, 372, 939, 941]),),
#  (array([205, 338, 339, 368, 373, 376, 912, 935, 942, 947]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([599]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([431]),),
#  (array([78]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([255, 300]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([264]),),
#  (array([], dtype=int64),),
#  (array([269, 311, 569]),),
#  (array([ 43,  87,  88,  89, 154, 311, 565]),),
#  (array([ 43,  87,  88,  89, 153, 311, 565]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([1040]),),
#  (array([], dtype=int64),),
#  (array([591]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([607]),),
#  (array([282, 616, 617, 618]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([ 95, 288]),),
#  (array([19]),),
#  (array([968]),),
#  (array([677]),),
#  (array([1151]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([837]),),
#  (array([25]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([238, 434, 436, 569]),),
#  (array([239, 849]),),
#  (array([86]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([872]),),
#  (array([111]),),
#  (array([], dtype=int64),),
#  (array([279, 329, 598]),),
#  (array([332, 350, 882, 884]),),
#  (array([], dtype=int64),),
#  (array([949, 950]),),
#  (array([], dtype=int64),),
#  (array([  64, 1042]),),
#  (array([198]),),
#  (array([197]),),
#  (array([], dtype=int64),),
#  (array([202]),),
#  (array([], dtype=int64),),
#  (array([200]),),
#  (array([], dtype=int64),),
#  (array([122, 363, 364, 370, 372, 939, 941]),),
#  (array([123, 335, 339, 365, 366, 367, 368, 371, 373, 935, 936, 938, 947]),),
#  (array([207, 208, 375, 378]),),
#  (array([206, 208, 374, 375, 378]),),
#  (array([206, 207, 374, 375, 378]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([391]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([392]),),
#  (array([73]),),
#  (array([40]),),
#  (array([], dtype=int64),),
#  (array([408, 411, 633]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([226]),),
#  (array([225]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([427]),),
#  (array([], dtype=int64),),
#  (array([15]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([   6, 1142]),),
#  (array([237]),),
#  (array([236]),),
#  (array([269, 569]),),
#  (array([181, 849]),),
#  (array([241, 274, 313, 439, 440, 583]),),
#  (array([240, 439, 440]),),
#  (array([], dtype=int64),),
#  (array([435, 846]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([258]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([455, 460, 468, 504, 510]),),
#  (array([451, 477, 524, 526, 527, 613]),),
#  (array([488, 492, 497, 501]),),
#  (array([146, 300]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([248]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([536]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([150]),),
#  (array([], dtype=int64),),
#  (array([ 542,  543,  546, 1055, 1128]),),
#  (array([556, 557, 558, 559]),),
#  (array([], dtype=int64),),
#  (array([152, 238, 569]),),
#  (array([574, 576, 850]),),
#  (array([577]),),
#  (array([580, 581, 582]),),
#  (array([], dtype=int64),),
#  (array([240, 313, 579, 583]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([602]),),
#  (array([598]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([165, 616, 617]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([652]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([ 95, 168]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([690, 691, 697, 700, 730, 760, 807]),),
#  (array([714]),),
#  (array([756, 757]),),
#  (array([753, 755, 758]),),
#  (array([], dtype=int64),),
#  (array([654, 660, 661, 662, 663, 732, 733, 798]),),
#  (array([734, 982]),),
#  (array([146, 255]),),
#  (array([], dtype=int64),),
#  (array([822]),),
#  (array([1152]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([56]),),
#  (array([37]),),
#  (array([839]),),
#  (array([239, 435, 846]),),
#  (array([ 87,  88,  89, 152, 153, 154, 565]),),
#  (array([840, 845]),),
#  (array([240, 274, 579, 583]),),
#  (array([843]),),
#  (array([566, 852]),),
#  (array([324, 869]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([105]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([323, 867]),),
#  (array([322, 867]),),
#  (array([316, 869]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([192, 350, 882, 884]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([205, 365, 366, 367, 369, 371, 936, 938, 943, 947]),),
#  (array([918, 919]),),
#  (array([], dtype=int64),),
#  (array([ 100,  123,  339,  368,  373,  376,  377,  912,  935,  942, 1154]),),
#  (array([123, 205, 338, 366, 368, 373, 376, 912, 935, 942, 947]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([1021]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([ 594, 1044]),),
#  (array([915]),),
#  (array([], dtype=int64),),
#  (array([192, 332, 882, 884]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([632]),),
#  (array([], dtype=int64),),
#  (array([401]),),
#  (array([], dtype=int64),),
#  (array([402]),),
#  (array([], dtype=int64),),
#  (array([ 38, 980]),),
#  (array([], dtype=int64),),
#  (array([122, 204, 364, 370, 372, 939, 941]),),
#  (array([122, 204, 363, 370, 372, 939, 941]),),
#  (array([205, 335, 366, 367, 371, 923, 936, 938, 947]),),
#  (array([205, 335, 339, 365, 367, 368, 371, 373, 935, 936, 938, 947]),),
#  (array([205, 335, 365, 366, 369, 371, 373, 936, 938, 943, 947]),),
#  (array([123, 205, 338, 339, 366, 373, 912, 935, 942, 947]),),
#  (array([335, 367, 370, 371, 936, 938, 943, 945]),),
#  (array([122, 204, 363, 364, 369, 372, 941, 943, 945]),),
#  (array([205, 335, 365, 366, 367, 369, 936, 938, 947]),),
#  (array([122, 204, 363, 364, 370, 939, 941]),),
#  (array([123, 205, 338, 339, 366, 367, 368, 935, 947]),),
#  (array([ 100,  207,  208,  375,  377,  378, 1154]),),
#  (array([206, 207, 208, 374, 378]),),
#  (array([ 100,  123,  338,  339,  377,  912,  935,  942, 1154]),),
#  (array([ 100,  338,  374,  376,  378,  912,  942, 1154]),),
#  (array([206, 207, 208, 374, 375, 377]),),
#  (array([], dtype=int64),),
#  (array([383, 918]),),
#  (array([931, 932]),),
#  (array([911]),),
#  (array([380]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([0]),),
#  (array([], dtype=int64),),
#  (array([213]),),
#  (array([217]),),
#  (array([], dtype=int64),),
#  (array([72]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([2]),),
#  (array([], dtype=int64),),
#  (array([357]),),
#  (array([ 61, 359]),),
#  (array([ 43, 404]),),
#  (array([ 43, 403]),),
#  (array([], dtype=int64),),
#  (array([407, 409, 414, 415]),),
#  (array([406, 409, 414, 415]),),
#  (array([221, 411, 633]),),
#  (array([406, 407, 414, 415]),),
#  (array([634]),),
#  (array([221, 408]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([406, 407, 409, 415]),),
#  (array([406, 407, 409, 414]),),
#  (array([220]),),
#  (array([418]),),
#  (array([417]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([5]),),
#  (array([], dtype=int64),),
#  (array([425]),),
#  (array([424]),),
#  (array([], dtype=int64),),
#  (array([229]),),
#  (array([], dtype=int64),),
#  (array([1147]),),
#  (array([], dtype=int64),),
#  (array([137]),),
#  (array([847]),),
#  (array([], dtype=int64),),
#  (array([180, 436]),),
#  (array([243, 310, 846]),),
#  (array([180, 434]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([240, 241, 440]),),
#  (array([240, 241, 439]),),
#  (array([], dtype=int64),),
#  (array([443]),),
#  (array([442]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([739, 741, 749]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([253, 477, 524, 527, 613]),),
#  (array([454]),),
#  (array([458]),),
#  (array([452]),),
#  (array([252, 460, 468, 510]),),
#  (array([], dtype=int64),),
#  (array([458]),),
#  (array([453, 457]),),
#  (array([511]),),
#  (array([252, 455, 468, 510]),),
#  (array([], dtype=int64),),
#  (array([508]),),
#  (array([], dtype=int64),),
#  (array([473]),),
#  (array([467, 470, 479, 517]),),
#  (array([469, 481, 515, 520, 530]),),
#  (array([465, 470, 479, 517]),),
#  (array([252, 455, 460, 504, 510]),),
#  (array([466, 481, 515, 519, 520]),),
#  (array([465, 467, 479]),),
#  (array([474, 480, 482, 518]),),
#  (array([504]),),
#  (array([464]),),
#  (array([471, 480, 482, 518]),),
#  (array([476]),),
#  (array([475]),),
#  (array([253, 451, 526, 613]),),
#  (array([525]),),
#  (array([465, 467, 470]),),
#  (array([471, 474, 482, 518]),),
#  (array([466, 469, 515, 520, 530]),),
#  (array([471, 474, 480, 518]),),
#  (array([526]),),
#  (array([], dtype=int64),),
#  (array([487, 490, 491, 492]),),
#  (array([], dtype=int64),),
#  (array([485, 490, 491]),),
#  (array([254, 492, 497]),),
#  (array([496, 498, 500]),),
#  (array([485, 487, 491, 492]),),
#  (array([485, 487, 490]),),
#  (array([254, 485, 488, 490, 497]),),
#  (array([ 499,  514,  519, 1148]),),
#  (array([505]),),
#  (array([502]),),
#  (array([489, 498, 500]),),
#  (array([254, 488, 492, 501]),),
#  (array([489, 496, 500]),),
#  (array([493, 494, 505, 514]),),
#  (array([489, 496, 498]),),
#  (array([254, 497]),),
#  (array([495]),),
#  (array([], dtype=int64),),
#  (array([252, 468, 472, 510]),),
#  (array([494]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([462]),),
#  (array([512]),),
#  (array([252, 455, 460, 468, 504]),),
#  (array([459]),),
#  (array([509]),),
#  (array([], dtype=int64),),
#  (array([493, 499]),),
#  (array([466, 469, 481, 519, 520]),),
#  (array([], dtype=int64),),
#  (array([465, 467]),),
#  (array([471, 474, 480, 482]),),
#  (array([466, 469, 515, 520]),),
#  (array([466, 469, 481, 515, 519]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([253, 451, 527, 532, 613]),),
#  (array([478]),),
#  (array([253, 477, 483]),),
#  (array([253, 451, 524, 528, 613]),),
#  (array([527]),),
#  (array([], dtype=int64),),
#  (array([466]),),
#  (array([], dtype=int64),),
#  (array([524, 533]),),
#  (array([532]),),
#  (array([81]),),
#  (array([], dtype=int64),),
#  (array([261]),),
#  (array([11]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([ 266,  543,  546, 1055, 1128]),),
#  (array([ 266,  542,  546, 1055, 1128]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([ 266,  542,  543, 1055, 1128]),),
#  (array([], dtype=int64),),
#  (array([1062]),),
#  (array([], dtype=int64),),
#  (array([ 551,  862, 1118, 1121, 1123]),),
#  (array([ 550,  862, 1118, 1121, 1123]),),
#  (array([], dtype=int64),),
#  (array([1098, 1119, 1120]),),
#  (array([1057]),),
#  (array([], dtype=int64),),
#  (array([267, 557, 558, 559]),),
#  (array([267, 556, 558, 559]),),
#  (array([267, 556, 557, 559]),),
#  (array([267, 556, 557, 558]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([564, 567, 584]),),
#  (array([563, 567, 584]),),
#  (array([ 43,  87,  88,  89, 153, 154, 311]),),
#  (array([315, 841]),),
#  (array([563, 564, 584]),),
#  (array([], dtype=int64),),
#  (array([152, 180, 238, 269]),),
#  (array([573, 633]),),
#  (array([  28,   57,  572, 1145, 1153]),),
#  (array([  28,   57,  571, 1145, 1153]),),
#  (array([570, 633]),),
#  (array([270, 576]),),
#  (array([], dtype=int64),),
#  (array([270, 574, 850]),),
#  (array([271]),),
#  (array([], dtype=int64),),
#  (array([274, 313, 583]),),
#  (array([272, 581, 582]),),
#  (array([272, 580]),),
#  (array([272, 580]),),
#  (array([240, 274, 313, 579]),),
#  (array([563, 564, 567]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([853]),),
#  (array([161]),),
#  (array([ 593, 1046]),),
#  (array([ 592, 1046]),),
#  (array([ 347, 1044]),),
#  (array([], dtype=int64),),
#  (array([102, 597]),),
#  (array([102, 596]),),
#  (array([279]),),
#  (array([133]),),
#  (array([601]),),
#  (array([600]),),
#  (array([278]),),
#  (array([681]),),
#  (array([608, 877]),),
#  (array([606]),),
#  (array([605]),),
#  (array([164]),),
#  (array([604, 877]),),
#  (array([ 36, 110]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([904]),),
#  (array([253, 451, 477, 524, 527]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([165, 282, 617, 618]),),
#  (array([165, 282, 616, 618]),),
#  (array([616, 617, 619]),),
#  (array([618]),),
#  (array([], dtype=int64),),
#  (array([622]),),
#  (array([621]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([52]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([416]),),
#  (array([355]),),
#  (array([221, 408, 570, 573]),),
#  (array([410]),),
#  (array([637]),),
#  (array([], dtype=int64),),
#  (array([635]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([642, 667, 668]),),
#  (array([641, 667, 668]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([964, 965]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([699]),),
#  (array([], dtype=int64),),
#  (array([285]),),
#  (array([], dtype=int64),),
#  (array([661, 662, 663, 733, 798]),),
#  (array([656, 657, 658, 659]),),
#  (array([655, 657, 658, 659]),),
#  (array([655, 656, 658, 659]),),
#  (array([655, 656, 657]),),
#  (array([655, 656, 657]),),
#  (array([298, 654, 661, 662, 663, 733, 798]),),
#  (array([298, 654, 660, 662, 663, 798]),),
#  (array([298, 654, 660, 661, 663, 732, 733, 798]),),
#  (array([298, 654, 660, 661, 662, 732, 733, 798]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([933]),),
#  (array([641, 642, 668]),),
#  (array([641, 642, 667]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([834]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([171]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([603]),),
#  (array([], dtype=int64),),
#  (array([684]),),
#  (array([683]),),
#  (array([686, 687, 688, 920, 924, 925]),),
#  (array([685, 687, 688, 920, 924, 925]),),
#  (array([685, 686, 688, 920, 924, 925]),),
#  (array([685, 686, 687, 920, 924, 925]),),
#  (array([695, 725, 726, 750, 759, 761]),),
#  (array([293, 691, 695, 697, 700, 727, 730, 807]),),
#  (array([293, 690, 697, 700, 727, 730, 807]),),
#  (array([701, 704, 708, 722, 724, 728, 729]),),
#  (array([750, 759, 761, 763, 766]),),
#  (array([751, 993]),),
#  (array([689, 690, 700, 725, 726, 727, 759, 761]),),
#  (array([], dtype=int64),),
#  (array([293, 690, 691, 700, 727, 730, 807]),),
#  (array([], dtype=int64),),
#  (array([650]),),
#  (array([293, 690, 691, 695, 697, 727, 730, 807]),),
#  (array([692, 704, 708, 724, 729, 806]),),
#  (array([740, 746, 988]),),
#  (array([], dtype=int64),),
#  (array([692, 701, 708, 722, 724, 728, 729]),),
#  (array([809]),),
#  (array([], dtype=int64),),
#  (array([1009]),),
#  (array([692, 701, 704, 724, 729, 805, 806]),),
#  (array([], dtype=int64),),
#  (array([ 738, 1000]),),
#  (array([712, 778, 779, 789]),),
#  (array([711, 775, 778, 781]),),
#  (array([717, 718, 814, 815]),),
#  (array([294, 717]),),
#  (array([719, 720]),),
#  (array([721]),),
#  (array([713, 714]),),
#  (array([713, 814, 815]),),
#  (array([715, 720]),),
#  (array([715, 719, 813]),),
#  (array([716]),),
#  (array([692, 704, 728, 729, 760]),),
#  (array([746, 750, 761, 763, 766]),),
#  (array([692, 701, 704, 708, 729, 805, 806]),),
#  (array([689, 695, 726, 750, 759, 761, 763, 766]),),
#  (array([689, 695, 725, 750, 759, 761, 763]),),
#  (array([293, 690, 691, 697, 700, 807]),),
#  (array([692, 704, 722, 729, 760]),),
#  (array([692, 701, 704, 708, 722, 724, 728]),),
#  (array([293, 690, 691, 697, 700, 760, 762]),),
#  (array([], dtype=int64),),
#  (array([298, 662, 663, 733, 798]),),
#  (array([298, 654, 660, 662, 663, 732, 798]),),
#  (array([299, 982]),),
#  (array([796]),),
#  (array([737, 801, 803]),),
#  (array([ 736,  801,  999, 1002]),),
#  (array([ 710, 1000]),),
#  (array([448, 741]),),
#  (array([702, 723, 746, 988]),),
#  (array([448, 739, 749]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([702, 723, 740, 763, 988]),),
#  (array([], dtype=int64),),
#  (array([752]),),
#  (array([741]),),
#  (array([689, 693, 723, 725, 726, 759, 761, 763, 766]),),
#  (array([694, 993]),),
#  (array([748]),),
#  (array([ 296,  755,  758, 1033]),),
#  (array([], dtype=int64),),
#  (array([296, 753, 758]),),
#  (array([295, 757]),),
#  (array([295, 756]),),
#  (array([296, 753, 755]),),
#  (array([689, 693, 695, 725, 726, 750, 761, 763, 766]),),
#  (array([293, 722, 728, 729, 730, 762]),),
#  (array([689, 693, 695, 725, 726, 750, 759, 763, 766]),),
#  (array([730, 760]),),
#  (array([693, 723, 725, 726, 746, 750, 759, 761, 766]),),
#  (array([], dtype=int64),),
#  (array([786]),),
#  (array([693, 723, 725, 726, 750, 759, 761, 763]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([772]),),
#  (array([], dtype=int64),),
#  (array([774, 779, 782]),),
#  (array([769, 787]),),
#  (array([], dtype=int64),),
#  (array([771]),),
#  (array([ 712,  776,  778,  780,  781, 1023, 1039]),),
#  (array([ 775,  780,  781, 1023]),),
#  (array([781, 782, 783]),),
#  (array([ 711,  712,  775,  776,  780,  781, 1023, 1039]),),
#  (array([711, 771, 782]),),
#  (array([ 775,  776,  778,  781, 1023]),),
#  (array([712, 775, 776, 777, 778, 780, 783]),),
#  (array([771, 777, 779]),),
#  (array([777, 781]),),
#  (array([785]),),
#  (array([784]),),
#  (array([765]),),
#  (array([772, 788, 789, 792]),),
#  (array([787, 789]),),
#  (array([711, 787, 788, 792]),),
#  (array([791]),),
#  (array([790]),),
#  (array([787, 789]),),
#  (array([794]),),
#  (array([793]),),
#  (array([], dtype=int64),),
#  (array([735, 797]),),
#  (array([796]),),
#  (array([298, 654, 660, 661, 662, 663, 732, 733]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([736, 737, 803, 999]),),
#  (array([], dtype=int64),),
#  (array([736, 737, 801]),),
#  (array([], dtype=int64),),
#  (array([708, 724, 806]),),
#  (array([701, 708, 724, 805]),),
#  (array([293, 690, 691, 697, 727]),),
#  (array([816]),),
#  (array([705]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([713, 718, 815]),),
#  (array([713, 718, 814]),),
#  (array([808]),),
#  (array([983, 984, 990, 994]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([302]),),
#  (array([], dtype=int64),),
#  (array([825]),),
#  (array([824]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([672]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([176]),),
#  (array([], dtype=int64),),
#  (array([309]),),
#  (array([312, 845]),),
#  (array([566]),),
#  (array([852]),),
#  (array([314]),),
#  (array([], dtype=int64),),
#  (array([312, 840]),),
#  (array([243, 310, 435]),),
#  (array([432]),),
#  (array([], dtype=int64),),
#  (array([181]),),
#  (array([270, 576]),),
#  (array([], dtype=int64),),
#  (array([315, 842]),),
#  (array([590]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([30]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([1127]),),
#  (array([1090, 1120]),),
#  (array([ 550,  551, 1062, 1118, 1121, 1123]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([322, 323]),),
#  (array([ 58, 107]),),
#  (array([316, 324]),),
#  (array([], dtype=int64),),
#  (array([34]),),
#  (array([188]),),
#  (array([93]),),
#  (array([], dtype=int64),),
#  (array([ 60, 112]),),
#  (array([], dtype=int64),),
#  (array([604, 608]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([883]),),
#  (array([192, 332, 350, 884]),),
#  (array([881]),),
#  (array([192, 332, 350, 882]),),
#  (array([], dtype=int64),),
#  (array([887]),),
#  (array([886]),),
#  (array([], dtype=int64),),
#  (array([890]),),
#  (array([889]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([896, 908]),),
#  (array([908]),),
#  (array([894, 908]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([900, 901]),),
#  (array([899, 901]),),
#  (array([899, 900]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([612]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([894, 895, 896]),),
#  (array([961, 962]),),
#  (array([], dtype=int64),),
#  (array([382, 913]),),
#  (array([ 100,  123,  338,  339,  368,  376,  377,  935,  942, 1154]),),
#  (array([911]),),
#  (array([], dtype=int64),),
#  (array([348]),),
#  (array([917, 919, 958]),),
#  (array([916, 958]),),
#  (array([336, 380, 919]),),
#  (array([336, 916, 918]),),
#  (array([685, 686, 687, 688, 924, 925]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([365]),),
#  (array([685, 686, 687, 688, 920, 925]),),
#  (array([685, 686, 687, 688, 920, 924]),),
#  (array([955, 963]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([381, 932]),),
#  (array([381, 931]),),
#  (array([666, 934]),),
#  (array([933, 965]),),
#  (array([123, 205, 338, 339, 366, 368, 373, 376, 912, 947]),),
#  (array([205, 335, 365, 366, 367, 369, 371, 938, 943, 947]),),
#  (array([], dtype=int64),),
#  (array([205, 335, 365, 366, 367, 369, 371, 936, 943, 947]),),
#  (array([122, 204, 363, 364, 372, 941]),),
#  (array([], dtype=int64),),
#  (array([122, 204, 363, 364, 370, 372, 939, 945]),),
#  (array([ 100,  123,  338,  339,  368,  376,  377,  912, 1154]),),
#  (array([335, 367, 369, 370, 936, 938, 945]),),
#  (array([946, 959]),),
#  (array([369, 370, 941, 943]),),
#  (array([944, 959]),),
#  (array([123, 205, 335, 339, 365, 366, 367, 368, 371, 373, 935, 936, 938]),),
#  (array([], dtype=int64),),
#  (array([194]),),
#  (array([194]),),
#  (array([], dtype=int64),),
#  (array([953]),),
#  (array([952]),),
#  (array([973]),),
#  (array([926, 963]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([916, 917]),),
#  (array([944, 946]),),
#  (array([], dtype=int64),),
#  (array([909, 962]),),
#  (array([909, 961]),),
#  (array([926, 955]),),
#  (array([646, 965]),),
#  (array([646, 934, 964]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([170]),),
#  (array([970]),),
#  (array([969]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([954, 974, 977]),),
#  (array([973, 977]),),
#  (array([976]),),
#  (array([975]),),
#  (array([973, 974]),),
#  (array([115]),),
#  (array([], dtype=int64),),
#  (array([ 38, 361]),),
#  (array([983, 990, 994]),),
#  (array([299, 734]),),
#  (array([817, 981, 990, 994]),),
#  (array([817, 990]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([993, 995, 996]),),
#  (array([702, 740, 746]),),
#  (array([992]),),
#  (array([817, 981, 983, 984, 994]),),
#  (array([], dtype=int64),),
#  (array([989]),),
#  (array([694, 751, 987]),),
#  (array([981, 983, 990]),),
#  (array([987]),),
#  (array([987]),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([ 737,  801, 1002]),),
#  ...]

# %%
closestarstics90 = []
for i in range (len(closestarslist90)):
    tics = []
    tics.append(ref[stars90].TIC_ID.values[i])
    for j in range(len(closestarslist90[i][0])):
        tics.append(ref[stars90].TIC_ID.values[closestarslist90[i][0][j]])
    closestarstics90.append(tics)

# %%
refebs = ref.loc[ref['TIC_ID'].isin(eb90.index.values)]
files = data_dir + refebs.Filename.values
lcc = loaders.LightCurveCollection(refebs.Sector.values,
                                   refebs.Camera.values,
                                   files,
                                   False
                            )
lcc.useCpus = 8
lcc.load_all_lcs()

lcs = lcc.lcs

# %%
len(lcs)
# Out:
# 1156

# %%
tic = []
avgflux = []
    
for i in range(len(lcs)):
    tic.append(refebs['TIC_ID'].values[i])
    avgflux.append(np.median(lcs[i].flux.value))

# %%
df = {'TIC': tic, 'avgflux': avgflux}
avg = pd.DataFrame(df)

# %%
highestfluxtics = []
for i in range(len(closestarstics90)):
    a = []
    for j in closestarstics90[i]:
        a.append(avg[avg['TIC'] == j].avgflux.values[0])
    highestfluxtics.append(closestarstics90[i][a.index(max(a))])

# %%
result = checkIfDuplicates_2(highestfluxtics)
if result:
    print('Yes, list contains duplicates')
else:
    print('No duplicates found in list')
# Out:
# Yes, list contains duplicates

# %%
newlist = [] #eb list with no duplicates, cut down to ones with highest flux values in a radius of 0.1
duplist = []
for i in highestfluxtics:
    if i not in newlist:
        newlist.append(i)
    else:
        duplist.append(i)

# %%
len(newlist)
# Out:
# 755

# %%
lcc = loaders.LightCurveCollection(refebs.Sector.values,
                                   refebs.Camera.values,
                                   files,
                                   False
                            )
lcc.useCpus = 8
lcc.load_all_lcs()

lcs = lcc.lcs

# %%
import matplotlib.pyplot as plt

from matplotlib.backends.backend_pdf import PdfPages

with PdfPages(f"Sector1/90-100%ebsmodified2.pdf") as pdf:
    plt.cla()
    for i in range(len(newlist)):
        lcs[i].scatter()
        pdf.savefig()
        plt.close();
plt.close()

# %%
len(newlist)
# Out:
# 753

# %% [markdown]
# ____
# 70-90%

# %%
eb70 = sec1[sec1['probone'] > 0.7]
eb70 = eb70[eb70['probone'] < 0.9]

# %%
eb70
# Out:
#             probzero   probone  pred
# 270221859   0.102000  0.898000     1
# 126803454   0.102000  0.898000     1
# 206488769   0.102000  0.898000     1
# 231702259   0.102000  0.898000     1
# 1989908229  0.102000  0.898000     1
# ...              ...       ...   ...
# 325338582   0.298000  0.702000     1
# 99672412    0.298000  0.702000     1
# 211411347   0.298000  0.702000     1
# 358578246   0.298333  0.701667     1
# 309859850   0.299000  0.701000     1
#
# [553 rows x 3 columns]

# %%
tics70 = eb70.index.values
len(tics70)
# Out:
# 553

# %%
stars70 = ref.TIC_ID.isin(tics70)
ref[stars70]
# Out:
#                                                   Filename          RA  \
# 1583     tesslcs_sector_1_104/2_min_cadence_targets/tes...  329.657326
# 6671     tesslcs_sector_1_104/2_min_cadence_targets/tes...  346.257891
# 6740     tesslcs_sector_1_104/2_min_cadence_targets/tes...  327.972707
# 8009     tesslcs_sector_1_104/2_min_cadence_targets/tes...   42.004698
# 9054     tesslcs_sector_1_104/2_min_cadence_targets/tes...  314.508758
# ...                                                    ...         ...
# 1167597  tesslcs_sector_1_104/tesslcs_tmag_14_15/tesslc...  111.128836
# 1171727  tesslcs_sector_1_104/tesslcs_tmag_14_15/tesslc...   82.671529
# 1182861  tesslcs_sector_1_104/tesslcs_tmag_9_10/tesslc_...   95.250848
# 1185492  tesslcs_sector_1_104/tesslcs_tmag_9_10/tesslc_...    7.044836
# 1187585  tesslcs_sector_1_104/tesslcs_tmag_9_10/tesslc_...  109.671266
#
#                Dec     TIC_ID  Sector  Camera  CCD  Magnitude
# 1583    -45.743401  389726435       1       2    4     7.5370
# 6671    -43.935783  139207681       1       2    3    11.1999
# 6740    -42.373203  144194304       1       1    1     9.1715
# 8009    -62.964119  220521199       1       3    4     7.6334
# 9054    -46.066771  126602778       1       1    1    10.8078
# ...            ...        ...     ...     ...  ...        ...
# 1167597 -67.592412  300379437       1       4    3    14.8609
# 1171727 -67.105892  391745881       1       4    1    14.1482
# 1182861 -54.549127  260370454       1       4    4     9.5690
# 1185492 -59.322451  281562112       1       3    1     9.2338
# 1187585 -64.667674  349311164       1       4    3     9.8965
#
# [553 rows x 8 columns]

# %%
closestarslist70 = []
for i in range(len(tics70)):
    rastar = ref[stars70].RA.values[i]
    decstar = ref[stars70].Dec.values[i]
    dist = np.sqrt(((rastar-ref[stars70].RA.values)*(np.cos(decstar)))**2+(decstar-ref[stars70].Dec.values)**2)
    closestars = np.where((dist < 0.1) & (dist != 0))
    closestarslist70.append(closestars)

# %%
closestarstics70 = []
for i in range (len(closestarslist70)):
    tics = []
    tics.append(ref[stars70].TIC_ID.values[i])
    for j in range(len(closestarslist70[i][0])):
        tics.append(ref[stars70].TIC_ID.values[closestarslist70[i][0][j]])
    closestarstics70.append(tics)

# %%
refebs = ref.loc[ref['TIC_ID'].isin(eb70.index.values)]
files = data_dir + refebs.Filename.values
lcc = loaders.LightCurveCollection(refebs.Sector.values,
                                   refebs.Camera.values,
                                   files,
                                   False
                            )
lcc.useCpus = 8
lcc.load_all_lcs()

lcs = lcc.lcs

# %%
len(lcs)
# Out:
# 553

# %%
tic = []
avgflux = []
    
for i in range(len(lcs)):
    tic.append(refebs['TIC_ID'].values[i])
    avgflux.append(np.median(lcs[i].flux.value))

# %%
df = {'TIC': tic, 'avgflux': avgflux}
avg = pd.DataFrame(df)

# %%
highestfluxtics = []
for i in range(len(closestarstics70)):
    a = []
    for j in closestarstics70[i]:
        a.append(avg[avg['TIC'] == j].avgflux.values[0])
    highestfluxtics.append(closestarstics70[i][a.index(max(a))])

# %%
result = checkIfDuplicates_2(highestfluxtics)
if result:
    print('Yes, list contains duplicates')
else:
    print('No duplicates found in list')
# Out:
# Yes, list contains duplicates

# %%
newlist = [] #eb list with no duplicates, cut down to ones with highest flux values in a radius of 0.1
duplist = []
for i in highestfluxtics:
    if i not in newlist:
        newlist.append(i)
    else:
        duplist.append(i)

# %%
len(newlist)
# Out:
# 455

# %%
lcc = loaders.LightCurveCollection(refebs.Sector.values,
                                   refebs.Camera.values,
                                   files,
                                   False
                            )
lcc.useCpus = 8
lcc.load_all_lcs()

lcs = lcc.lcs

# %%
with PdfPages(f"Sector1/70-90%ebsmodified.pdf") as pdf:
    plt.cla()
    for i in range(len(newlist)):
        lcs[i].scatter()
        pdf.savefig()
        plt.close();
plt.close()

# %% [markdown]
# ____
# 60-70%

# %%
eb60 = sec1[sec1['probone'] > 0.6]
eb60 = eb60[eb60['probone'] < 0.7]

# %%
eb60
# Out:
#            probzero   probone  pred
# 141544911  0.300800  0.699200     1
# 441406061  0.301471  0.698529     1
# 231910499  0.302000  0.698000     1
# 139347748  0.302000  0.698000     1
# 262704654  0.302000  0.698000     1
# ...             ...       ...   ...
# 319290682  0.398000  0.602000     1
# 289950539  0.398867  0.601133     1
# 309780442  0.399000  0.601000     1
# 302299660  0.399000  0.601000     1
# 289936195  0.399000  0.601000     1
#
# [889 rows x 3 columns]

# %%
tics60 = eb60.index.values
len(tics60)
# Out:
# 889

# %%
stars60 = ref.TIC_ID.isin(tics60)
ref[stars60]
# Out:
#                                                   Filename          RA  \
# 1362     tesslcs_sector_1_104/2_min_cadence_targets/tes...  339.173601
# 1921     tesslcs_sector_1_104/2_min_cadence_targets/tes...  310.802024
# 5733     tesslcs_sector_1_104/2_min_cadence_targets/tes...   75.384919
# 6223     tesslcs_sector_1_104/2_min_cadence_targets/tes...  311.362145
# 8245     tesslcs_sector_1_104/2_min_cadence_targets/tes...   64.090211
# ...                                                    ...         ...
# 1167485  tesslcs_sector_1_104/tesslcs_tmag_14_15/tesslc...  111.152728
# 1167584  tesslcs_sector_1_104/tesslcs_tmag_14_15/tesslc...  117.480197
# 1167605  tesslcs_sector_1_104/tesslcs_tmag_14_15/tesslc...  117.614797
# 1167834  tesslcs_sector_1_104/tesslcs_tmag_14_15/tesslc...  108.913548
# 1190317  tesslcs_sector_1_104/tesslcs_tmag_9_10/tesslc_...  100.658603
#
#                Dec     TIC_ID  Sector  Camera  CCD  Magnitude
# 1362    -38.302472  214198381       1       1    2    11.0508
# 1921    -32.293175  441406061       1       1    4     9.4763
# 5733    -59.512804  220474209       1       4    1    10.2897
# 6223    -34.646424  441422220       1       1    4     9.0641
# 8245    -62.012890   38586438       1       4    1    11.6704
# ...            ...        ...     ...     ...  ...        ...
# 1167485 -66.605915  300380202       1       4    3    14.9440
# 1167584 -67.943912  300934054       1       4    3    14.9862
# 1167605 -67.926111  300934070       1       4    3    14.5988
# 1167834 -66.702985  300141911       1       4    3    14.9829
# 1190317 -56.541875  278861826       1       4    4     9.8695
#
# [889 rows x 8 columns]

# %%
closestarslist60 = []
for i in range(len(tics60)):
    rastar = ref[stars60].RA.values[i]
    decstar = ref[stars60].Dec.values[i]
    dist = np.sqrt(((rastar-ref[stars60].RA.values)*(np.cos(decstar)))**2+(decstar-ref[stars60].Dec.values)**2)
    closestars = np.where((dist < 0.1) & (dist != 0))
    closestarslist60.append(closestars)

# %%
closestarstics60 = []
for i in range (len(closestarslist60)):
    tics = []
    tics.append(ref[stars60].TIC_ID.values[i])
    for j in range(len(closestarslist60[i][0])):
        tics.append(ref[stars60].TIC_ID.values[closestarslist60[i][0][j]])
    closestarstics60.append(tics)

# %%
refebs = ref.loc[ref['TIC_ID'].isin(eb60.index.values)]
files = data_dir + refebs.Filename.values
lcc = loaders.LightCurveCollection(refebs.Sector.values,
                                   refebs.Camera.values,
                                   files,
                                   False
                            )
lcc.useCpus = 8
lcc.load_all_lcs()

lcs = lcc.lcs

# %%
len(lcs)
# Out:
# 889

# %%
tic = []
avgflux = []
    
for i in range(len(lcs)):
    tic.append(refebs['TIC_ID'].values[i])
    avgflux.append(np.median(lcs[i].flux.value))

# %%
df = {'TIC': tic, 'avgflux': avgflux}
avg = pd.DataFrame(df)

# %%
highestfluxtics = []
for i in range(len(closestarstics60)):
    a = []
    for j in closestarstics60[i]:
        a.append(avg[avg['TIC'] == j].avgflux.values[0])
    highestfluxtics.append(closestarstics60[i][a.index(max(a))])

# %%
result = checkIfDuplicates_2(highestfluxtics)
if result:
    print('Yes, list contains duplicates')
else:
    print('No duplicates found in list')
# Out:
# Yes, list contains duplicates

# %%
newlist = [] #eb list with no duplicates, cut down to ones with highest flux values in a radius of 0.1
duplist = []
for i in highestfluxtics:
    if i not in newlist:
        newlist.append(i)
    else:
        duplist.append(i)

# %%
len(newlist)
# Out:
# 633

# %%
lcc = loaders.LightCurveCollection(refebs.Sector.values,
                                   refebs.Camera.values,
                                   files,
                                   False
                            )
lcc.useCpus = 8
lcc.load_all_lcs()

lcs = lcc.lcs

# %%
with PdfPages(f"Sector1/60-70%ebsmodified.pdf") as pdf:
    plt.cla()
    for i in range(len(newlist)):
        lcs[i].scatter()
        pdf.savefig()
        plt.close();
plt.close()

# %% [markdown]
# ___

# %% [markdown]
# 50%-60%

# %%
data_dir = "/home/jupyter/mountpoint/"

# %%
ref = pd.read_csv(data_dir + 'sector1lookup.csv')

# %%
ref
# Out:
#                                                   Filename          RA  \
# 0        tesslcs_sector_1_104/2_min_cadence_targets/tes...  318.057138
# 1        tesslcs_sector_1_104/2_min_cadence_targets/tes...  312.371213
# 2        tesslcs_sector_1_104/2_min_cadence_targets/tes...  318.093446
# 3        tesslcs_sector_1_104/2_min_cadence_targets/tes...  312.316831
# 4        tesslcs_sector_1_104/2_min_cadence_targets/tes...  316.741183
# ...                                                    ...         ...
# 1192402  tesslcs_sector_1_104/tesslcs_tmag_9_10/tesslc_...   77.255332
# 1192403  tesslcs_sector_1_104/tesslcs_tmag_9_10/tesslc_...   76.045921
# 1192404  tesslcs_sector_1_104/tesslcs_tmag_9_10/tesslc_...   65.861085
# 1192405  tesslcs_sector_1_104/tesslcs_tmag_9_10/tesslc_...   53.767747
# 1192406  tesslcs_sector_1_104/tesslcs_tmag_9_10/tesslc_...   96.551983
#
#                Dec     TIC_ID  Sector  Camera  CCD  Magnitude
# 0       -40.269362  159670453       1       1    1     5.4117
# 1       -41.711500  389450629       1       1    1     7.8065
# 2       -41.931732  159671133       1       1    1     9.5973
# 3       -41.644755  389450601       1       1    1    10.1857
# 4       -40.591502  115115510       1       1    1     8.8380
# ...            ...        ...     ...     ...  ...        ...
# 1192402 -67.176152   40337767       1       4    1     9.0043
# 1192403 -67.546160   30931836       1       4    1     9.6937
# 1192404 -66.135079  370041020       1       4    1     9.8354
# 1192405 -67.832940   31927505       1       3    4     9.9057
# 1192406 -53.245226  255567371       1       4    4     9.9048
#
# [1192407 rows x 8 columns]

# %%
eb50 = sec1[sec1['probone'] > 0.5]
eb50 = eb50[eb50['probone'] < 0.6]

# %%
tics50 = eb50.index.values
len(tics50)
# Out:
# 1849

# %%
stars50 = ref.TIC_ID.isin(tics50)
ref[stars50]
# Out:
#                                                   Filename          RA  \
# 571      tesslcs_sector_1_104/2_min_cadence_targets/tes...   66.470863
# 715      tesslcs_sector_1_104/2_min_cadence_targets/tes...   16.409233
# 758      tesslcs_sector_1_104/2_min_cadence_targets/tes...  334.810708
# 797      tesslcs_sector_1_104/2_min_cadence_targets/tes...   20.218095
# 894      tesslcs_sector_1_104/2_min_cadence_targets/tes...  322.763703
# ...                                                    ...         ...
# 1187639  tesslcs_sector_1_104/tesslcs_tmag_9_10/tesslc_...   81.455091
# 1188704  tesslcs_sector_1_104/tesslcs_tmag_9_10/tesslc_...  336.837903
# 1190201  tesslcs_sector_1_104/tesslcs_tmag_9_10/tesslc_...   34.502523
# 1190959  tesslcs_sector_1_104/tesslcs_tmag_9_10/tesslc_...  111.752572
# 1191848  tesslcs_sector_1_104/tesslcs_tmag_9_10/tesslc_...  320.428150
#
#                Dec      TIC_ID  Sector  Camera  CCD  Magnitude
# 571     -81.319731   269762258       1       3    3  13.024600
# 715     -80.061304   263074592       1       3    3   9.358700
# 758     -40.533673   278706358       1       1    2  10.389200
# 797     -80.316844   261656371       1       3    3  10.566000
# 894     -50.846920   139721086       1       2    4   7.893700
# ...            ...         ...     ...     ...  ...        ...
# 1187639 -64.989374   149160359       1       4    1   9.992700
# 1188704 -58.000068  2026963422       1       2    1   9.567800
# 1190201 -71.467326   630986911       1       3    4   9.647000
# 1190959 -63.734975   349572805       1       4    3   9.833201
# 1191848 -30.936537   211336604       1       1    4   9.741900
#
# [1849 rows x 8 columns]

# %%
closestarslist50 = []
for i in range(len(tics50)):
    rastar = ref[stars50].RA.values[i]
    decstar = ref[stars50].Dec.values[i]
    dist = np.sqrt(((rastar-ref[stars50].RA.values)*(np.cos(decstar)))**2+(decstar-ref[stars50].Dec.values)**2)
    closestars = np.where((dist < 0.1) & (dist != 0))
    closestarslist50.append(closestars)

# %%
closestarstics50 = []
for i in range (len(closestarslist50)):
    tics = []
    tics.append(ref[stars50].TIC_ID.values[i])
    for j in range(len(closestarslist50[i][0])):
        tics.append(ref[stars50].TIC_ID.values[closestarslist50[i][0][j]])
    closestarstics50.append(tics)

# %%
refebs = ref.loc[ref['TIC_ID'].isin(eb50.index.values)]

# %%
files = data_dir + refebs.Filename.values
lcc = loaders.LightCurveCollection(refebs.Sector.values,
                                   refebs.Camera.values,
                                   files,
                                   False
                            )
lcc.useCpus = 8
lcc.load_all_lcs()

lcs = lcc.lcs

# %%
len(lcs)
# Out:
# 1849

# %%
tic = []
avgflux = []
    
for i in range(len(lcs)):
    tic.append(refebs['TIC_ID'].values[i])
    avgflux.append(np.median(lcs[i].flux.value))

# %%
df = {'TIC': tic, 'avgflux': avgflux}
avg = pd.DataFrame(df)

# %%
highestfluxtics = []
for i in range(len(closestarstics50)):
    a = []
    for j in closestarstics50[i]:
        a.append(avg[avg['TIC'] == j].avgflux.values[0])
    highestfluxtics.append(closestarstics50[i][a.index(max(a))])

# %%
result = checkIfDuplicates_2(highestfluxtics)
if result:
    print('Yes, list contains duplicates')
else:
    print('No duplicates found in list')
# Out:
# Yes, list contains duplicates

# %%
newlist = [] #eb list with no duplicates, cut down to ones with highest flux values in a radius of 0.1
duplist = []
for i in highestfluxtics:
    if i not in newlist:
        newlist.append(i)
    else:
        duplist.append(i)

# %%
len(newlist)
# Out:
# 1126

# %%
lcc = loaders.LightCurveCollection(refebs.Sector.values,
                                   refebs.Camera.values,
                                   files,
                                   False
                            )
lcc.useCpus = 8
lcc.load_all_lcs()

lcs = lcc.lcs

# %%
with PdfPages(f"Sector1/50-60%ebsmodified.pdf") as pdf:
    plt.cla()
    for i in range(len(newlist)):
        lcs[i].scatter()
        pdf.savefig()
        plt.close();
plt.close()

# %% [markdown]
# ___

# %%
sec1.loc[[247878713]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_16319/903582371.py in <module>
# ----> 1 sec1.loc[[247878713]]
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1151                     raise ValueError("Cannot index with multidimensional key")
#    1152
# -> 1153                 return self._getitem_iterable(key, axis=axis)
#    1154
#    1155             # nested tuple slicing
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1091
#    1092         # A collection of keys
# -> 1093         keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1094         return self.obj._reindex_with_indexers(
#    1095             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1372                 if use_interval_msg:
#    1373                     key = list(key)
# -> 1374                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Int64Index([247878713], dtype='int64')] are in the [index]"

# %%
sec6 = pd.read_csv('Sector6/pred&confidenceValsSector6.csv', index_col=0)

# %%
sec6.loc[[247878713]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_16319/2440183153.py in <module>
# ----> 1 sec6.loc[[247878713]]
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1151                     raise ValueError("Cannot index with multidimensional key")
#    1152
# -> 1153                 return self._getitem_iterable(key, axis=axis)
#    1154
#    1155             # nested tuple slicing
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1091
#    1092         # A collection of keys
# -> 1093         keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1094         return self.obj._reindex_with_indexers(
#    1095             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1372                 if use_interval_msg:
#    1373                     key = list(key)
# -> 1374                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Int64Index([247878713], dtype='int64')] are in the [index]"

# %%
sec6.loc[[141126559]]
# Out:
#            longtermtrend  meanmedrat     skews     varss  coeffvar  stds  \
# 141126559       0.129283    0.966157  0.016714  0.133812     225.0   0.0
#
#            numoutliers  numnegoutliers  numposoutliers  numout1s  ...  \
# 141126559          1.0             1.0        0.078338  1.612755  ...
#
#            tflatmean  roundmean  troundmean  roundrat   flatrat  mstat  \
# 141126559   0.382946   0.535229    0.865685  0.966863  0.332072  0.809
#
#              astat  pred  probzero  probone
# 141126559  0.86665     1    0.4535   0.5465
#
# [1 rows x 65 columns]
